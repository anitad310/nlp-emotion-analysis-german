# %% [markdown]
# # Distributional Analysis of the Emotions "Freude" and "Wut" in German Corpora (DWDS)
#
# An academic project focused on linguistic analysis and text data mining using 6 subcorpora from the **DWDS** (Digitales Wörterbuch der deutschen Sprache) platform.
#
# ## What does this project do?
# * **Data Cleaning:** Tokenization, stopword removal, and special character filtering tailored for the German language (using NLTK and Re).
# * **Collocation Analysis:** Extracting the most frequent word co-occurrences within a specific context window.
# * **Embeddings (Word2Vec):** Training a word vector model (using Gensim) to explore the semantic proximity of emotions.
# * **Clustering (K-Means & PCA):** Clustering emotional concepts and visualizing them in a 2D space.
#
# ### Legal Note and Data
# In compliance with the DWDS license, the raw text data (`.tsv`, `.xlsx`) **is not included in this public repository**. This project contains only the original processing code.
#
# ## Analysis Results (Visualization)
# To facilitate visualization - without the need to download the necessary corpora, or prior to doing - so visualization results and result tables appear in Markdown format following certain code blocks.

# %%
import pandas as pd

# %%
zeitungskorpora_freude = pd.read_csv("Berliner_Zeitung_94-05_Freude.tsv", sep='\t')
zeitungskorpora_freude
# Out:
#     No.        Date    Genre                          Bibl  URL  \
# 0     1  2005-12-31  Zeitung  Berliner Zeitung, 31.12.2005  NaN
# 1     2  2005-12-31  Zeitung  Berliner Zeitung, 31.12.2005  NaN
# 2     3  2005-12-31  Zeitung  Berliner Zeitung, 31.12.2005  NaN
# 3     4  2005-12-31  Zeitung  Berliner Zeitung, 31.12.2005  NaN
# 4     5  2005-12-31  Zeitung  Berliner Zeitung, 31.12.2005  NaN
# ..  ...         ...      ...                           ...  ...
# 95   96  2005-12-05  Zeitung  Berliner Zeitung, 05.12.2005  NaN
# 96   97  2005-12-05  Zeitung  Berliner Zeitung, 05.12.2005  NaN
# 97   98  2005-12-03  Zeitung  Berliner Zeitung, 03.12.2005  NaN
# 98   99  2005-12-03  Zeitung  Berliner Zeitung, 03.12.2005  NaN
# 99  100  2005-12-03  Zeitung  Berliner Zeitung, 03.12.2005  NaN
#
#                                         ContextBefore     Hit  \
# 0                         Sie werden sehen , wie viel  Freude
# 1   Die ganze deutsche Eislauf-Familie weiß sich a...  Freude
# 2                                                 NaN  Freude
# 3                            Meine Motivation ist die  Freude
# 4                         Sie werden sehen , wie viel  Freude
# ..                                                ...     ...
# 95  Hübchen , der leer ausgegangen war , tröstete ...  Freude
# 96  Dionysos , den Schlangenledermantel cool überg...  Freude
# 97  Die Probleme des Westens , ob in Irak oder nun...  Freude
# 98                                            Und die  Freude
# 99                         Das Haus sei "" eine wahre  Freude
#
#                                          ContextAfter
# 0   es macht , wenn man Schritt für Schritt voran ...
# 1   kaum zu fassen , doch er beantwortet die Frage...
# 2   : Der Erfurter Stefan Lindemann hat sich zum f...
# 3              am Springen "" , sagt Martin Schmitt :
# 4   es macht , wenn man Schritt für Schritt voran ...
# ..                                                ...
# 95                           an diesem Film habe . ""
# 96                               am offenen Ausgang .
# 97                                      aufgenommen .
# 98                                         hielt an .
# 99                 , findet ein Ehepaar aus Frohnau .
#
# [100 rows x 8 columns]

# %%
webkorpora_freude = pd.read_csv("Webkorpora_Blogs_95-14_Freude.tsv", sep='\t')
webkorpora_freude
# Out:
#     No.        Date            Genre  \
# 0     1  2014-01-24  internetbasiert
# 1     2  2014-01-20  internetbasiert
# 2     3  2014-01-20  internetbasiert
# 3     4  2014-01-19  internetbasiert
# 4     5  2014-01-19  internetbasiert
# ..  ...         ...              ...
# 95   96  2013-12-08  internetbasiert
# 96   97  2013-12-08  internetbasiert
# 97   98  2013-12-04  internetbasiert
# 98   99  2013-12-04  internetbasiert
# 99  100  2013-12-04  internetbasiert
#
#                                                  Bibl  \
# 0               Events. Cowboy of Bottrop, 2014-01-24
# 1   NEUES VON FREUNDEN , short cut. zintzen.org, 2...
# 2   NEUES VON FREUNDEN , short cut. zintzen.org, 2...
# 3   JobKompass – Mindestsicherung’s steirische Erf...
# 4   wort oder doch sprache …. Area V. Info aus Gra...
# ..                                                ...
# 95  schon zwee. Max und Vio's Schreibblog, 2013-12-08
# 96  Salon Littéraire | Crauss. : Schönheit des Was...
# 97  Der Steampunk und das Rett-Syndrom. PhantaNews...
# 98  AlleKochen-Weihnachtsgewinnspiel - AlleKochen....
# 99  Koalitionsvertrag 2013 - ich stimme zu!. Lumma...
#
#                                                   URL  \
# 0             http://www.cowboy-of-bottrop.de/events/
# 1   http://www.zintzen.org/2014/01/20/neues-von-fr...
# 2   http://www.zintzen.org/2014/01/20/neues-von-fr...
# 3            http://v-areainfo.styriartig.at/?p=15636
# 4             http://v-areainfo.styriartig.at/?p=5477
# ..                                                ...
# 95      http://blog.max-fun.de/2013/12/08/schon-zwee/
# 96  http://www.zintzen.org/2013/12/08/salon-litter...
# 97  http://phantanews.de/wp/2013/12/der-steampunk-...
# 98  http://www.allekochen.com/allekochen-weihnacht...
# 99  http://lumma.de/2013/12/04/koalitionsvertrag-2...
#
#                                         ContextBefore  \
# 0   Nun präsentiert sich die Band um Sänger Christ...
# 1   in den 60ern und 70ern des 20. jahrhunderts ge...
# 2   in den 60ern und 70ern des 20. jahrhunderts ge...
# 3   mein erster Lebenslauf hat auch nicht wirklich...
# 4   Schon das Besprechen innerhalb ritueller handl...
# ..                                                ...
# 95         Wir wünschen euch einen schönen 2. Advent.
# 96  SIEHT SO DIE FINSTERNIS AUS: staunend einem ca...
# 97  Lesen Sie, was all diese Helden in den Geschic...
# 98  Die ersten Kekse sind gebacken und der Schnee ...
# 99  Gestern bin ich zur Regionalkonferenz der SPD ...
#
#                                                   Hit  \
# 0   Liebhaber des Western, Folk und Blues werden i...
# 1   [...] Eine historische Romanze 1966″. in seine...
# 2   [...] Eine historische Romanze 1966″. in seine...
# 3   Aber ich musste nicht nur lächeln, es hat mich...
# 4   Im spass, in der freude und lust, entschuldige...
# ..                                                ...
# 95  P.S. wer uns ne Freude machen will: hier gibts...
# 96  was siehst du. das seltsamste ist nicht der re...
# 97  Nicht nur Fans von Steampunk und Jules Verne w...
# 98  Jetzt fehlt eigentlich nur noch eine Kleinigke...
# 99  Was den Koalitionsvertrag angeht, da bin ich j...
#
#                                          ContextAfter
# 0   2010 gewannen Gringos Fate den WDR2 Bandwettbe...
# 1                                 (herbert j. wimmer)
# 2                                 (herbert j. wimmer)
# 3        Ich hatte und habe endlich einen Lebenslauf.
# 4   Im ernst würde ich nie etwas machen, tun, um d...
# ..                                                ...
# 95    Kommentare zu diesem Beitrag verfolgen: via RSS
# 96  SCHMETTERLINGSFLÜGEL, durchsichtiger mit jedem...
# 97  Was Sie auch lesen werden, ist die weltweit er...
# 98  Die Kreativen unter euch haben da sicher berei...
# 99  Ja, es wäre wünschenswert, wenn einiges schnel...
#
# [100 rows x 8 columns]

# %%
metakorpora_freude = pd.read_csv("Metakorpora_DTA_Freude.tsv", sep='\t')
metakorpora_freude
# Out:
#     No. Corpus  Date               Genre  \
# 0     1   dtae  1987  Gebrauchsliteratur
# 1     2   dtae  1987  Gebrauchsliteratur
# 2     3   dtae  1987  Gebrauchsliteratur
# 3     4   dtae  1987  Gebrauchsliteratur
# 4     5   dtae  1987  Gebrauchsliteratur
# ..  ...    ...   ...                 ...
# 95   96   dtae  1987  Gebrauchsliteratur
# 96   97   dtae  1987  Gebrauchsliteratur
# 97   98   dtae  1987  Gebrauchsliteratur
# 98   99   dtae  1987  Gebrauchsliteratur
# 99  100   dtae  1987  Gebrauchsliteratur
#
#                                           Bibl  \
# 0   Kuczynski, Jürgen: Tagebuch. Berlin, 1987.
# 1   Kuczynski, Jürgen: Tagebuch. Berlin, 1987.
# 2   Kuczynski, Jürgen: Tagebuch. Berlin, 1987.
# 3   Kuczynski, Jürgen: Tagebuch. Berlin, 1987.
# 4   Kuczynski, Jürgen: Tagebuch. Berlin, 1987.
# ..                                         ...
# 95  Kuczynski, Jürgen: Tagebuch. Berlin, 1987.
# 96  Kuczynski, Jürgen: Tagebuch. Berlin, 1987.
# 97  Kuczynski, Jürgen: Tagebuch. Berlin, 1987.
# 98  Kuczynski, Jürgen: Tagebuch. Berlin, 1987.
# 99  Kuczynski, Jürgen: Tagebuch. Berlin, 1987.
#
#                                         ContextBefore  \
# 0   Und was das Akademie-Institut betrifft, so ist...
# 1          Gestern Nachmittag 11/2 Stunden bei Varga.
# 2   Heute früh eine unbedeutende Sitzung mit Schuk...
# 3   Statt mit dem Tode des Gr.H. aber mit einer Ho...
# 4                                            13 *5.57
# ..                                                ...
# 95  Im Zimmer der Generaldirektion des Konzerns ""...
# 96  Rolf Möbius Abteilungsleiter Prop. /Wiss e ns ...
# 97                  Hatte ein wunderschönes Erlebnis.
# 98  Natürlich ist mir meine Liebe zu ihr bewußt, a...
# 99  Natürlich ist mir meine Liebe zu ihr bewußt, a...
#
#                                                   Hit  \
# 0   Diese Schüler sind ein reines Glück in doppelt...
# 1   Eine reine Freude, wenn er auch mir gegenüber ...
# 2   Wirklich klug und ausgewogen im Urteil, eine r...
# 3   Die Post brachte ein Manuskript von Fritz Behr...
# 4   Las mit Freude den Roman von Inge Wangenheim ü...
# ..                                                ...
# 95          vor drei Monaten eitel Freude geherrscht.
# 96  Habe viel Freude au der Zusammenstellung alter...
# 97  Nachdem die ""Berliner Zeitung"" eine von ihr ...
# 98           Meine Mutter hätte gesagt* Freud, Freud!
# 99           Meine Mutter hätte gesagt* Freud, Freud!
#
#                                          ContextAfter
# 0   Natürlich kann man einiges vermitteln, aber sc...
# 1   Rührend auch seine Frau, die mir 3 Zigarren sc...
# 2                                              3.2.57
# 3   Heute die Besprechung von Abels Buch (19 Seite...
# 4             Lese jetzt die Erinnerungen von Leyden.
# ..                                                ...
# 95  Die Rull-Serie des neuesten Roboters Rr. 1111 ...
# 96  Aber von einem ganz neu zu schreibenden Buch i...
# 97  Sie brachten dann auch letzte Woche die Bespre...
# 98  Sodann hat mich Erich, nachdem ich ihm einen D...
# 99  Sodann hat mich Erich, nachdem ich ihm einen D...
#
# [100 rows x 8 columns]

# %%
zeitungskorpora_wut = pd.read_csv("Berliner_Zeitung_94-05_Wut.tsv", sep='\t')
zeitungskorpora_wut
# Out:
#     No.        Date    Genre                          Bibl  URL  \
# 0     1  2005-12-31  Zeitung  Berliner Zeitung, 31.12.2005  NaN
# 1     2  2005-12-28  Zeitung  Berliner Zeitung, 28.12.2005  NaN
# 2     3  2005-12-27  Zeitung  Berliner Zeitung, 27.12.2005  NaN
# 3     4  2005-12-27  Zeitung  Berliner Zeitung, 27.12.2005  NaN
# 4     5  2005-12-24  Zeitung  Berliner Zeitung, 24.12.2005  NaN
# ..  ...         ...      ...                           ...  ...
# 95   96  2005-09-20  Zeitung  Berliner Zeitung, 20.09.2005  NaN
# 96   97  2005-09-20  Zeitung  Berliner Zeitung, 20.09.2005  NaN
# 97   98  2005-09-20  Zeitung  Berliner Zeitung, 20.09.2005  NaN
# 98   99  2005-09-17  Zeitung  Berliner Zeitung, 17.09.2005  NaN
# 99  100  2005-09-15  Zeitung  Berliner Zeitung, 15.09.2005  NaN
#
#                                         ContextBefore  \
# 0   Nun hat er einen Kleist am Deutschen Theater v...
# 1   Er jedoch weigert sich nun schon seit Ewigkeit...
# 2                            Und um das Weitermachen.
# 3   Bezeichnenderweise waren die Platten von Comet...
# 4   Der Pfleger nahm sie ihm weg - sie hatte zuges...
# ..                                                ...
# 95  Er gab den Parteivorsitz ab, verlegte den Wahl...
# 96                    Reisen muss dagegen der Gegner.
# 97  Ich glaube, die Verunsicherung der Menschen sp...
# 98  Vorher aber soll die Ukraine den Verdruss der ...
# 99      1997 kehrt er zu Besuch nach Rumänien zurück.
#
#                                                   Hit  \
# 0   Jetzt könnte es losgehen, aber mit Lust und Kr...
# 1   Amedeo Carboni vom FC Valencia, 18 Mal italien...
# 2   Da ist Wut auf jeden Fall die bessere Antriebs...
# 3   Jetzt aber weisen sie einen gehörigen Biss auf...
# 4                                      Wut bei Kalle.
# ..                                                ...
# 95  Die Politik indessen, der doch die Wut vieler ...
# 96  Die Türken werden mit viel Wut im Bauch hier a...
# 97  In Ihrer Partei wächst die Wut über die schlec...
# 98  Wir müssen mit Wut im Bauch gegen die Ukraine ...
# 99  Mit seinem ""Buch der Wut"" hat er das Selbstp...
#
#                                          ContextAfter
# 0                     ----------------------------- -
# 1                         Und hier ist er immer noch.
# 2   Auf diese Weise haben Comet Gain nun das wohl ...
# 3                             Die Faust in der Tasche
# 4        Kurz darauf kam die Seltersflasche geflogen.
# ..                                                ...
# 95  Das einzig Imponierende war Schröders geradezu...
# 96  Der Coach weiß, dass die meisten der deutschen...
# 97  Zu der nötigen Debatte um die Ursachen kann je...
# 98  Zweifellos ist das eine bessere Gelegenheit al...
# 99                            Heute, 15. 9. um 21 Uhr
#
# [100 rows x 8 columns]

# %%
webkorpora_wut = pd.read_csv("Webkorpora_Blogs_95-14_Wut.tsv", sep='\t')
webkorpora_wut
# Out:
#     No.        Date            Genre  \
# 0     1  2003-06-09  internetbasiert
# 1     2  2003-06-30  internetbasiert
# 2     3  2003-06-30  internetbasiert
# 3     4  2003-06-30  internetbasiert
# 4     5  2003-06-30  internetbasiert
# ..  ...         ...              ...
# 95   96  2007-06-10  internetbasiert
# 96   97  2007-06-15  internetbasiert
# 97   98  2007-06-19  internetbasiert
# 98   99  2007-06-19  internetbasiert
# 99  100  2007-06-26  internetbasiert
#
#                                                  Bibl  \
# 0      kaliban.org Jun 9 2003. kaliban.de, 2003-06-09
# 1                   Juni 2003. kaliban.de, 2003-06-30
# 2                   Juni 2003. kaliban.de, 2003-06-30
# 3                   Juni 2003. kaliban.de, 2003-06-30
# 4     kaliban.org Jun 30 2003. kaliban.de, 2003-06-30
# ..                                                ...
# 95  NS-Bewältigung. Philologisches Klo - Archiv, 2...
# 96  Zu verkaufen. Taking detours to the MArrow, 20...
# 97  Transgenialer CSD in Berlin. Fachschaftsinitia...
# 98  Transgenialer CSD in Berlin. Fachschaftsinitia...
# 99  Nicht der schwarze Mann im Dunkeln. Somlus Wel...
#
#                                                   URL  \
# 0   http://kaliban.de/2003/06/kaliban-org-Jun-9-2003/
# 1                          http://kaliban.de/2003/06/
# 2                          http://kaliban.de/2003/06/
# 3                          http://kaliban.de/2003/06/
# 4   http://kaliban.de/2003/06/kaliban-org-Jun-30-2...
# ..                                                ...
# 95  http://philolog.wordpress.com/2007/06/10/ns-be...
# 96  http://marrow.wordpress.com/2007/06/15/zu-verk...
# 97  http://genderini.wordpress.com/2007/06/19/tran...
# 98  http://genderini.wordpress.com/2007/06/19/tran...
# 99  http://somluswelt.wordpress.com/2007/06/26/nic...
#
#                                         ContextBefore  \
# 0                        Wo versank die welsche Brut?
# 1   Wie in deinem Computerspiel Feinde hast du nie...
# 2   Das ist deine Realität Wie in deinem Computers...
# 3   Es ist deine Realität Wie in deinem Computersp...
# 4   Wie in deinem Computerspiel Feinde hast du nie...
# ..                                                ...
# 95                           und das Ende vom Anfang?
# 96  Mein Stolz hat mich angerufen und mir Bescheid...
# 97                        10 Jahre Transgenialer CSD.
# 98                 Und bezahlt wird immer noch nicht.
# 99                   Der Eigenausdruck wird geopfert.
#
#                                                   Hit  \
# 0   In Niedersachsens Bergen, An Niedersachsens Wu...
# 1   Mehr Waffen Mehr Feinde Mehr Levels Mehr Detai...
# 2   Mehr Waffen Mehr Feinde Mehr Levels Mehr Detai...
# 3   Mehr Waffen Mehr Feinde Mehr Levels Mehr Detai...
# 4   Mehr Waffen Mehr Feinde Mehr Levels Mehr Detai...
# ..                                                ...
# 95  ich würde sagen mit einem lauten Knall und nat...
# 96  Nach dem er sich vor anderthalb Wochen mit ein...
# 97       Was mit Schlamm begann, geht mit Wut weiter.
# 98              Tragt die Wut mit uns auf die Straße.
# 99  Das erzeugt Wut und Hass, der sich häufig genu...
#
#                                          ContextAfter
# 0     Wer hielt Freiheit hoch Im deutschen Vaterland?
# 1   Mehr Waffen Mehr Feinde Mehr Levels Mehr Detai...
# 2   Mehr Waffen Mehr Feinde Mehr Levels Mehr Detai...
# 3   Mehr Waffen Mehr Feinde Mehr Levels Mehr Detai...
# 4   Mehr Waffen Mehr Feinde Mehr Levels Mehr Detai...
# ..                                                ...
# 95                              …==>Tätergesellschaft
# 96              Aber die war nicht da, die blöde Kuh.
# 97                       Und wir sind richtig wütend!
# 98  Lasst uns lieben, lachen, kämpfen für queere S...
# 99         Die letztere Formulierung ist mir wichtig.
#
# [100 rows x 8 columns]

# %%
metakorpora_wut = pd.read_csv("Metakorpora_DTA_Wut.tsv", sep='\t')
metakorpora_wut
# Out:
#     No. Corpus  Date               Genre  \
# 0     1   dtae  1987  Gebrauchsliteratur
# 1     2   dtae  1987  Gebrauchsliteratur
# 2     3   dtae  1987  Gebrauchsliteratur
# 3     4   dtae  1987  Gebrauchsliteratur
# 4     5   dtae  1987  Gebrauchsliteratur
# ..  ...    ...   ...                 ...
# 95   96   dtae  1914        Belletristik
# 96   97   dtae  1914        Belletristik
# 97   98   dtae  1914        Belletristik
# 98   99   dtae  1914        Belletristik
# 99  100   dtae  1914        Belletristik
#
#                                            Bibl  \
# 0    Kuczynski, Jürgen: Tagebuch. Berlin, 1987.
# 1    Kuczynski, Jürgen: Tagebuch. Berlin, 1987.
# 2    Kuczynski, Jürgen: Tagebuch. Berlin, 1987.
# 3    Kuczynski, Jürgen: Tagebuch. Berlin, 1987.
# 4    Kuczynski, Jürgen: Tagebuch. Berlin, 1987.
# ..                                          ...
# 95  Bahr, Hermann: Der Querulant. Berlin, 1914.
# 96  Bahr, Hermann: Der Querulant. Berlin, 1914.
# 97  Bahr, Hermann: Der Querulant. Berlin, 1914.
# 98  Bahr, Hermann: Der Querulant. Berlin, 1914.
# 99  Bahr, Hermann: Der Querulant. Berlin, 1914.
#
#                                         ContextBefore  \
# 0   Studien zur Geschichte der Weltwirtschaft"" in...
# 1   Die Stimmung an der Akademie ist fürchterlich ...
# 2   Aber die Ohne daß ich das schon schreibe, glau...
# 3   Eine Schande für die Parteiführung - und ln 3 ...
# 4        Man wußte noch nicht recht, was mit ihm war.
# ..                                                ...
# 95                                        Mei Freund!
# 96                                  I hab was für di!
# 97                                   Da schaust, was?
# 98           (Er hält ihm den Teller unter die Nase.)
# 99                         Was is denn nur g'scheg'n?
#
#                                                   Hit  \
# 0   Man versteht auoh die alten Berichte der Orden...
# 1   Fritz trinkt wieder stärker, andere sind bitte...
# 2   wie meine Lust nach meinem süßen Nachtisch ein...
# 3   Weniger Hirasen, weniger Heuchelei, mehr Selbs...
# 4   Er erzählte mir, er hätte gerade wieder von ei...
# ..                                                ...
# 95  (Will auf ihn zu.) Straßer (zuckt bei dem Wort...
# 96  Straßer (sich vor Wut aufblähend, krähend, noc...
# 97     Straßer (stößt Hias weg; mit verbissener Wut).
# 98  Straßer (unwillkürlich gierig nach dem Speck s...
# 99  Straßer (kann vor Wut nicht sprechen, schüttel...
#
#                                          ContextAfter
# 0                                         9 * Oktober
# 1   Lese Simone de Beauvoir Les Mandarins, das mir...
# 2   An diesen habe Ich jeden- Wissenschaft von der...
# 3   Zugleich zeigt sich immer wieder, wie unser Po...
# 4   Natürlich habe ich nichts davon in der SU zu s...
# ..                                                ...
# 95                                              Hähä!
# 96                                              Hähä!
# 97                              B'halt da dein Speck!
# 98                           I brauch dein Speck nöt!
# 99                                              Hähä!
#
# [100 rows x 8 columns]

# %%
zeitungskorpora_freude.to_excel('zeitungskorpora_freude.xlsx')
webkorpora_freude.to_excel('webkorpora_freude.xlsx')
metakorpora_freude.to_excel('metakorpora_freude.xlsx')
zeitungskorpora_wut.to_excel('zeitungskorpora_wut.xlsx')
webkorpora_wut.to_excel('webkorpora_wut.xlsx')
metakorpora_wut.to_excel('metakorpora_wut.xlsx')

# %%
import pandas as pd

zeitungskorpora_freude = pd.read_excel('zeitungskorpora_freude.xlsx')
webkorpora_freude = pd.read_excel('webkorpora_freude.xlsx')
metakorpora_freude = pd.read_excel('metakorpora_freude.xlsx')
zeitungskorpora_wut = pd.read_excel('zeitungskorpora_wut.xlsx')
webkorpora_wut = pd.read_excel('webkorpora_wut.xlsx')
metakorpora_wut = pd.read_excel('metakorpora_wut.xlsx')

# %%
print(zeitungskorpora_freude.columns)
# Out:
# Index(['Unnamed: 0', 'No.', 'Date', 'Genre', 'Bibl', 'URL', 'ContextBefore',
#        'Hit', 'ContextAfter'],
#       dtype='object')

# %%
zeitungskorpora_freude['full_text'] = zeitungskorpora_freude['ContextBefore'] + ' ' + zeitungskorpora_freude['Hit'] + ' ' + zeitungskorpora_freude['ContextAfter']
webkorpora_freude['full_text'] = webkorpora_freude['ContextBefore'] + ' ' + webkorpora_freude['Hit'] + ' ' + webkorpora_freude['ContextAfter']
metakorpora_freude['full_text'] = metakorpora_freude['ContextBefore'] + ' ' + metakorpora_freude['Hit'] + ' ' + metakorpora_freude['ContextAfter']

zeitungskorpora_wut['full_text'] = zeitungskorpora_wut['ContextBefore'] + ' ' + zeitungskorpora_wut['Hit'] + ' ' + zeitungskorpora_wut['ContextAfter']
webkorpora_wut['full_text'] = webkorpora_wut['ContextBefore'] + ' ' + webkorpora_wut['Hit'] + ' ' + webkorpora_wut['ContextAfter']
metakorpora_wut['full_text'] = metakorpora_wut['ContextBefore'] + ' ' + metakorpora_wut['Hit'] + ' ' + metakorpora_wut['ContextAfter']

# %%
print(zeitungskorpora_freude.columns)
# Out:
# Index(['Unnamed: 0', 'No.', 'Date', 'Genre', 'Bibl', 'URL', 'ContextBefore',
#        'Hit', 'ContextAfter', 'full_text'],
#       dtype='object')

# %%
import re
import spacy
from nltk.corpus import stopwords

nlp = spacy.load("de_core_news_sm")

try:
    stop_words = set(stopwords.words('german'))
except LookupError:
    import nltk
    nltk.download('stopwords')
    stop_words = set(stopwords.words('german'))

def clean_text(text):
    if pd.isnull(text):
        return []
    
    text = text.lower() 
    text = re.sub(r'[^a-zäöüß\s]', '', text)
    
    doc = nlp(text)
    
    tokens = [token.text for token in doc if token.text not in stop_words and token.text.strip() != '' and not token.is_punct]

    return tokens

# Przykład zastosowania na korpusie
zeitungskorpora_freude['tokens'] = zeitungskorpora_freude['full_text'].apply(clean_text)
# webkorpora_freude['tokens'] = webkorpora_freude['full_text'].apply(clean_text)
# metakorpora_freude['tokens'] = metakorpora_freude['full_text'].apply(clean_text)
# zeitungskorpora_wut['tokens'] = zeitungskorpora_wut['full_text'].apply(clean_text)
# webkorpora_wut['tokens'] = webkorpora_wut['full_text'].apply(clean_text)
# metakorpora_wut['tokens'] = metakorpora_wut['full_text'].apply(clean_text)
print(zeitungskorpora_freude['tokens'].head())
# Out:
# 0    [sehen, freude, macht, schritt, schritt, voran...
# 1    [ganze, deutsche, eislauffamilie, weiß, angesi...
# 2                                                   []
# 3    [motivation, freude, springen, sagt, martin, s...
# 4    [sehen, freude, macht, schritt, schritt, voran...
# Name: tokens, dtype: object

# %%
zeitungskorpora_freude['tokens'] = zeitungskorpora_freude['full_text'].apply(clean_text)
webkorpora_freude['tokens'] = webkorpora_freude['full_text'].apply(clean_text)
metakorpora_freude['tokens'] = metakorpora_freude['full_text'].apply(clean_text)

zeitungskorpora_wut['tokens'] = zeitungskorpora_wut['full_text'].apply(clean_text)
webkorpora_wut['tokens'] = webkorpora_wut['full_text'].apply(clean_text)
metakorpora_wut['tokens'] = metakorpora_wut['full_text'].apply(clean_text)

# %%
zeitungskorpora_freude.to_excel('zeitungskorpora_freude_cleaned.xlsx', index=False)
webkorpora_freude.to_excel('webkorpora_freude_cleaned.xlsx', index=False)
metakorpora_freude.to_excel('metakorpora_freude_cleaned.xlsx', index=False)

zeitungskorpora_wut.to_excel('zeitungskorpora_wut_cleaned.xlsx', index=False)
webkorpora_wut.to_excel('webkorpora_wut_cleaned.xlsx', index=False)
metakorpora_wut.to_excel('metakorpora_wut_cleaned.xlsx', index=False)

# %% [markdown]
# collocation analysis

# %%
from collections import Counter

def find_collocations(tokenized_sentences, target_word, window=5):
    collocations = []
    
    for sentence in tokenized_sentences:
        for i, token in enumerate(sentence):
            if token == target_word:
                start = max(0, i - window)
                end = min(len(sentence), i + window + 1)
                collocations.extend(sentence[start:i] + sentence[i+1:end])
    
    return collocations

freude_collocations_zeitung = find_collocations(zeitungskorpora_freude['tokens'].tolist(), 'freude')
wut_collocations_zeitung = find_collocations(zeitungskorpora_wut['tokens'].tolist(), 'wut')

freude_collocations_web = find_collocations(webkorpora_freude['tokens'].tolist(), 'freude')
wut_collocations_web = find_collocations(webkorpora_wut['tokens'].tolist(), 'wut')

freude_collocations_meta = find_collocations(metakorpora_freude['tokens'].tolist(), 'freude')
wut_collocations_meta = find_collocations(metakorpora_wut['tokens'].tolist(), 'wut')

# Zliczanie najczęstszych kolokacji dla każdego korpusu
freude_counter_zeitung = Counter(freude_collocations_zeitung)
wut_counter_zeitung = Counter(wut_collocations_zeitung)

freude_counter_web = Counter(freude_collocations_web)
wut_counter_web = Counter(wut_collocations_web)

freude_counter_meta = Counter(freude_collocations_meta)
wut_counter_meta = Counter(wut_collocations_meta)

print("========== Freude - Zeitung (10 Most frequent collocations) ==========")
print(freude_counter_zeitung.most_common(10))
print()

print("========== Wut - Zeitung (10 Most frequent collocations) ==========")
print(wut_counter_zeitung.most_common(10))
print()

print("========== Freude - Web (10 Most frequent collocations) ==========")
print(freude_counter_web.most_common(10))
print()

print("========== Wut - Web (10 Most frequent collocations) ==========")
print(wut_counter_web.most_common(10))
print()

print("========== Freude - Meta (10 Most frequent collocations) ==========")
print(freude_counter_meta.most_common(10))
print()

print("========== Wut - Meta (10 Most frequent collocations) ==========")
print(wut_counter_meta.most_common(10))
# Out:
# ========== Freude - Zeitung (10 Most frequent collocations) ==========
# [('gerne', 5), ('grund', 5), ('vielleicht', 5), ('schritt', 4), ('sagt', 4), ('große', 4), ('sagte', 4), ('wissen', 4), ('lässt', 4), ('mitreißen', 4)]
#
# ========== Wut - Zeitung (10 Most frequent collocations) ==========
# [('wut', 8), ('wurde', 6), ('scham', 6), ('angst', 5), ('mehr', 5), ('sagte', 5), ('deren', 5), ('sei', 4), ('ja', 4), ('lässt', 4)]
#
# ========== Freude - Web (10 Most frequent collocations) ==========
# [('immer', 7), ('daran', 4), ('unbändige', 4), ('neuen', 4), ('leserinnen', 4), ('leben', 4), ('hätte', 4), ('gehabt', 4), ('groß', 4), ('wenig', 4)]
#
# ========== Wut - Web (10 Most frequent collocations) ==========
# [('mehr', 26), ('angst', 9), ('wirklich', 8), ('ganze', 8), ('gut', 7), ('levels', 6), ('details', 6), ('blut', 6), ('spiel', 6), ('immer', 6)]
#
# ========== Freude - Meta (10 Most frequent collocations) ==========
# [('große', 17), ('großer', 16), ('immer', 14), ('reine', 12), ('ganz', 11), ('sehen', 9), ('genossen', 8), ('arbeit', 7), ('gestern', 6), ('las', 6)]
#
# ========== Wut - Meta (10 Most frequent collocations) ==========
# [('angst', 10), ('immer', 10), ('schon', 8), ('zorn', 6), ('gar', 6), ('sehen', 5), ('darin', 4), ('ja', 4), ('haß', 4), ('reine', 4)]

# %%
import pandas as pd
import spacy

nlp = spacy.load("de_core_news_sm")

zeitungskorpora_freude = pd.read_excel('zeitungskorpora_freude_cleaned.xlsx')
webkorpora_freude = pd.read_excel('webkorpora_freude_cleaned.xlsx')
metakorpora_freude = pd.read_excel('metakorpora_freude_cleaned.xlsx')

zeitungskorpora_wut = pd.read_excel('zeitungskorpora_wut_cleaned.xlsx')
webkorpora_wut = pd.read_excel('webkorpora_wut_cleaned.xlsx')
metakorpora_wut = pd.read_excel('metakorpora_wut_cleaned.xlsx')

zeitungskorpora_freude_cleaned = zeitungskorpora_freude.dropna(subset=['full_text'])
webkorpora_freude_cleaned = webkorpora_freude.dropna(subset=['full_text'])
metakorpora_freude_cleaned = metakorpora_freude.dropna(subset=['full_text'])

zeitungskorpora_wut_cleaned = zeitungskorpora_wut.dropna(subset=['full_text'])
webkorpora_wut_cleaned = webkorpora_wut.dropna(subset=['full_text'])
metakorpora_wut_cleaned = metakorpora_wut.dropna(subset=['full_text'])

def analysiere_syntax(texts):
    """
    Führt eine syntaktische Analyse durch und gibt grammatikalische Abhängigkeiten zurück.
    """
    doc = nlp(texts)
    satz_strukturen = []

    for sent in doc.sents:
        struktur = []
        for token in sent:
            struktur.append((token.text, token.dep_, token.head.text))
        satz_strukturen.append(struktur)

    return satz_strukturen

def analysiere_korpus(df, korpus_name):
    print(f"\n=== Analyse für: {korpus_name} ===")

    for idx, row in df.iterrows():
        text = row['full_text']
        if isinstance(text, str) and text.strip():
            ergebnis = analysiere_syntax(text)
            print(f"\n→ Satzstruktur für Dokument {idx+1}:")
            for satz in ergebnis:
                print(satz)
        else:
            print(f"\n⚠️ Leerer oder ungültiger Text in Zeile {idx+1}")

analysiere_korpus(zeitungskorpora_freude_cleaned, "Zeitung – Freude")
analysiere_korpus(webkorpora_freude_cleaned, "Web – Freude")
analysiere_korpus(metakorpora_freude_cleaned, "Metakorpus – Freude")

analysiere_korpus(zeitungskorpora_wut_cleaned, "Zeitung – Wut")
analysiere_korpus(webkorpora_wut_cleaned, "Web – Wut")
analysiere_korpus(metakorpora_wut_cleaned, "Metakorpus – Wut")
# Out:
# === Analyse für: Zeitung – Freude ===
#
# → Satzstruktur für Dokument 1:
# [('Sie', 'sb', 'werden'), ('werden', 'ROOT', 'werden'), ('sehen', 'oc', 'werden'), (',', 'punct', 'sehen'), ('wie', 'mo', 'macht'), ('viel', 'nk', 'Freude'), ('Freude', 'sb', 'macht'), ('es', 'sb', 'macht'), ('macht', 'oc', 'sehen'), (',', 'punct', 'macht'), ('wenn', 'cp', 'geht'), ('man', 'sb', 'geht'), ('Schritt', 'oa', 'geht'), ('für', 'mnr', 'Schritt'), ('Schritt', 'nk', 'für'), ('voran', 'mo', 'geht'), ('geht', 'mo', 'macht'), ('.', 'punct', 'werden')]
# [('"', 'ROOT', '"')]
# [('"', 'ROOT', '"')]
#
# → Satzstruktur für Dokument 2:
# [('Die', 'nk', 'Eislauf-Familie'), ('ganze', 'nk', 'Eislauf-Familie'), ('deutsche', 'nk', 'Eislauf-Familie'), ('Eislauf-Familie', 'sb', 'weiß'), ('weiß', 'ROOT', 'weiß'), ('sich', 'oa', 'weiß'), ('angesichts', 'mo', 'weiß'), ('des', 'nk', 'Dokuments'), ('kleinen', 'nk', 'Dokuments'), (',', 'punct', 'kleinen'), ('roten', 'cj', 'kleinen'), ('Dokuments', 'nk', 'angesichts'), ('mit', 'mnr', 'Dokuments'), ('Bundesadler', 'nk', 'mit'), ('vor', 'mo', 'weiß'), ('Freude', 'nk', 'vor'), ('kaum', 'mo', 'fassen'), ('zu', 'pm', 'fassen'), ('fassen', 'oc', 'weiß'), (',', 'punct', 'weiß'), ('doch', 'cd', 'weiß'), ('er', 'sb', 'beantwortet'), ('beantwortet', 'cj', 'doch'), ('die', 'nk', 'Frage'), ('Frage', 'oa', 'beantwortet'), (',', 'punct', 'Frage'), ('was', 'sb', 'werde'), ('sich', 'oa', 'ändern'), ('nach', 'mo', 'ändern'), ('der', 'nk', 'Einbürgerung'), ('Einbürgerung', 'nk', 'nach'), ('seiner', 'nk', 'Partnerin'), ('Partnerin', 'ag', 'Einbürgerung'), ('Aljona', 'pnc', 'Sawtschenko'), ('Sawtschenko', 'nk', 'Partnerin'), ('ändern', 'oc', 'werde'), ('werde', 'oc', 'Frage'), (',', 'punct', 'werde'), ('mit', 'mo', 'beantwortet'), ('den', 'nk', 'Worten'), ('Worten', 'nk', 'mit'), (':', 'punct', 'beantwortet')]
#
# → Satzstruktur für Dokument 4:
# [(' ', 'dep', ' ')]
# [('Meine', 'nk', 'Motivation'), ('Motivation', 'pd', 'ist'), ('ist', 'oc', 'sagt'), ('die', 'nk', 'Freude'), ('Freude', 'sb', 'ist'), ('am', 'mnr', 'Freude'), ('Springen', 'nk', 'am'), ('"', 'punct', 'ist'), ('"', 'punct', 'ist'), (',', 'punct', 'sagt'), ('sagt', 'ROOT', 'sagt'), ('Martin', 'pnc', 'Schmitt'), ('Schmitt', 'sb', 'sagt'), (':', 'punct', 'sagt')]
#
# → Satzstruktur für Dokument 5:
# [(' ', 'dep', ' ')]
# [('Sie', 'sb', 'werden'), ('werden', 'ROOT', 'werden'), ('sehen', 'oc', 'werden'), (',', 'punct', 'sehen'), ('wie', 'mo', 'macht'), ('viel', 'nk', 'Freude'), ('Freude', 'sb', 'macht'), ('es', 'sb', 'macht'), ('macht', 'oc', 'sehen'), (',', 'punct', 'macht'), ('wenn', 'cp', 'geht'), ('man', 'sb', 'geht'), ('Schritt', 'oa', 'geht'), ('für', 'mnr', 'Schritt'), ('Schritt', 'nk', 'für'), ('voran', 'mo', 'geht'), ('geht', 'mo', 'macht'), ('.', 'punct', 'werden')]
# [('"', 'ROOT', '"')]
# [('"', 'ROOT', '"')]
#
# → Satzstruktur für Dokument 6:
# [('Es', 'ep', 'gibt'), ('gibt', 'ROOT', 'gibt'), ('bei', 'mo', 'gibt'), ('Heiner', 'pnc', 'Müller'), ('Müller', 'nk', 'bei'), ('auch', 'mo', 'gibt'), ('so', 'mo', 'etwas'), ('etwas', 'oa', 'gibt'), ('wie', 'cm', 'Vergnügen'), ('das', 'nk', 'Vergnügen'), ('Vergnügen', 'cc', 'etwas'), ('am', 'mnr', 'Vergnügen'), ('Bösen', 'nk', 'am'), (',', 'punct', 'gibt'), ('die', 'nk', 'Freude'), ('Freude', 'cj', 'gibt'), (',', 'punct', 'Freude'), ('es', 'oa', 'anschauen'), ('anschauen', 'oc', 'Freude'), (',', 'punct', 'anschauen'), ('es', 'oa', 'porträtieren'), ('porträtieren', 'oc', 'können'), ('zu', 'pm', 'können'), ('können', 're', 'es'), (',', 'punct', 'gibt'), ('eine', 'nk', 'Faszination'), ('eigentümliche', 'nk', 'Faszination'), ('Faszination', 'oa', 'gibt'), (',', 'punct', 'Faszination'), ('ohne', 'cp', 'ist'), ('die', 'nk', 'Erkenntnis'), ('Erkenntnis', 'sb', 'ist'), ('nicht', 'ng', 'ist'), ('möglich', 'pd', 'ist'), ('ist', 'rc', 'Faszination'), ('.', 'punct', 'gibt')]
#
# → Satzstruktur für Dokument 7:
# [('In', 'mo', 'steckt'), ('diesem', 'nk', 'Satz'), ('Satz', 'nk', 'In'), ('und', 'cd', 'In'), ('in', 'cj', 'und'), ('dieser', 'nk', 'Freude'), ('Freude', 'nk', 'in'), ('steckt', 'ROOT', 'steckt'), ('der', 'nk', 'Müller'), ('ganze', 'nk', 'Müller'), ('Müller', 'sb', 'steckt'), ('.', 'punct', 'steckt')]
#
# → Satzstruktur für Dokument 8:
# [('Dann', 'mo', 'zugestimmt'), ('hätte', 'ROOT', 'hätte'), ('ich', 'sb', 'hätte'), ('mit', 'mo', 'zugestimmt'), ('Freude', 'nk', 'mit'), ('zugestimmt', 'oc', 'hätte'), (',', 'punct', 'hätte'), ('antwortete', 'nk', 'Marlen'), ('Marlen', 'oa', 'hätte'), (';', 'punct', 'hätte')]
# [('wenn', 'cp', 'wäre'), ('das', 'nk', 'volltags'), ('volltags', 'sb', 'wäre'), ('wäre', 'mo', 'gemacht'), (',', 'punct', 'hätte'), ('hätte', 'oc', 'einstellen'), ('ich', 'sb', 'hätte'), ('das', 'oa', 'gemacht'), ('gerne', 'mo', 'gemacht'), ('gemacht', 'oc', 'hätte'), (',', 'punct', 'können'), ('können', 'ROOT', 'können'), ('Sie', 'sb', 'können'), ('mich', 'oa', 'einstellen'), ('denn', 'mo', 'können'), ('volltags', 'mo', 'einstellen'), ('einstellen', 'oc', 'können'), ('?', 'punct', 'können')]
#
# → Satzstruktur für Dokument 9:
# [('Allein', 'mo', 'Tatsache'), ('die', 'nk', 'Tatsache'), ('Tatsache', 'sb', 'reicht'), (',', 'punct', 'Tatsache'), ('dass', 'cp', 'sind'), ('sie', 'sb', 'sind'), ('womöglich', 'mo', 'geeignet'), ('geeignet', 'pd', 'sind'), ('sind', 'oc', 'Tatsache'), (',', 'punct', 'sind'), ('die', 'nk', 'Freude'), ('Freude', 'sb', 'reicht'), ('und', 'cd', 'Freude'), ('das', 'nk', 'Interesse'), ('Interesse', 'oa', 'fördern'), ('am', 'mnr', 'Interesse'), ('Betriebssport', 'nk', 'am'), ('zu', 'pm', 'fördern'), ('fördern', 'oc', 'Freude'), (',', 'punct', 'reicht'), ('reicht', 'ROOT', 'reicht'), ('für', 'mo', 'reicht'), ('die', 'nk', 'Annahme'), ('Annahme', 'nk', 'für'), ('eines', 'nk', 'Zusammenhangs'), ('inneren', 'nk', 'Zusammenhangs'), ('Zusammenhangs', 'ag', 'Annahme'), ('mit', 'mnr', 'Zusammenhangs'), ('der', 'nk', 'Tätigkeit'), ('versicherten', 'nk', 'Tätigkeit'), ('Tätigkeit', 'nk', 'mit'), ('nicht', 'ng', 'reicht'), ('aus', 'svp', 'reicht'), ('.', 'punct', 'reicht')]
#
# → Satzstruktur für Dokument 10:
# [('Die', 'nk', 'Freude'), ('Freude', 'sb', 'können'), ('der', 'nk', 'Aktionäre'), ('Aktionäre', 'ag', 'Freude'), ('können', 'ROOT', 'können'), ('die', 'nk', 'Arbeitnehmer'), ('Arbeitnehmer', 'sb', 'können'), ('kaum', 'mo', 'können'), ('teilen', 'oc', 'können'), ('.', 'punct', 'können')]
#
# → Satzstruktur für Dokument 11:
# [('Nur', 'mo', 'eins'), ('eins', 'sb', 'bleibt'), ('bleibt', 'dep', 'ist'), ('-', 'punct', 'ist'), ('einsam', 'mo', 'ist'), ('ist', 'ROOT', 'ist'), ('er', 'sb', 'ist'), ('in', 'mo', 'ist'), ('seiner', 'nk', 'Freude'), ('Freude', 'nk', 'in'), ('über', 'op', 'Freude'), ('die', 'nk', 'Wunder'), ('Wunder', 'nk', 'über'), ('.', 'punct', 'ist')]
#
# → Satzstruktur für Dokument 12:
# [('Kinder', 'sb', 'genießen'), ('genießen', 'ROOT', 'genießen'), ('die', 'nk', 'Freuden'), ('Freuden', 'oa', 'genießen'), ('des', 'nk', 'Winters'), ('Winters', 'ag', 'Freuden'), ('.', 'punct', 'genießen')]
#
# → Satzstruktur für Dokument 13:
# [(' ', 'dep', ' ')]
# [('Okay', 'sb', 'stehe'), (',', 'punct', 'stehe'), ('ich', 'sb', 'stehe'), ('stehe', 'ROOT', 'stehe'), ('jetzt', 'mo', 'stehe'), ('nicht', 'ng', 'stehe'), ('mehr', 'mo', 'nicht'), ('regelmäßig', 'mo', 'stehe'), ('in', 'mo', 'stehe'), ('der', 'nk', 'Startelf'), ('Startelf', 'nk', 'in'), (',', 'punct', 'stehe'), ('doch', 'cd', 'stehe'), ('ich', 'sb', 'habe'), ('habe', 'cj', 'doch'), ('noch', 'mo', 'viel'), ('immer', 'mo', 'noch'), ('so', 'mo', 'viel'), ('viel', 'nk', 'Freude'), ('Freude', 'oa', 'habe'), ('am', 'mnr', 'Freude'), ('Beruf', 'nk', 'am'), ('.', 'punct', 'stehe')]
#
# → Satzstruktur für Dokument 14:
# [(' ', 'dep', ' ')]
# [('Wir', 'sb', 'springen'), ('springen', 'ROOT', 'springen'), ('ohne', 'mo', 'springen'), ('Druck', 'nk', 'ohne'), (',', 'punct', 'springen'), ('die', 'nk', 'Mannschaft'), ('Mannschaft', 'sb', 'hat'), ('hat', 'oc', 'springen'), ('Freude', 'oa', 'hat'), ('am', 'mnr', 'Freude'), ('Sport', 'nk', 'am'), ('.', 'punct', 'springen')]
# [('"', 'ROOT', '"')]
# [('"', 'ROOT', '"')]
#
# → Satzstruktur für Dokument 15:
# [(' ', 'dep', ' ')]
# [('Ich', 'sb', 'bin'), ('bin', 'oc', 'sagt'), ('ein', 'nk', 'Mann'), ('Mann', 'pd', 'bin'), ('der', 'nk', 'Freude'), ('stillen', 'nk', 'Freude'), ('Freude', 'ag', 'Mann'), (' ', 'dep', 'Freude'), (',', 'punct', 'sagt'), ('sagt', 'ROOT', 'sagt'), ('er', 'sb', 'sagt'), ('dann', 'mo', 'sagt'), ('.', 'punct', 'sagt')]
#
# → Satzstruktur für Dokument 16:
# [('Aber', 'ju', 'verbirgt'), ('seine', 'nk', 'Freude'), ('Freude', 'oa', 'verbirgt'), ('verbirgt', 'ROOT', 'verbirgt'), ('er', 'sb', 'verbirgt'), ('gerne', 'mo', 'verbirgt'), ('.', 'punct', 'verbirgt')]
#
# → Satzstruktur für Dokument 17:
# [('Denn', 'ju', 'rufe'), ('offen', 'mo', 'gestellte'), ('zur', 'mo', 'gestellte'), ('Schau', 'nk', 'zur'), ('gestellte', 'nk', 'Freude'), ('Freude', 'sb', 'rufe'), ('rufe', 'ROOT', 'rufe'), ('nur', 'mo', 'Neid'), ('Neid', 'sb', 'rufe'), ('hervor', 'svp', 'rufe'), ('.', 'punct', 'rufe')]
#
# → Satzstruktur für Dokument 18:
# [('Deutlich', 'mo', 'mehr'), ('mehr', 'nk', 'Freude'), ('Freude', 'sb', 'bereitet'), ('bereitet', 'ROOT', 'bereitet'), ('Stolpe', 'sb', 'bereitet'), (',', 'punct', 'Stolpe'), ('der', 'sb', 'war'), ('nie', 'mo', 'war'), ('ein', 'nk', 'Parteimensch'), ('Parteimensch', 'pd', 'war'), ('war', 'rc', 'Stolpe'), (',', 'punct', 'war'), ('die', 'nk', 'Koalition'), ('große', 'nk', 'Koalition'), ('Koalition', 'oa', 'bereitet'), ('in', 'mnr', 'Koalition'), ('Berlin', 'nk', 'in'), ('.', 'punct', 'bereitet')]
#
# → Satzstruktur für Dokument 19:
# [('Es', 'sb', 'ist'), ('ist', 'ROOT', 'ist'), ('eine', 'nk', 'Freude'), ('kleine', 'nk', 'Freude'), ('nachweihnachtliche', 'nk', 'Freude'), ('Freude', 'pd', 'ist'), ('.', 'punct', 'ist')]
#
# → Satzstruktur für Dokument 20:
# [(' ', 'dep', ' ')]
# [('Wenn', 'cp', 'pflegen'), ('Sie', 'sb', 'pflegen'), ('die', 'oa', 'pflegen'), ('gut', 'mo', 'pflegen'), ('pflegen', 'mo', 'halten'), (',', 'punct', 'halten'), ('halten', 'ROOT', 'halten'), ('sie', 'sb', 'halten'), ('nicht', 'ng', 'nur'), ('nur', 'mo', 'bis'), ('bis', 'mo', 'halten'), ('Januar', 'nk', 'bis'), (',', 'punct', 'halten'), ('sondern', 'cd', 'halten'), ('sie', 'sb', 'haben'), ('haben', 'cj', 'sondern'), ('bis', 'mo', 'haben'), ('März', 'nk', 'bis'), ('Ihre', 'nk', 'Freude'), ('Freude', 'oa', 'haben'), ('daran', 'mo', 'haben'), ('.', 'punct', 'halten')]
# [('"', 'ROOT', '"')]
# [('"', 'ROOT', '"')]
#
# → Satzstruktur für Dokument 21:
# [('Siehe', 'ROOT', 'Siehe'), (',', 'punct', 'Siehe'), ('ich', 'sb', 'verkündige'), ('verkündige', 'cj', 'Siehe'), ('Euch', 'da', 'verkündige'), ('eine', 'nk', 'Freude'), ('große', 'nk', 'Freude'), ('Freude', 'oa', 'verkündige'), (',', 'punct', 'Freude'), ('die', 'sb', 'wird'), ('allem', 'nk', 'Volk'), ('Volk', 'oa', 'widerfahren'), ('widerfahren', 'oc', 'wird'), ('wird', 'rc', 'Freude'), (':', 'punct', 'Siehe')]
#
# → Satzstruktur für Dokument 22:
# [('So', 'mo', 'zieht'), ('zieht', 'ROOT', 'zieht'), ('denn', 'mo', 'zieht'), ('alle', 'nk', 'Jahre'), ('Jahre', 'sb', 'zieht'), ('wieder', 'mo', 'zieht'), ('Freude', 'oa', 'zieht'), ('ein', 'svp', 'zieht'), ('in', 'mo', 'zieht'), ('jedes', 'nk', 'Haus'), ('Haus', 'nk', 'in'), (',', 'punct', 'zieht'), ('wenn', 'cp', 'wird'), ('im', 'mo', 'gegriffen'), ('Glanz', 'nk', 'im'), ('des', 'nk', 'Lichterbaumes'), ('Lichterbaumes', 'ag', 'Glanz'), ('zur', 'mo', 'gegriffen'), ('Fernbedienung', 'nk', 'zur'), ('gegriffen', 'oc', 'wird'), ('wird', 'mo', 'zieht'), ('.', 'punct', 'zieht')]
#
# → Satzstruktur für Dokument 23:
# [('Blonde', 'mo', 'gab'), ('Freude', 'nk', 'Blonde'), ('gab', 'ROOT', 'gab'), ('es', 'ep', 'gab'), ('wieder', 'mo', 'gab'), ('einmal', 'mo', 'gab'), ('in', 'mo', 'gab'), ('den', 'nk', 'Niederlanden'), ('Niederlanden', 'nk', 'in'), (':', 'punct', 'gab')]
#
# → Satzstruktur für Dokument 24:
# [('Wenn', 'cp', 'tun'), ('die', 'nk', 'Gemeindemitglieder'), ('Gemeindemitglieder', 'sb', 'tun'), ('der', 'nk', 'Kirche'), ('evangelischen', 'nk', 'Kirche'), ('Kirche', 'ag', 'Gemeindemitglieder'), ('in', 'mnr', 'Kirche'), ('Schafstädt', 'nk', 'in'), (',', 'punct', 'Schafstädt'), ('Sachsen-Anhalt', 'cj', 'Schafstädt'), (',', 'punct', 'tun'), ('also', 'mo', 'heute'), ('ausgerechnet', 'mo', 'heute'), ('heute', 'mo', 'tun'), (',', 'punct', 'heute'), ('am', 'mo', 'müssen'), ('Heiligen', 'nk', 'Abend'), ('Abend', 'nk', 'am'), (',', 'punct', 'müssen'), ('auf', 'op', 'verzichten'), ('ihre', 'nk', 'Orgel'), ('Orgel', 'nk', 'auf'), ('verzichten', 'oc', 'müssen'), ('müssen', 're', 'heute'), (',', 'punct', 'tun'), ('tun', 'ROOT', 'tun'), ('sie', 'sb', 'tun'), ('das', 'oa', 'tun'), ('mit', 'mo', 'tun'), ('Freuden', 'nk', 'mit'), ('.', 'punct', 'tun')]
#
# → Satzstruktur für Dokument 25:
# [('Ich', 'sb', 'möchte'), ('möchte', 'ROOT', 'möchte'), ('mit', 'mo', 'lachen'), ('ihnen', 'nk', 'mit'), ('lachen', 'oc', 'möchte'), (',', 'punct', 'lachen'), ('mit', 'mo', 'weinen'), ('ihnen', 'nk', 'mit'), ('weinen', 'oc', 'lachen'), (',', 'punct', 'weinen'), ('sie', 'sb', 'begleiten'), ('durch', 'mo', 'begleiten'), ('all', 'nk', 'Sorgen'), ('die', 'nk', 'Sorgen'), ('kleinen', 'nk', 'Sorgen'), ('Sorgen', 'nk', 'durch'), ('und', 'cd', 'Sorgen'), ('Freuden', 'cj', 'und'), ('des', 'nk', 'Alltags'), ('Alltags', 'ag', 'Freuden'), ('begleiten', 'oc', 'weinen'), ('.', 'punct', 'möchte')]
#
# → Satzstruktur für Dokument 26:
# [(' ', 'dep', ' ')]
# [('Wir', 'sb', 'haben'), ('haben', 'oc', 'sagte'), ('laufend', 'mo', 'haben'), ('Meldungen', 'oa', 'haben'), ('über', 'mnr', 'Meldungen'), ('Wölfe', 'nk', 'über'), ('"', 'punct', 'haben'), ('"', 'punct', 'haben'), (',', 'punct', 'sagte'), ('sagte', 'ROOT', 'sagte'), ('Matthias', 'pnc', 'Freude'), ('Freude', 'sb', 'sagte'), (',', 'punct', 'Freude'), ('Chef', 'app', 'Freude'), ('des', 'nk', 'Landesumweltamtes'), ('Landesumweltamtes', 'ag', 'Chef'), (',', 'punct', 'sagte'), ('am', 'mo', 'sagte'), ('Freitag', 'nk', 'am'), ('auf', 'mo', 'sagte'), ('Anfrage', 'nk', 'auf'), ('.', 'punct', 'sagte')]
#
# → Satzstruktur für Dokument 27:
# [('Und', 'ju', 'hätten'), ('eine', 'nk', 'Woche'), ('Woche', 'ams', 'zuvor'), ('zuvor', 'mo', 'gesehen'), ('hätten', 're', 'so'), ('ebenfalls', 'mo', 'gesehen'), ('glaubwürdige', 'nk', 'Zeugen'), ('Zeugen', 'sb', 'hätten'), ('auf', 'mnr', 'Zeugen'), ('den', 'nk', 'Landschaftswiesen'), ('Landschaftswiesen', 'nk', 'auf'), ('bei', 'mnr', 'Landschaftswiesen'), ('Belzig', 'nk', 'bei'), ('(', 'punct', 'Potsdam-Mittelmark'), ('Potsdam-Mittelmark', 'app', 'Belzig'), (')', 'punct', 'Potsdam-Mittelmark'), ('einen', 'nk', 'Wolf'), ('sehr', 'mo', 'großen'), ('großen', 'nk', 'Wolf'), ('Wolf', 'oa', 'gesehen'), ('gesehen', 'oc', 'hätten'), (',', 'punct', 'so'), ('so', 'mo', 'Freude'), ('Freude', 'ROOT', 'Freude'), ('.', 'punct', 'Freude')]
#
# → Satzstruktur für Dokument 28:
# [(' ', 'dep', ' ')]
# [('Dort', 'mo', 'festgestellt'), ('habe', 'oc', 'sagte'), ('ich', 'sb', 'habe'), ('selbst', 'mo', 'festgestellt'), ('schon', 'mo', 'mehrmals'), ('mehrmals', 'mo', 'festgestellt'), ('eindeutige', 'nk', 'Wolfsspuren'), ('Wolfsspuren', 'oa', 'festgestellt'), ('festgestellt', 'oc', 'habe'), ('"', 'punct', 'festgestellt'), ('"', 'punct', 'habe'), (',', 'punct', 'sagte'), ('sagte', 'ROOT', 'sagte'), ('Freude', 'sb', 'sagte'), ('.', 'punct', 'sagte')]
#
# → Satzstruktur für Dokument 29:
# [(' ', 'dep', ' ')]
# [('Schließlich', 'mo', 'ist'), ('ist', 're', 'so'), ('der', 'nk', 'Wolf'), ('Wolf', 'sb', 'ist'), ('ein', 'nk', 'Wesen'), ('sehr', 'mo', 'scheues'), ('scheues', 'nk', 'Wesen'), ('Wesen', 'pd', 'ist'), ('"', 'punct', 'Wesen'), ('"', 'punct', 'Wesen'), (',', 'punct', 'so'), ('so', 'mo', 'Freude'), ('Freude', 'ROOT', 'Freude'), ('.', 'punct', 'Freude')]
#
# → Satzstruktur für Dokument 30:
# [('Matthias', 'pnc', 'Freude'), ('Freude', 'sb', 'betonte'), ('betonte', 'ROOT', 'betonte'), (',', 'punct', 'betonte'), ('dass', 'cp', 'können'), ('Wölfe', 'sb', 'können'), ('dem', 'nk', 'Menschen'), ('Menschen', 'da', 'werden'), ('nicht', 'ng', 'können'), ('gefährlich', 'pd', 'werden'), ('werden', 'oc', 'können'), ('können', 'oc', 'betonte'), ('.', 'punct', 'betonte')]
#
# → Satzstruktur für Dokument 31:
# [(' ', 'dep', ' ')]
# [('Seit', 'mo', 'getötet'), ('dem', 'nk', 'Krieg'), ('30-jährigen', 'nk', 'Krieg'), ('Krieg', 'nk', 'Seit'), ('vor', 'mnr', 'Krieg'), ('fast', 'mo', '400'), ('400', 'nk', 'Jahren'), ('Jahren', 'nk', 'vor'), ('hat', 'oc', 'sagte'), ('hier', 'mo', 'getötet'), ('zu', 'mo', 'getötet'), ('Lande', 'nk', 'zu'), ('kein', 'nk', 'Wolf'), ('Wolf', 'mo', 'getötet'), ('mehr', 'mo', 'getötet'), ('einen', 'nk', 'Menschen'), ('Menschen', 'oa', 'getötet'), ('getötet', 'oc', 'hat'), ('"', 'punct', 'hat'), ('"', 'punct', 'hat'), (',', 'punct', 'sagte'), ('sagte', 'ROOT', 'sagte'), ('Freude', 'sb', 'sagte'), ('.', 'punct', 'sagte')]
#
# → Satzstruktur für Dokument 32:
# [('Spötter', 'sb', 'höhnten'), ('höhnten', 'ROOT', 'höhnten'), ('daher', 'mo', 'höhnten'), ('zwar', 'mo', 'höhnten'), ('gern', 'mo', 'höhnten'), ('über', 'mo', 'höhnten'), ('vierrädrige', 'nk', 'Termitenfallen'), ('"', 'punct', 'Termitenfallen'), ('"', 'punct', 'Termitenfallen'), ('Termitenfallen', 'nk', 'über'), ('"', 'punct', 'Termitenfallen'), ('"', 'punct', 'Termitenfallen'), (',', 'punct', 'höhnten'), ('sie', 'sb', 'wurden'), ('wurden', 'cj', 'höhnten'), ('dann', 'mo', 'wurden'), ('aber', 'mo', 'wurden'), ('auch', 'mo', 'flugs'), ('flugs', 'mo', 'als'), ('als', 'mo', 'wurden'), ('Schnäppchenjäger', 'nk', 'als'), ('aktiv', 'pd', 'wurden'), ('und', 'cd', 'wurden'), ('ergatterten', 'cj', 'und'), ('mit', 'mo', 'unansehnliche'), ('Freuden', 'nk', 'mit'), ('unansehnliche', 'nk', 'Woodies'), (',', 'punct', 'unansehnliche'), ('aber', 'cd', 'unansehnliche'), ('mechanisch', 'mo', 'einwandfreie'), ('einwandfreie', 'cj', 'aber'), ('Woodies', 'oa', 'ergatterten'), (',', 'punct', 'Woodies'), ('die', 'sb', 'wechselten'), ('schon', 'mo', 'für'), ('für', 'mo', 'wechselten'), ('läppische', 'mo', 'hundert'), ('hundert', 'nk', 'Dollar'), ('Dollar', 'nk', 'für'), ('den', 'nk', 'Besitzer'), ('Besitzer', 'oa', 'wechselten'), ('wechselten', 'rc', 'Woodies'), ('.', 'punct', 'höhnten')]
#
# → Satzstruktur für Dokument 33:
# [('Manager', 'sb', 'wollte'), ('Uli', 'pnc', 'Hoeneß'), ('Hoeneß', 'nk', 'Manager'), ('wollte', 'ROOT', 'wollte'), ('sich', 'oa', 'einkriegen'), ('gar', 'mo', 'nicht'), ('nicht', 'ng', 'wollte'), ('einkriegen', 'oc', 'wollte'), ('vor', 'mo', 'wollte'), ('Freude', 'nk', 'vor'), (',', 'punct', 'wollte'), ('er', 'sb', 'lachte'), ('lachte', 'cj', 'wollte'), ('und', 'cd', 'lachte'), ('brüllte', 'cj', 'und'), (',', 'punct', 'sprang'), ('sprang', 'cj', 'wollte'), ('und', 'cd', 'sprang'), ('tanzte', 'cj', 'und'), ('und', 'cd', 'sprang'), ('reckte', 'cj', 'und'), ('seine', 'nk', 'Faust'), ('geballte', 'nk', 'Faust'), ('rechte', 'nk', 'Faust'), ('Faust', 'oa', 'reckte'), ('triumphierend', 'mo', 'reckte'), ('Richtung', 'oa', 'sprang'), ('Haupttribüne', 'nk', 'Richtung'), (':', 'punct', 'wollte')]
#
# → Satzstruktur für Dokument 34:
# [('Zwölf', 'nk', 'Kinder'), ('Kinder', 'sb', 'haben'), ('aus', 'mnr', 'Kinder'), ('dem', 'nk', 'Chor'), ('Chor', 'nk', 'aus'), (',', 'punct', 'Kinder'), ('die', 'sb', 'haben'), ('haben', 'ROOT', 'haben'), ('besonders', 'mo', 'viel'), ('viel', 'nk', 'Freude'), ('Freude', 'oa', 'haben'), ('gehabt', 'oc', 'haben'), (',', 'punct', 'haben'), ('und', 'cd', 'haben'), ('zehn', 'nk', 'Mitarbeiter'), ('Mitarbeiter', 'cj', 'und'), ('.', 'punct', 'haben')]
#
# → Satzstruktur für Dokument 35:
# [('Trotz', 'mo', 'darf'), ('all', 'nk', 'Freude'), ('der', 'nk', 'Freude'), ('Freude', 'nk', 'Trotz'), ('unter', 'mnr', 'Freude'), ('den', 'nk', 'Fußballfunktionären'), ('Fußballfunktionären', 'nk', 'unter'), ('und', 'cd', 'Fußballfunktionären'), ('vielen', 'nk', 'Fernsehchefs'), ('Fernsehchefs', 'cj', 'und'), ('darf', 'ROOT', 'darf'), ('allerdings', 'mo', 'darf'), ('die', 'nk', 'Lösung'), ('unbefriedigende', 'nk', 'Lösung'), ('Lösung', 'sb', 'darf'), ('für', 'mnr', 'Lösung'), ('das', 'nk', 'Bezahlfernsehen'), ('Bezahlfernsehen', 'nk', 'für'), ('nicht', 'ng', 'darf'), ('übersehen', 'oc', 'werden'), ('werden', 'oc', 'darf'), ('.', 'punct', 'darf')]
#
# → Satzstruktur für Dokument 37:
# [(' ', 'dep', ' ')]
# [('Die', 'nk', 'Freude'), ('Freude', 'sb', 'ist'), ('ist', 'ROOT', 'ist'), ('sehr', 'mo', 'groß'), ('groß', 'pd', 'ist'), ('bei', 'mo', 'groß'), ('uns', 'nk', 'bei'), ('.', 'punct', 'ist')]
#
# → Satzstruktur für Dokument 38:
# [('Kein', 'nk', 'Wunder'), ('Wunder', 'pd', 'hat'), (',', 'punct', 'hat'), ('dass', 'cp', 'hat'), ('er', 'sb', 'hat'), ('vor', 'mo', 'hat'), ('diesem', 'nk', 'Weihnachtsfest'), ('Weihnachtsfest', 'nk', 'vor'), ('keinen', 'nk', 'Grund'), ('Grund', 'oa', 'hat'), ('zur', 'mnr', 'Grund'), ('Freude', 'nk', 'zur'), ('hat', 'ROOT', 'hat'), ('.', 'punct', 'hat')]
#
# → Satzstruktur für Dokument 39:
# [('Das', 'nk', 'Wort'), ('Wort', 'sb', 'ist'), ('"', 'punct', 'Wort'), ('"', 'punct', 'Wort'), ('endlich', 'mnr', 'Wort'), ('"', 'punct', 'ist'), ('"', 'punct', 'ist'), ('ist', 'ROOT', 'ist'), ('hier', 'mo', 'ist'), ('kein', 'nk', 'Ausdruck'), ('Ausdruck', 'pd', 'ist'), ('von', 'pg', 'Ausdruck'), ('Freude', 'nk', 'von'), (',', 'punct', 'ist'), ('sondern', 'cd', 'ist'), ('steht', 'cj', 'sondern'), ('für', 'mo', 'steht'), ('ein', 'nk', 'Gefühl'), ('tiefes', 'nk', 'Gefühl'), ('Gefühl', 'nk', 'für'), ('von', 'pg', 'Gefühl'), ('Traurigkeit', 'nk', 'von'), ('und', 'cd', 'Traurigkeit'), ('offener', 'nk', 'Sorge'), ('Sorge', 'cj', 'und'), ('.', 'punct', 'ist')]
#
# → Satzstruktur für Dokument 40:
# [('Mit', 'mo', 'geworfen'), ('Glück', 'nk', 'Mit'), ('und', 'cd', 'Glück'), ('Geschick', 'cj', 'und'), ('hat', 'ROOT', 'hat'), ('der', 'nk', 'TSV'), ('TSV', 'sb', 'hat'), ('1860', 'nk', 'München'), ('München', 'oa', 'geworfen'), ('den', 'nk', 'Freiburg'), ('SC', 'pnc', 'Freiburg'), ('Freiburg', 'nk', 'München'), ('im', 'mo', 'geworfen'), ('Zweitliga-Duell', 'nk', 'im'), ('aus', 'mo', 'geworfen'), ('dem', 'nk', 'DFB-Pokal'), ('DFB-Pokal', 'nk', 'aus'), ('geworfen', 'oc', 'hat'), ('und', 'cd', 'geworfen'), ('Trainer', 'cj', 'und'), ('Volker', 'pnc', 'Finke'), ('Finke', 'nk', 'Trainer'), ('die', 'nk', 'Freude'), ('Freude', 'oa', 'verdorben'), ('über', 'mnr', 'Freude'), ('die', 'nk', 'Vertragsverlängerung'), ('Vertragsverlängerung', 'nk', 'über'), ('verdorben', 'oc', 'Trainer'), ('.', 'punct', 'hat')]
#
# → Satzstruktur für Dokument 41:
# [('Die', 'nk', 'Freude'), ('Freude', 'sb', 'stellt'), ('stellt', 'ROOT', 'stellt'), ('sich', 'oa', 'stellt'), ('schon', 'mo', 'stellt'), ('aufgrund', 'mo', 'stellt'), ('der', 'nk', 'Tatsache'), ('Tatsache', 'nk', 'aufgrund'), ('ein', 'svp', 'stellt'), (',', 'punct', 'stellt'), ('dass', 'cp', 'haben'), ('Streisand', 'sb', 'haben'), ('und', 'cd', 'Streisand'), ('Gibb', 'cj', 'und'), ('sich', 'oa', 'versucht'), ('an', 'mo', 'versucht'), ('einer', 'nk', 'Fortsetzung'), ('Fortsetzung', 'nk', 'an'), ('des', 'nk', 'Guilty'), ('wirklich', 'mo', 'großen'), ('großen', 'nk', 'Guilty'), ('"', 'punct', 'Guilty'), ('"', 'punct', 'Guilty'), ('Guilty', 'ag', 'Fortsetzung'), ('"', 'punct', 'Guilty'), ('"', 'punct', 'Guilty'), ('versucht', 'oc', 'haben'), ('haben', 'oc', 'stellt'), ('.', 'punct', 'stellt')]
#
# → Satzstruktur für Dokument 42:
# [('Die', 'nk', 'Freude'), ('Freude', 'sb', 'hatte'), ('der', 'nk', 'Männer'), ('beiden', 'nk', 'Männer'), ('jungen', 'nk', 'Männer'), ('Männer', 'ag', 'Freude'), ('in', 'mnr', 'Freude'), ('der', 'nk', 'Reihe'), ('fünften', 'nk', 'Reihe'), ('Reihe', 'nk', 'in'), ('hatte', 'ROOT', 'hatte'), ('etwas', 'nk', 'Ansteckendes'), ('Ansteckendes', 'oa', 'hatte'), ('.', 'punct', 'hatte')]
#
# → Satzstruktur für Dokument 43:
# [('Auch', 'mo', 'das'), ('das', 'sb', 'kann'), ('kann', 'ROOT', 'kann'), ('ein', 'nk', 'Grund'), ('Grund', 'pd', 'sein'), ('zur', 'mnr', 'Grund'), ('Freude', 'nk', 'zur'), ('sein', 'oc', 'kann'), ('.', 'punct', 'kann')]
#
# → Satzstruktur für Dokument 44:
# [('Grund', 'ROOT', 'Grund'), ('genug', 'nk', 'Grund'), (',', 'punct', 'Grund'), ('ihnen', 'da', 'zukommen'), ('vor', 'mo', 'im'), ('allem', 'nk', 'vor'), ('im', 'mo', 'lassen'), ('Winter', 'nk', 'im'), ('die', 'nk', 'Pflege'), ('richtige', 'nk', 'Pflege'), ('Pflege', 'oa', 'zukommen'), ('zukommen', 'oc', 'lassen'), ('zu', 'pm', 'lassen'), ('lassen', 'oc', 'Grund'), (',', 'punct', 'lassen'), ('damit', 'cp', 'hat'), ('man', 'sb', 'hat'), ('noch', 'mo', 'lange'), ('lange', 'nk', 'Freude'), ('Freude', 'oa', 'hat'), ('an', 'mo', 'hat'), ('ihnen', 'nk', 'an'), ('hat', 'mo', 'lassen'), ('.', 'punct', 'Grund')]
#
# → Satzstruktur für Dokument 46:
# [(' ', 'dep', ' ')]
# [('Halleluja', 'sb', 'sei'), (',', 'punct', 'Halleluja'), ('Gott', 'cj', 'Halleluja'), ('sei', 'ROOT', 'sei'), ('Dank', 'pd', 'sei'), (',', 'punct', 'Dank'), ('welch', 'mo', 'Freude'), ('eine', 'nk', 'Freude'), ('Freude', 'mo', 'sei'), ('und', 'cd', 'Freude'), ('Erleichterung', 'cj', 'und'), ('.', 'punct', 'sei')]
#
# → Satzstruktur für Dokument 47:
# [('Liebe', 'sb', 'zünden'), ('Susanne', 'nk', 'Liebe'), (',', 'punct', 'zünden'), ('wir', 'sb', 'zünden'), ('zünden', 'ROOT', 'zünden'), ('heute', 'mo', 'zünden'), ('Lichter', 'oa', 'zünden'), ('der', 'nk', 'Freude'), ('Freude', 'ag', 'Lichter'), ('an', 'svp', 'zünden'), (',', 'punct', 'zünden'), ('da', 'cp', 'gekommen'), ('Du', 'sb', 'gekommen'), ('frei', 'mo', 'gekommen'), ('gekommen', 'mo', 'zünden'), ('und', 'cd', 'gekommen'), ('unversehrt', 'pd', 'bist'), ('bist', 'cj', 'und'), ('.', 'punct', 'zünden')]
# [('"', 'ROOT', '"')]
# [('"', 'ROOT', '"')]
#
# → Satzstruktur für Dokument 48:
# [(' ', 'dep', 'Das'), ('Das', 'sb', 'ist'), ('ist', 'oc', 'sagt'), ('dann', 'mo', 'ist'), ('so', 'mo', 'ist'), ('eine', 'nk', 'Freude'), ('große', 'nk', 'Freude'), ('Freude', 'pd', 'ist'), (' ', 'dep', 'Freude'), (',', 'punct', 'sagt'), ('sagt', 'ROOT', 'sagt'), ('er', 'sb', 'sagt'), (',', 'punct', 'sagt'), ('"', 'dep', 'sagt'), ('"', 'punct', 'bekommst'), ('wenn', 'cp', 'bekommst'), ('du', 'sb', 'bekommst'), ('plötzlich', 'mo', 'bekommst'), ('diese', 'nk', 'Nachricht'), ('Nachricht', 'oa', 'bekommst'), ('bekommst', 'mo', 'sagt'), ('.', 'punct', 'sagt')]
#
# → Satzstruktur für Dokument 49:
# [('Am', 'mo', 'ließ'), ('Sonntag', 'nk', 'Am'), ('ließ', 'ROOT', 'ließ'), ('der', 'nk', 'Gott'), ('liebe', 'nk', 'Gott'), ('Gott', 'sb', 'ließ'), ('seinen', 'nk', 'Vertreter'), ('irdischen', 'nk', 'Vertreter'), ('Vertreter', 'oa', 'verkünden'), ('Papst', 'pnc', 'Benedikt'), ('Benedikt', 'nk', 'Vertreter'), ('in', 'mo', 'verkünden'), ('Rom', 'nk', 'in'), ('verkünden', 'oc', 'ließ'), (',', 'punct', 'verkünden'), ('dass', 'cp', 'sei'), ('die', 'nk', 'Gabe'), ('wahre', 'nk', 'Gabe'), ('Gabe', 'sb', 'sei'), ('dieser', 'nk', 'Zeit'), ('Zeit', 'ag', 'Gabe'), ('nicht', 'ng', 'Geschenk'), ('irgendein', 'nk', 'Geschenk'), ('kostspieliges', 'nk', 'Geschenk'), ('Geschenk', 'pd', 'sei'), (',', 'punct', 'Geschenk'), ('sondern', 'cd', 'Geschenk'), ('Freude', 'pd', 'sei'), ('sei', 'oc', 'verkünden'), ('.', 'punct', 'ließ')]
#
# → Satzstruktur für Dokument 50:
# [('Ein', 'nk', 'Lächeln'), ('Lächeln', 'sb', 'ist'), (',', 'punct', 'Lächeln'), ('eine', 'nk', 'Geste'), ('Geste', 'cj', 'Lächeln'), ('-', 'punct', 'ist'), ('es', 'sb', 'ist'), ('ist', 'ROOT', 'ist'), ('so', 'mo', 'leicht'), ('leicht', 'pd', 'ist'), (',', 'punct', 'leicht'), ('Freude', 'oa', 'schenken'), ('zu', 'pm', 'schenken'), ('schenken', 're', 'Lächeln'), ('.', 'punct', 'ist')]
#
# → Satzstruktur für Dokument 51:
# [(' ', 'dep', ' ')]
# [('Ich', 'sb', 'bin'), ('bin', 'oc', 'sagt'), ('ganz', 'mo', 'schön'), ('schön', 'mo', 'aufgeregt'), ('aufgeregt', 'pd', 'bin'), (',', 'punct', 'aufgeregt'), ('wieder', 'mo', 'spielen'), ('ganz', 'mo', 'oben'), ('oben', 'mo', 'spielen'), ('zu', 'pm', 'spielen'), ('spielen', 'oc', 'aufgeregt'), ('"', 'punct', 'bin'), ('"', 'punct', 'bin'), (',', 'punct', 'sagt'), ('sagt', 'ROOT', 'sagt'), ('Hede', 'sb', 'sagt'), (',', 'punct', 'sagt'), ('und', 'cd', 'sagt'), ('man', 'sb', 'spürt'), ('spürt', 'cj', 'und'), ('die', 'nk', 'Freude'), ('Freude', 'oa', 'spürt'), ('förmlich', 'mo', 'spürt'), ('durchs', 'mo', 'spürt'), ('Telefon', 'nk', 'durchs'), ('.', 'punct', 'sagt')]
#
# → Satzstruktur für Dokument 52:
# [('Große', 'nk', 'Freude'), ('Freude', 'sb', 'kam'), ('aber', 'mo', 'kam'), ('kam', 'ROOT', 'kam'), ('über', 'mo', 'kam'), ('den', 'nk', 'Tabellenplatz'), ('bislang', 'mo', 'erreichten'), ('erreichten', 'nk', 'Tabellenplatz'), ('fünften', 'nk', 'Tabellenplatz'), ('Tabellenplatz', 'nk', 'über'), ('nicht', 'ng', 'kam'), ('auf', 'svp', 'kam'), (',', 'punct', 'kam'), ('weil', 'cp', 'ist'), ('der', 'nk', 'Abstand'), ('Abstand', 'sb', 'ist'), ('zum', 'mo', 'ist'), ('führenden', 'nk', 'Quartett'), ('Quartett', 'nk', 'zum'), ('sehr', 'mo', 'groß'), ('groß', 'pd', 'ist'), ('ist', 'mo', 'kam'), ('.', 'punct', 'kam')]
#
# → Satzstruktur für Dokument 53:
# [('Anders', 'mo', 'hat'), ('als', 'cm', 'beim'), ('beim', 'cc', 'Anders'), ('Vererben', 'nk', 'beim'), ('hat', 'ROOT', 'hat'), ('der', 'nk', 'Gebende'), ('Gebende', 'sb', 'hat'), ('noch', 'mo', 'etwas'), ('etwas', 'oa', 'hat'), ('von', 'pg', 'etwas'), ('der', 'nk', 'Freude'), ('Freude', 'nk', 'von'), ('der', 'nk', 'Kinder'), ('Kinder', 'ag', 'Freude'), ('oder', 'cd', 'Kinder'), ('Enkel', 'cj', 'oder'), ('über', 'mnr', 'Freude'), ('das', 'nk', 'Geschenk'), ('Geschenk', 'nk', 'über'), ('.', 'punct', 'hat')]
#
# → Satzstruktur für Dokument 54:
# [('Der', 'nk', 'Familie'), ('Familie', 'ROOT', 'Familie'), ('von', 'pg', 'Familie'), ('Frau', 'nk', 'von'), ('Osthoff', 'nk', 'Frau'), (',', 'punct', 'Familie'), ('die', 'oa', 'unterrichtet'), ('wir', 'sb', 'haben'), ('heute', 'mo', 'unterrichtet'), ('Abend', 'oa', 'unterrichtet'), ('unterrichtet', 'oc', 'haben'), ('haben', 'rc', 'Familie'), (',', 'punct', 'Familie'), ('und', 'cd', 'Familie'), ('ihren', 'nk', 'Freunden'), ('Freunden', 'da', 'versichern'), ('möchte', 'cj', 'und'), ('ich', 'sb', 'möchte'), ('versichern', 'oc', 'möchte'), (',', 'punct', 'möchte'), ('dass', 'cp', 'teile'), ('ich', 'sb', 'teile'), ('ihre', 'nk', 'Freude'), ('Freude', 'oa', 'teile'), ('und', 'cd', 'Freude'), ('Erleichterung', 'cj', 'und'), ('nach', 'mo', 'teile'), ('diesen', 'nk', 'Tagen'), ('Tagen', 'nk', 'nach'), ('und', 'cd', 'Tagen'), ('Wochen', 'cj', 'und'), ('der', 'nk', 'Ungewissheit'), ('Ungewissheit', 'ag', 'Tagen'), ('von', 'pg', 'Ungewissheit'), ('ganzem', 'nk', 'Herzen'), ('Herzen', 'nk', 'von'), ('teile', 'mo', 'möchte'), ('.', 'punct', 'Familie')]
#
# → Satzstruktur für Dokument 55:
# [('Alle', 'sb', 'haben'), ('haben', 'ROOT', 'haben'), ('sich', 'oa', 'gemacht'), ('schick', 'mo', 'gemacht'), ('gemacht', 'oc', 'haben'), (',', 'punct', 'gemacht'), ('in', 'mo', 'sehen'), ('vielen', 'nk', 'Gesichtern'), ('Gesichtern', 'nk', 'in'), ('ist', 'cj', 'haben'), ('Freude', 'sb', 'ist'), ('zu', 'pm', 'sehen'), ('sehen', 'oc', 'ist'), ('.', 'punct', 'haben')]
#
# → Satzstruktur für Dokument 56:
# [('Es', 'ep', 'geht'), ('geht', 'ROOT', 'geht'), ('-', 'punct', 'geht'), ('während', 'cp', 'ist'), ('von', 'mo', 'ist'), ('physiologischen', 'nk', 'Phänomenen'), (',', 'punct', 'physiologischen'), ('evolutionstechnischen', 'cj', 'physiologischen'), (',', 'punct', 'physiologischen'), ('musiktheoretischen', 'cj', 'evolutionstechnischen'), (',', 'punct', 'physiologischen'), ('sexualkundlichen', 'cj', 'physiologischen'), ('Phänomenen', 'nk', 'von'), ('der', 'nk', 'Liebe'), ('Liebe', 'ag', 'Phänomenen'), ('die', 'nk', 'Rede'), ('Rede', 'sb', 'ist'), ('ist', 'mo', 'geht'), ('-', 'punct', 'ist'), ('um', 'mo', 'ist'), ('die', 'nk', 'Liebe'), ('echte', 'nk', 'Liebe'), ('Liebe', 'nk', 'um'), ('zwischen', 'mnr', 'Liebe'), ('Schauspieler', 'nk', 'zwischen'), ('und', 'cd', 'Schauspieler'), ('Zuschauer', 'cj', 'und'), (',', 'punct', 'ist'), ('um', 'mo', 'ist'), ('die', 'nk', 'Schwierigkeiten'), ('Schwierigkeiten', 'nk', 'um'), ('und', 'cd', 'Schwierigkeiten'), ('die', 'nk', 'Freude'), ('Freude', 'cj', 'und'), ('am', 'op', 'Freude'), ('geteilten', 'nk', 'Menschsein'), ('Menschsein', 'nk', 'am'), ('.', 'punct', 'geht')]
#
# → Satzstruktur für Dokument 57:
# [('Daspu', 'sb', 'wird'), ('wird', 'ROOT', 'wird'), ('auch', 'mo', 'Karnevals-Umzug'), ('den', 'nk', 'Karnevals-Umzug'), ('Karnevals-Umzug', 'pd', 'wird'), ('"', 'punct', 'wird'), ('"', 'punct', 'wird')]
# [('Prazeres', 'sb', 'ausstatten'), ('Davida', 'nk', 'Prazeres'), ('-', 'punct', 'Davida'), ('Freuden', 'app', 'Davida'), ('des', 'nk', 'Lebens'), ('Lebens', 'ag', 'Freuden'), ('"', 'punct', 'Freuden'), ('"', 'punct', 'Freuden'), ('ausstatten', 'ROOT', 'ausstatten'), (',', 'punct', 'ausstatten'), ('den', 'oa', 'veranstalten'), ('die', 'sb', 'veranstalten'), ('im', 'mo', 'veranstalten'), ('Rotlichtviertel', 'nk', 'im'), ('der', 'nk', 'Altstadt'), ('Altstadt', 'ag', 'Rotlichtviertel'), ('Tätigen', 'oa', 'veranstalten'), ('im', 'mnr', 'Tätigen'), ('kommenden', 'nk', 'Jahr'), ('Jahr', 'nk', 'im'), ('veranstalten', 'rc', 'Davida'), ('.', 'punct', 'ausstatten')]
#
# → Satzstruktur für Dokument 58:
# [('Noch', 'mo', 'zum'), ('bis', 'ac', 'zum'), ('zum', 'mo', 'getanzt'), ('26.', 'nk', 'Dezember'), ('Dezember', 'nk', 'zum'), ('wird', 'ROOT', 'wird'), ('im', 'mo', 'getanzt'), ('ICC', 'nk', 'im'), ('getanzt', 'oc', 'wird'), ('und', 'cd', 'getanzt'), ('gesungen', 'cj', 'und'), (',', 'punct', 'getanzt'), ('dass', 'cp', 'ist'), ('es', 'sb', 'ist'), ('eine', 'nk', 'Freude'), ('Freude', 'pd', 'ist'), ('ist', 'sb', 'wird'), ('.', 'punct', 'wird')]
#
# → Satzstruktur für Dokument 59:
# [('Ich', 'sb', 'weiß'), ('weiß', 'ROOT', 'weiß'), ('nicht', 'ng', 'weiß'), (',', 'punct', 'weiß'), ('ob', 'cp', 'musste'), ('sie', 'sb', 'musste'), ('selbst', 'mo', 'musste'), ('diese', 'nk', 'musste'), ('ertragen', 'nk', 'musste'), ('musste', 'oc', 'weiß'), ('oder', 'cd', 'musste'), ('sie', 'sb', 'kennt'), ('nur', 'mo', 'vom'), ('vom', 'mo', 'kennt'), ('Hörensagen', 'nk', 'vom'), ('kennt', 'cj', 'oder'), (',', 'punct', 'weiß'), ('jedenfalls', 'mo', 'wundern'), ('wundern', 'cj', 'weiß'), ('sich', 'oa', 'wundern'), ('meine', 'nk', 'Frau'), ('Frau', 'sb', 'wundern'), ('und', 'cd', 'Frau'), ('ich', 'cj', 'und'), ('immer', 'mo', 'wieder'), ('wieder', 'mo', 'wundern'), (',', 'punct', 'wundern'), ('wie', 'mo', 'war'), ('es', 'sb', 'war'), ('uns', 'da', 'war'), ('möglich', 'pd', 'war'), ('war', 'oc', 'wundern'), (',', 'punct', 'war'), ('in', 'mo', 'setzen'), ('der', 'nk', 'DDR'), ('DDR', 'nk', 'in'), ('zwei', 'nk', 'Kinder'), ('gesunde', 'nk', 'Kinder'), ('Kinder', 'oa', 'setzen'), ('in', 'mo', 'setzen'), ('die', 'nk', 'Welt'), ('Welt', 'nk', 'in'), ('zu', 'pm', 'setzen'), ('setzen', 're', 'es'), (',', 'punct', 'setzen'), ('die', 'sb', 'sind'), ('prächtig', 'mo', 'gediehen'), ('gediehen', 'oc', 'sind'), ('sind', 'rc', 'DDR'), (',', 'punct', 'sind'), ('eine', 'nk', 'Berufsausbildung'), ('gute', 'nk', 'Berufsausbildung'), ('Berufsausbildung', 'oa', 'absolvierten'), ('absolvierten', 'cj', 'sind'), ('und', 'cd', 'absolvierten'), ('keinen', 'nk', 'Schaden'), ('psychischen', 'nk', 'Schaden'), ('Schaden', 'oa', 'erlitten'), ('erlitten', 'cj', 'und'), ('und', 'cd', 'erlitten'), ('uns', 'da', 'machen'), ('Freude', 'oa', 'machen'), ('machen', 'cj', 'und'), ('.', 'punct', 'weiß')]
#
# → Satzstruktur für Dokument 60:
# [('Wenn', 'cp', 'sollten'), ('Sie', 'sb', 'sollten'), ('doch', 'mo', 'sollten'), ('noch', 'mo', 'sollten'), ('einen', 'oa', 'abbekommen'), ('abbekommen', 'oc', 'sollten'), ('sollten', 're', 'dann'), (',', 'punct', 'dann'), ('dann', 'mo', 'werfen'), ('werfen', 'ROOT', 'werfen'), ('Sie', 'sb', 'werfen'), ('den', 'nk', 'Baum'), ('Baum', 'oa', 'werfen'), ('bloß', 'mo', 'nicht'), ('nicht', 'ng', 'werfen'), ('vor', 'mo', 'werfen'), ('Freude', 'nk', 'vor'), ('einfach', 'mo', 'werfen'), ('so', 'mo', 'werfen'), ('ins', 'mo', 'werfen'), ('Auto', 'nk', 'ins'), ('.', 'punct', 'werfen')]
#
# → Satzstruktur für Dokument 61:
# [('Einer', 'pd', 'war'), ('der', 'nk', 'Handwerker'), ('Handwerker', 'ag', 'Einer'), (',', 'punct', 'Einer'), ('an', 'mo', 'haben'), ('dem', 'nk', 'Perzels'), ('Perzels', 'nk', 'an'), ('ihre', 'nk', 'Freude'), ('besondere', 'nk', 'Freude'), ('Freude', 'oa', 'haben'), ('haben', 'oc', 'würden'), ('würden', 'rc', 'Einer'), (',', 'punct', 'war'), ('war', 'ROOT', 'war'), ('der', 'nk', 'Sohn'), ('Sohn', 'sb', 'war'), ('des', 'nk', 'Chefs'), ('Chefs', 'ag', 'Sohn'), ('und', 'cd', 'war'), ('sollte', 'cj', 'und'), ('im', 'mo', 'sollte'), ('Haus', 'nk', 'im'), ('der', 'nk', 'Perzels'), ('Perzels', 'ag', 'Haus'), ('eine', 'nk', 'Spielwiese'), ('Spielwiese', 'sb', 'finden'), ('finden', 'oc', 'sollte'), ('für', 'mo', 'finden'), ('erste', 'nk', 'Betätigungen'), ('Betätigungen', 'nk', 'für'), ('am', 'mnr', 'Betätigungen'), ('Bau', 'nk', 'am'), ('.', 'punct', 'war')]
#
# → Satzstruktur für Dokument 62:
# [('Ben', 'sb', 'kämpfen'), ('und', 'cd', 'Ben'), ('Julebukk', 'cj', 'und'), ('kämpfen', 'ROOT', 'kämpfen'), ('für', 'mo', 'kämpfen'), ('die', 'nk', 'Rettung'), ('Rettung', 'nk', 'für'), ('Weihnachtens', 'ag', 'Rettung'), ('als', 'mo', 'kämpfen'), ('Fest', 'nk', 'als'), ('der', 'nk', 'Freude'), ('Freude', 'ag', 'Fest'), ('-', 'punct', 'kämpfen'), ('und', 'cd', 'kämpfen'), ('nicht', 'ng', 'Geldes'), ('des', 'nk', 'Geldes'), ('Geldes', 'cj', 'und'), ('.', 'punct', 'kämpfen')]
#
# → Satzstruktur für Dokument 63:
# [('Foto', 'ROOT', 'Foto'), (':', 'punct', 'Foto')]
# [('In', 'ROOT', 'In'), ('der', 'nk', 'Freude'), ('Freude', 'nk', 'In'), ('des', 'nk', 'Mpenza'), ('Emile', 'pnc', 'Mpenza'), ('Mpenza', 'ag', 'Freude'), ('über', 'op', 'Freude'), ('seinen', 'nk', 'Treffer'), ('Treffer', 'nk', 'über'), ('zum', 'mnr', 'Treffer'), ('2:0', 'nk', 'zum'), ('für', 'mnr', '2:0'), ('den', 'nk', 'SV'), ('Hamburger', 'nk', 'SV'), ('SV', 'nk', 'für'), ('in', 'mnr', 'Freude'), ('der', 'nk', 'Minute'), ('57.', 'nk', 'Minute'), ('Minute', 'nk', 'in'), ('des', 'nk', 'Uefa-Cup-Spiels'), ('Uefa-Cup-Spiels', 'ag', 'Minute'), ('gegen', 'mnr', 'Uefa-Cup-Spiels'), ('Slavia', 'nk', 'gegen')]
# [('Prag', 'sb', 'schwang'), ('schwang', 'ROOT', 'schwang'), ('immer', 'mo', 'noch'), ('noch', 'mo', 'schwang'), ('ein', 'nk', 'Kummer'), ('bisschen', 'nk', 'Kummer'), ('Kummer', 'sb', 'schwang'), ('über', 'op', 'schwang'), ('seine', 'nk', 'Chancen'), ('zuvor', 'mo', 'verpassten'), ('verpassten', 'nk', 'Chancen'), ('Chancen', 'nk', 'über'), ('mit', 'svp', 'schwang'), ('.', 'punct', 'schwang')]
#
# → Satzstruktur für Dokument 64:
# [(' ', 'dep', ' ')]
# [('Ein', 'nk', 'Gefühl'), ('schönes', 'nk', 'Gefühl'), ('Gefühl', 'ROOT', 'Gefühl'), ('"', 'punct', 'Gefühl')]
# [('"', 'punct', 'sagte'), (',', 'punct', 'sagte'), ('sagte', 'ROOT', 'sagte'), ('Weissenberger', 'sb', 'sagte'), ('nur', 'mo', 'sagte'), ('und', 'cd', 'sagte'), ('stellte', 'cj', 'und'), ('dabei', 'mo', 'stellte'), ('ehrliche', 'nk', 'Freude'), ('Freude', 'oa', 'stellte'), ('statt', 'mo', 'stellte'), ('Überheblichkeit', 'nk', 'statt'), ('zur', 'mnr', 'Überheblichkeit'), ('Schau', 'nk', 'zur'), ('.', 'punct', 'sagte')]
#
# → Satzstruktur für Dokument 65:
# [('Ich', 'sb', 'habe'), ('habe', 'ROOT', 'habe'), ('einen', 'nk', 'Terminkalender'), ('vollen', 'nk', 'Terminkalender'), ('Terminkalender', 'oa', 'habe'), (',', 'punct', 'habe'), ('und', 'cd', 'habe'), ('es', 'sb', 'macht'), ('macht', 'cj', 'und'), ('mir', 'da', 'macht'), ('Freude', 'oa', 'macht'), (',', 'punct', 'Freude'), ('mich', 'oa', 'einzusetzen'), ('für', 'mo', 'einzusetzen'), ('andere', 'nk', 'für'), ('einzusetzen', 'oc', 'Freude'), ('.', 'punct', 'habe')]
#
# → Satzstruktur für Dokument 66:
# [('Das', 'nk', 'Hof-Theater'), ('Hackesche', 'nk', 'Hof-Theater'), ('Hof-Theater', 'sb', 'hat'), ('hat', 'ROOT', 'hat'), ('keine', 'nk', 'Chance'), ('Chance', 'oa', 'hat'), (',', 'punct', 'Chance'), ('aber', 'cd', 'Chance'), ('Seidemann', 'sb', 'will'), ('will', 'cj', 'aber'), ('sie', 'oa', 'nutzen'), ('nutzen', 'oc', 'will'), ('-', 'punct', 'will'), ('und', 'cd', 'hat'), ('vielleicht', 'mo', 'bringt'), ('bringt', 'cj', 'und'), ('Weihnukka', 'sb', 'bringt'), ('neben', 'mo', 'bringt'), ('Frieden', 'nk', 'neben'), ('und', 'cd', 'Frieden'), ('Freuden', 'cj', 'und'), ('doch', 'mo', 'bringt'), ('eine', 'nk', 'Chance'), ('allerletzte', 'nk', 'Chance'), ('Chance', 'oa', 'bringt'), (',', 'punct', 'Chance'), ('das', 'nk', 'Mietverhältnis'), ('Mietverhältnis', 'oa', 'verlängern'), ('in', 'mo', 'verlängern'), ('einer', 'nk', 'Weise'), ('für', 'mo', 'akzeptablen'), ('beide', 'nk', 'Seiten'), ('Seiten', 'nk', 'für'), ('akzeptablen', 'nk', 'Weise'), ('Weise', 'nk', 'in'), ('zu', 'pm', 'verlängern'), ('verlängern', 'oc', 'Chance'), ('.', 'punct', 'hat')]
#
# → Satzstruktur für Dokument 67:
# [('Bei', 'mo', 'sind'), ('solchen', 'nk', 'Vorlagen'), ('Vorlagen', 'nk', 'Bei'), ('sind', 'ROOT', 'sind'), ('auch', 'mo', 'Schauspieler'), ('die', 'nk', 'Schauspieler'), ('Schauspieler', 'sb', 'sind'), ('mit', 'mnr', 'Schauspieler'), ('sichtlicher', 'nk', 'Freude'), ('Freude', 'nk', 'mit'), ('am', 'mo', 'sind'), ('Werk', 'nk', 'am'), ('.', 'punct', 'sind')]
#
# → Satzstruktur für Dokument 68:
# [('Wer', 'sb', 'will'), ('also', 'mo', 'machen'), ('(', 'punct', 's'), ('s', 'par', 'also'), (')', 'punct', 's'), ('einer', 'nk', 'Frau'), ('Frau', 'da', 'machen'), ('eine', 'nk', 'Freude'), ('Freude', 'oa', 'machen'), ('machen', 'oc', 'will'), ('will', 'sb', 'schenkt'), (',', 'punct', 'schenkt'), ('schenkt', 'ROOT', 'schenkt'), ('ihr', 'da', 'schenkt'), ('vielleicht', 'mo', 'schenkt'), ('ein', 'nk', 'Schweigeseminar'), ('Schweigeseminar', 'sb', 'schenkt'), ('unter', 'mo', 'schenkt'), ('dem', 'nk', 'Motto'), ('schönen', 'nk', 'Motto'), ('Motto', 'nk', 'unter'), (':', 'punct', 'schenkt')]
#
# → Satzstruktur für Dokument 69:
# [('Besinnung', 'sb', 'würden'), (',', 'punct', 'Besinnung'), ('Einkehr', 'cj', 'Besinnung'), ('und', 'cd', 'Einkehr'), ('innere', 'nk', 'Freude'), ('Freude', 'cj', 'und'), ('würden', 'ROOT', 'würden'), ('in', 'mo', 'gedrängt'), ('den', 'nk', 'Hintergrund'), ('Hintergrund', 'nk', 'in'), ('gedrängt', 'oc', 'würden'), ('.', 'punct', 'würden')]
#
# → Satzstruktur für Dokument 70:
# [('Als', 'cp', 'bekam'), ('der', 'nk', 'Iran'), ('Iran', 'sb', 'bekam'), ('Angola', 'nk', 'Iran'), (',', 'punct', 'Angola'), ('Mexiko', 'cj', 'Angola'), ('und', 'cd', 'Mexiko'), ('Portugal', 'cj', 'und'), ('zugeteilt', 'oc', 'bekam'), ('bekam', 'ROOT', 'bekam'), (',', 'punct', 'bekam'), ('umarmten', 'cj', 'bekam'), ('und', 'cd', 'bekam'), ('küssten', 'cj', 'und'), ('sich', 'oa', 'küssten'), ('die', 'nk', 'Moderatoren'), ('Moderatoren', 'sb', 'küssten'), ('des', 'nk', 'Fernsehens'), ('staatlichen', 'nk', 'Fernsehens'), ('Fernsehens', 'ag', 'Moderatoren'), ('vor', 'mo', 'küssten'), ('Freude', 'nk', 'vor'), ('.', 'punct', 'bekam')]
#
# → Satzstruktur für Dokument 71:
# [('Besonders', 'mo', 'groß'), ('groß', 'pd', 'war'), ('war', 'ROOT', 'war'), ('die', 'nk', 'Freude'), ('Freude', 'sb', 'war'), ('in', 'mnr', 'Freude'), ('Costa', 'pnc', 'Rica'), ('Rica', 'nk', 'in'), ('darüber', 'mo', 'war'), (',', 'punct', 'darüber'), ('dass', 'cp', 'dürfen'), ('die', 'nk', 'Ticos'), ('"', 'punct', 'Ticos'), ('"', 'punct', 'Ticos'), ('Ticos', 'sb', 'dürfen'), ('"', 'punct', 'Ticos'), ('"', 'punct', 'Ticos'), ('das', 'nk', 'Eröffnungsspiel'), ('Eröffnungsspiel', 'oa', 'bestreiten'), ('der', 'nk', 'Weltmeisterschaft'), ('Weltmeisterschaft', 'ag', 'Eröffnungsspiel'), ('bestreiten', 'oc', 'dürfen'), ('dürfen', 're', 'darüber'), (':', 'punct', 'war')]
#
# → Satzstruktur für Dokument 72:
# [('Um', 'cp', 'machen'), ('mir', 'da', 'machen'), ('eine', 'nk', 'Freude'), ('Freude', 'oa', 'machen'), ('zu', 'pm', 'machen'), ('machen', 'mo', 'heruntergeladen'), (',', 'punct', 'hat'), ('hat', 'ROOT', 'hat'), ('sie', 'sb', 'hat'), ('es', 'oa', 'heruntergeladen'), ('mir', 'da', 'heruntergeladen'), ('extra', 'mo', 'heruntergeladen'), ('aus', 'mo', 'heruntergeladen'), ('dem', 'nk', 'Netz'), ('Netz', 'nk', 'aus'), ('heruntergeladen', 'oc', 'hat'), ('.', 'punct', 'hat')]
#
# → Satzstruktur für Dokument 73:
# [('Aber', 'ju', 'hatte'), ('Lederer', 'sb', 'hatte'), ('hatte', 'ROOT', 'hatte'), ('noch', 'mo', 'hatte'), ('einen', 'nk', 'Grund'), ('zweiten', 'nk', 'Grund'), ('Grund', 'oa', 'hatte'), ('zur', 'mnr', 'Grund'), ('Freude', 'nk', 'zur'), (':', 'punct', 'hatte')]
#
# → Satzstruktur für Dokument 74:
# [('Wie', 'cm', 'im'), ('im', 'mo', 'liegen'), ('richtigen', 'nk', 'Leben'), ('Leben', 'nk', 'im'), ('liegen', 'ROOT', 'liegen'), ('auch', 'mo', 'im'), ('im', 'mo', 'liegen'), ('Zoo', 'nk', 'im'), ('manchmal', 'mo', 'liegen'), ('Freude', 'sb', 'liegen'), ('und', 'cd', 'Freude'), ('Trauer', 'cj', 'und'), ('dicht', 'mo', 'beieinander'), ('beieinander', 'mo', 'liegen'), ('.', 'punct', 'liegen')]
#
# → Satzstruktur für Dokument 75:
# [('Auch', 'mo', 'in'), ('in', 'mo', 'gibt'), ('anderen', 'nk', 'Ländern'), ('europäischen', 'nk', 'Ländern'), ('Ländern', 'nk', 'in'), ('gibt', 'ROOT', 'gibt'), ('es', 'ep', 'gibt'), ('überdimensionale', 'nk', 'Bürokratien'), ('Bürokratien', 'oa', 'gibt'), (',', 'punct', 'gibt'), ('obskure', 'nk', 'Reglements'), ('Reglements', 'cj', 'gibt'), ('und', 'cd', 'Reglements'), ('in', 'cj', 'und'), ('Superzeitlupe', 'nk', 'in'), ('agierende', 'nk', 'Behörden'), ('Behörden', 'oa', 'gibt'), ('-', 'punct', 'gibt'), ('aber', 'cd', 'gibt'), ('dort', 'mo', 'kann'), ('kann', 'cj', 'aber'), ('man', 'sb', 'kann'), ('zumindest', 'mo', 'kann'), ('auf', 'mo', 'zurückgreifen'), ('einen', 'nk', 'Fundus'), ('zuverlässigen', 'nk', 'Fundus'), ('Fundus', 'nk', 'auf'), ('von', 'pg', 'Fundus'), ('Korruption', 'nk', 'von'), (',', 'punct', 'Fundus'), ('zentral', 'mo', 'verwalteter'), ('verwalteter', 'nk', 'Planlosigkeit'), ('Planlosigkeit', 'nk', 'auf'), ('oder', 'cd', 'auf'), ('zumindest', 'mo', 'Freude'), ('eine', 'nk', 'Freude'), ('über', 'op', 'verteilte'), ('alle', 'nk', 'Teile'), ('Teile', 'nk', 'über'), ('der', 'nk', 'Bevölkerung'), ('Bevölkerung', 'ag', 'Teile'), ('verteilte', 'nk', 'Freude'), ('Freude', 'cj', 'oder'), ('am', 'mnr', 'Freude'), ('Trödeln', 'nk', 'am'), ('zurückgreifen', 'oc', 'kann'), ('.', 'punct', 'gibt')]
#
# → Satzstruktur für Dokument 76:
# [('Sichtliche', 'nk', 'Freude'), ('Freude', 'sb', 'haben'), ('haben', 'ROOT', 'haben'), ('auch', 'mo', 'Engel'), ('Judith', 'pnc', 'Engel'), ('Engel', 'sb', 'haben'), ('als', 'mnr', 'Engel'), ('überforderte', 'nk', 'Stiefmutter'), ('Stiefmutter', 'nk', 'als'), ('und', 'cd', 'Stiefmutter'), ('Stipe', 'pnc', 'Erceg'), ('Erceg', 'cj', 'und'), ('als', 'mnr', 'Engel'), ('Internet-Romeo', 'nk', 'als'), (',', 'punct', 'Internet-Romeo'), ('der', 'sb', 'bezahlt'), ('seinen', 'nk', 'Narzissmus'), ('Narzissmus', 'oa', 'bezahlt'), ('mit', 'mo', 'bezahlt'), ('dem', 'nk', 'Tod'), ('Tod', 'nk', 'mit'), ('bezahlt', 'rc', 'Internet-Romeo'), ('.', 'punct', 'haben')]
#
# → Satzstruktur für Dokument 77:
# [('Auch', 'mo', 'kommt'), ('wenn', 'cp', 'kommt'), ('mit', 'mo', 'kommt'), ('einer', 'nk', 'Servolenkung'), ('Servolenkung', 'nk', 'mit'), ('freilich', 'mo', 'kommt'), ('ein', 'nk', 'Teil'), ('Teil', 'sb', 'kommt'), ('dieser', 'nk', 'Freude'), ('Freude', 'ag', 'Teil'), ('und', 'cd', 'Freude'), ('des', 'nk', 'Stolzes'), ('Stolzes', 'cj', 'und'), ('abhanden', 'mnr', 'Teil'), ('kommt', 'mo', 'sollte'), (',', 'punct', 'sollte'), ('sollte', 'ROOT', 'sollte'), ('man', 'sb', 'sollte'), ('die', 'nk', 'Euro'), ('450', 'nk', 'Euro'), ('Euro', 'oa', 'investieren'), ('investieren', 'oc', 'sollte'), ('.', 'punct', 'sollte')]
#
# → Satzstruktur für Dokument 78:
# [('Für', 'mo', 'hält'), ('-', 'punct', 'hält'), ('aus', 'mo', 'hält'), ('europäischer', 'nk', 'Sicht'), ('Sicht', 'nk', 'aus'), ('-', 'punct', 'hält'), ('extreme', 'nk', 'Gelüste'), ('Gelüste', 'oa', 'hält'), ('hält', 'ROOT', 'hält'), ('die', 'nk', 'Kochkunst'), ('vietnamesische', 'nk', 'Kochkunst'), ('Kochkunst', 'sb', 'hält'), ('auch', 'mo', 'hält'), ('ganz', 'mo', 'besondere'), ('besondere', 'nk', 'Freuden'), ('Freuden', 'oa', 'hält'), ('parat', 'svp', 'hält'), (':', 'punct', 'hält')]
# [('Schlangenragout', 'ROOT', 'Schlangenragout'), (',', 'punct', 'Schlangenragout'), ('gegrilltes', 'nk', 'Hundefleisch'), ('Hundefleisch', 'cj', 'Ente'), (',', 'punct', 'Schlangenragout'), ('gebratene', 'nk', 'Skorpione'), ('Skorpione', 'cj', 'Ente'), (',', 'punct', 'Schlangenragout'), ('im', 'mo', 'gemästete'), ('Bambusrohr', 'nk', 'im'), ('gemästete', 'nk', 'Ente'), ('Ente', 'cj', 'Schlangenragout'), ('oder', 'cd', 'Ente'), ('Eintopf', 'cj', 'oder'), ('von', 'pg', 'Eintopf'), ('Ziegenbockpenissen', 'nk', 'von'), ('.', 'punct', 'Schlangenragout')]
#
# → Satzstruktur für Dokument 79:
# ...
#
# → Satzstruktur für Dokument 91:
# [('Einmal', 'mo', 'unterzogen'), ('hatte', 'ROOT', 'hatte'), ('die', 'nk', 'Mutter'), ('Mutter', 'sb', 'hatte'), ('Gregors', 'ag', 'Zimmer'), ('Zimmer', 'oa', 'unterzogen'), ('einer', 'nk', 'Reinigung'), ('großen', 'nk', 'Reinigung'), ('Reinigung', 'ag', 'Zimmer'), ('unterzogen', 'oc', 'hatte'), (',', 'punct', 'unterzogen'), ('die', 'sb', 'war'), ('ihr', 'da', 'gelungen'), ('nur', 'mo', 'nach'), ('nach', 'mo', 'gelungen'), ('Verbrauch', 'nk', 'nach'), ('einiger', 'nk', 'Kübel'), ('Kübel', 'ag', 'Verbrauch'), ('Wasser', 'nk', 'nach'), ('gelungen', 'oc', 'war'), ('war', 'rc', 'einer'), ('-', 'punct', 'war'), ('die', 'nk', 'Feuchtigkeit'), ('viele', 'nk', 'Feuchtigkeit'), ('Feuchtigkeit', 'sb', 'kränkte'), ('kränkte', 'cj', 'hatte'), ('allerdings', 'mo', 'kränkte'), ('Gregor', 'sb', 'kränkte'), ('auch', 'mo', 'kränkte'), ('und', 'cd', 'kränkte'), ('er', 'sb', 'lag'), ('lag', 'cj', 'und'), ('breit', 'mo', 'lag'), (',', 'punct', 'lag'), ('verbittert', 'cj', 'lag'), ('und', 'cd', 'verbittert'), ('unbeweglich', 'cj', 'und'), ('auf', 'mo', 'unbeweglich'), ('dem', 'nk', 'Kanapee'), ('Kanapee', 'nk', 'auf'), ('-', 'punct', 'kränkte'), (',', 'punct', 'hatte'), ('aber', 'cd', 'hatte'), ('die', 'nk', 'Strafe'), ('Strafe', 'sb', 'blieb'), ('blieb', 'cj', 'aber'), ('für', 'mo', 'blieb'), ('die', 'nk', 'Mutter'), ('Mutter', 'nk', 'für'), ('nicht', 'ng', 'blieb'), ('aus', 'svp', 'blieb'), ('.', 'punct', 'hatte')]
# [('[', 'ROOT', '['), ('...', 'punct', '['), (']', 'mo', '['), ('die', 'nk', 'Eltern'), ('Eltern', 'sb', 'war'), ('-', 'punct', 'Eltern'), ('der', 'nk', 'Vater'), ('Vater', 'app', 'Eltern'), ('war', 'rs', '['), ('natürlich', 'mo', 'aufgeschreckt'), ('aus', 'mo', 'aufgeschreckt'), ('seinem', 'nk', 'Sessel'), ('Sessel', 'nk', 'aus'), ('aufgeschreckt', 'oc', 'worden'), ('worden', 'oc', 'war'), ('-', 'punct', 'worden'), ('zuerst', 'mo', 'zusahen'), ('erstaunt', 'mo', 'zusahen'), ('und', 'cd', 'erstaunt'), ('hilflos', 'cj', 'und'), ('zusahen', 'oc', 'war'), (';', 'punct', '[')]
# [('bis', 'cp', 'anfingen'), ('auch', 'mo', 'sie'), ('sie', 'sb', 'anfingen'), ('sich', 'oa', 'rühren'), ('zu', 'pm', 'rühren'), ('rühren', 'oc', 'anfingen'), ('anfingen', 'ROOT', 'anfingen'), (';', 'punct', 'anfingen')]
# [('der', 'nk', 'Vater'), ('Vater', 'sb', 'machte'), ('rechts', 'mo', 'machte'), ('der', 'nk', 'Mutter'), ('Mutter', 'da', 'machte'), ('Vorwürfe', 'oa', 'machte'), ('machte', 'ROOT', 'machte'), (',', 'punct', 'machte'), ('daß', 'cp', 'überließ'), ('sie', 'sb', 'überließ'), ('Gregors', 'ag', 'Zimmer'), ('Zimmer', 'oa', 'überließ'), ('nicht', 'ng', 'überließ'), ('der', 'nk', 'Schwester'), ('Schwester', 'da', 'überließ'), ('zur', 'mo', 'überließ'), ('Reinigung', 'nk', 'zur'), ('überließ', 'oc', 'machte'), (';', 'punct', 'machte')]
# [('links', 'mo', 'Schwester'), ('dagegen', 'mo', 'Schwester'), ('die', 'nk', 'Schwester'), ('Schwester', 'sb', 'werde'), ('anschrie', 'nk', 'Schwester'), (',', 'punct', 'Schwester'), ('sie', 'sb', 'werde'), ('werde', 'ROOT', 'werde'), ('niemals', 'mo', 'dürfen'), ('mehr', 'nk', 'Gregors'), ('Gregors', 'oa', 'reinigen'), ('Zimmer', 'nk', 'Gregors'), ('reinigen', 'oc', 'dürfen'), ('dürfen', 'oc', 'werde'), (';', 'punct', 'werde')]
# [('während', 'cp', 'suchte'), ('die', 'nk', 'Mutter'), ('Mutter', 'sb', 'suchte'), ('den', 'nk', 'Vater'), ('Vater', 'oa', 'suchte'), (',', 'punct', 'Vater'), ('der', 'sb', 'kannte'), ('sich', 'oa', 'kannte'), ('vor', 'mo', 'kannte'), ('Erregung', 'nk', 'vor'), ('nicht', 'ng', 'kannte'), ('mehr', 'mo', 'nicht'), ('kannte', 'rc', 'Vater'), (',', 'punct', 'suchte'), ('ins', 'mo', 'schleppen'), ('Schlafzimmer', 'nk', 'ins'), ('zu', 'pm', 'schleppen'), ('schleppen', 'oc', 'suchte'), ('suchte', 'ROOT', 'suchte'), (';', 'punct', 'suchte')]
# [('die', 'nk', 'Schwester'), ('Schwester', 'sb', 'bearbeitete'), (',', 'punct', 'Schwester'), ('von', 'sbp', 'geschüttelt'), ('Schluchzen', 'nk', 'von'), ('geschüttelt', 'par', 'Schwester'), (',', 'punct', 'Schwester'), ('mit', 'mo', 'bearbeitete'), ('ihren', 'nk', 'Fäusten'), ('kleinen', 'nk', 'Fäusten'), ('Fäusten', 'nk', 'mit'), ('den', 'nk', 'Tisch'), ('Tisch', 'oa', 'bearbeitete'), ('bearbeitete', 'ROOT', 'bearbeitete'), (';', 'punct', 'bearbeitete')]
# [('und', 'ju', 'zischte'), ('Gregor', 'sb', 'zischte'), ('laut', 'mo', 'zischte'), ('vor', 'mo', 'zischte'), ('Wut', 'nk', 'vor'), ('darüber', 'op', 'zischte'), ('zischte', 'ROOT', 'zischte'), (',', 'punct', 'zischte'), ('daß', 'cp', 'einfiel'), ('es', 'ep', 'einfiel'), ('keinem', 'nk', 'einfiel'), ('einfiel', 're', 'darüber'), (',', 'punct', 'einfiel'), ('die', 'nk', 'Tür'), ('Tür', 'oa', 'schließen'), ('zu', 'pm', 'schließen'), ('schließen', 'oc', 'einfiel'), ('und', 'cd', 'schließen'), ('ihm', 'da', 'ersparen'), ('diesen', 'nk', 'Anblick'), ('Anblick', 'oa', 'ersparen'), ('und', 'cd', 'Anblick'), ('Lärm', 'cj', 'und'), ('zu', 'pm', 'ersparen'), ('ersparen', 'cj', 'und'), ('.', 'punct', 'zischte')]
# [('[', 'ROOT', '['), ('...', 'punct', '['), (']', 'punct', '[')]
# [('Aber', 'ju', 'erschöpft'), ('selbst', 'mo', 'erschöpft'), ('wenn', 'cp', 'erschöpft'), ('die', 'nk', 'Schwester'), ('Schwester', 'sb', 'erschöpft'), (',', 'punct', 'erschöpft'), ('erschöpft', 're', 'so'), ('von', 'mo', 'erschöpft'), ('ihrer', 'nk', 'Berufsarbeit'), ('Berufsarbeit', 'nk', 'von'), (',', 'punct', 'Berufsarbeit'), ('dessen', 'sb', 'war'), ('überdrüssig', 'pd', 'geworden'), ('geworden', 'oc', 'war'), ('war', 'rc', 'Berufsarbeit'), (',', 'punct', 'war'), ('für', 'mo', 'erschöpft'), ('Gregor', 'nk', 'für'), (',', 'punct', 'Gregor'), ('wie', 'mo', 'früher'), ('früher', 'mo', 'sorgen'), (',', 'punct', 'sorgen'), ('zu', 'pm', 'sorgen'), ('sorgen', 'oc', 'erschöpft'), (',', 'punct', 'so'), ('so', 'mo', 'müssen'), ('hätte', 'ROOT', 'hätte'), ('noch', 'mo', 'keineswegs'), ('keineswegs', 'mo', 'müssen'), ('die', 'nk', 'Mutter'), ('Mutter', 'sb', 'hätte'), ('für', 'mo', 'eintreten'), ('sie', 'nk', 'für'), ('eintreten', 'oc', 'müssen'), ('müssen', 'oc', 'hätte'), ('und', 'cd', 'müssen'), ('Gregor', 'sb', 'hätte'), ('hätte', 'cj', 'und'), ('doch', 'mo', 'brauchen'), ('nicht', 'ng', 'brauchen'), ('vernachlässigt', 'oc', 'werden'), ('werden', 'oc', 'brauchen'), ('brauchen', 'oc', 'hätte'), ('.', 'punct', 'hätte')]
#
# → Satzstruktur für Dokument 92:
# [('Wie', 'mo', 'erwarten'), ('zu', 'pm', 'erwarten'), ('erwarten', 'mo', 'hallte'), (',', 'punct', 'hallte'), ('hallte', 'ROOT', 'hallte'), ('der', 'nk', 'Sturm'), ('Sturm', 'sb', 'hallte'), ('der', 'nk', 'Entrüstung'), ('Entrüstung', 'ag', 'Sturm'), ('gegen', 'mnr', 'Entrüstung'), ('die', 'nk', 'Missionare'), ('Missionare', 'nk', 'gegen'), ('auch', 'mo', 'bald'), ('bald', 'mo', 'hallte'), ('aus', 'mo', 'hallte'), ('Blättern', 'nk', 'aus'), ('der', 'nk', 'Heimat'), ('Heimat', 'ag', 'Blättern'), ('hierher', 'mo', 'hallte'), ('zurück', 'svp', 'hallte'), ('.', 'punct', 'hallte')]
# [('Die', 'nk', 'Zeitschrift'), ('"', 'punct', 'Zeitschrift'), ('"', 'punct', 'Zeitschrift'), ('Koloniale', 'nk', 'Zeitschrift'), ('Zeitschrift', 'pd', 'war'), ('"', 'punct', 'Zeitschrift'), ('"', 'punct', 'Zeitschrift'), ('war', 'ROOT', 'war'), ('es', 'sb', 'war'), (',', 'punct', 'es'), ('die', 'sb', 'verstieg'), ('sich', 'oa', 'verstieg'), ('in', 'mo', 'verstieg'), ('ohnmächtiger', 'nk', 'Wut'), ('Wut', 'nk', 'in'), ('zu', 'op', 'verstieg'), ('dem', 'nk', 'Satz'), ('Satz', 'nk', 'zu'), ('verstieg', 'rc', 'es'), (':', 'punct', 'war')]
# [('Malaria', 'sb', 'ist'), (',', 'punct', 'Malaria'), ('Heuschrecken', 'cj', 'Malaria'), (',', 'punct', 'Malaria'), ('Schwarzwasserfieber', 'cj', 'Heuschrecken'), (',', 'punct', 'so'), ('so', 'mo', 'unausrottbar'), ('unausrottbar', 'mo', 'diese'), ('diese', 'par', 'Malaria'), (',', 'punct', 'so'), ('so', 'mo', 'unausrottbar'), ('unausrottbar', 'pd', 'ist'), ('ist', 'ROOT', 'ist'), ('leider', 'mo', 'ist'), ('auch', 'mo', 'Mission'), ('die', 'nk', 'Mission'), ('Mission', 'pd', 'ist'), ('.', 'punct', 'ist')]
# [('"', 'ROOT', '"')]
# [('"', 'ROOT', '"')]
#
# → Satzstruktur für Dokument 93:
# [('Was', 'nk', 'is'), ("g'schehen", 'nk', 'is'), ('is', 'ROOT', 'is'), (',', 'punct', 'is'), ('is', 'mo', "g'schehen"), ('einmal', 'mo', 'is'), ("g'schehen", 'cj', 'is'), (',', 'punct', 'is'), ('und', 'cd', 'is'), ('der', 'nk', 'Forstmeister'), ('Forstmeister', 'sb', 'wird'), ('wird', 'cj', 'und'), ('schon', 'mo', 'wissen'), ('wissen', 'oc', 'wird'), ('warum', 'mo', 'wird'), ('.', 'punct', 'is')]
# [('(', 'punct', 'sich'), ('Außer', 'ROOT', 'Außer'), ('sich', 'nk', 'Außer'), ('vor', 'ac', 'Außer'), ('Wut', 'nk', 'vor'), ('.', 'punct', 'Außer'), (')', 'punct', 'Außer')]
# [('Aber', 'ju', 'schicken'), ('nicht', 'ng', 'schicken'), (',', 'punct', 'nicht'), ('daß', 'cp', 'schicken'), ('Sie', 'sb', 'schicken'), ('mir', 'da', 'schicken'), ('den', 'nk', 'Wisch'), ('Wisch', 'oa', 'schicken'), ('ins', 'mo', 'schicken'), ('Haus', 'nk', 'ins'), ('schicken', 'ROOT', 'schicken'), (',', 'punct', "mit'm"), ("mit'm", 'nk', 'Amtsdiener'), ('Amtsdiener', 'sb', 'schicken'), ('!', 'punct', 'schicken')]
#
# → Satzstruktur für Dokument 94:
# [('Wär', 'ROOT', 'Wär'), ('ich', 'oa', 'heimkommen'), ('nur', 'mo', 'früher'), ('einen', 'nk', 'Augenblick'), ('Augenblick', 'ams', 'früher'), ('früher', 'mo', 'heimkommen'), ('heimkommen', 'oc', 'Wär'), ('!', 'punct', 'Wär')]
# [('Wenn', 'cp', 'ist'), ('der', 'nk', 'Vater'), ('Vater', 'sb', 'ist'), ('einmal', 'mo', 'ist'), ('in', 'mo', 'ist'), ('Wut', 'nk', 'in'), ('ist', 'mo', 'hört'), (',', 'punct', 'hört'), ('hört', 'ROOT', 'hört'), ('er', 'sb', 'hört'), ('auf', 'op', 'hört'), ('niemand', 'nk', 'auf'), ('als', 'mo', 'hört'), ('mich', 'nk', 'als'), ('.', 'punct', 'hört')]
# [('Forstmeister', 'sb', 'verstockt'), ('(', 'punct', 'ärgerlich'), ('ärgerlich', 'mo', 'verstockt'), (',', 'punct', 'verstockt'), ('verstockt', 'ROOT', 'verstockt'), (')', 'punct', 'verstockt'), ('.', 'punct', 'verstockt')]
#
# → Satzstruktur für Dokument 95:
# [('Da', 'cp', 'Herr'), ('aber', 'mo', 'Herr'), ('der', 'nk', 'Herr'), ('Herr', 'ROOT', 'Herr'), ('Gunglbauer', 'nk', 'Herr'), ('selbst', 'mnr', 'Gunglbauer'), ('--', 'punct', 'Herr'), ('Forstmeister', 'app', 'Herr'), ('(', 'punct', 'geratend'), ('von', 'sbp', 'geratend'), ('neuem', 'nk', 'von'), ('in', 'mo', 'geratend'), ('Wut', 'nk', 'in'), ('geratend', 'par', 'Forstmeister'), (',', 'punct', 'geratend'), ('höhnisch', 'mo', 'auflachend'), ('auflachend', 'par', 'Forstmeister'), (')', 'punct', 'Herr'), ('.', 'punct', 'Herr')]
# [('Der', 'nk', 'Herr'), ('Herr', 'ROOT', 'Herr'), ('Gunglbauer', 'nk', 'Herr'), ('!', 'punct', 'Herr')]
#
# → Satzstruktur für Dokument 96:
# [('Mei', 'ag', 'Freund'), ('Freund', 'ROOT', 'Freund'), ('!', 'punct', 'Freund')]
# [('(', 'punct', 'Will'), ('Will', 'ROOT', 'Will'), ('auf', 'mo', 'Will'), ('ihn', 'nk', 'auf'), ('zu', 'svp', 'Will'), ('.', 'punct', 'Will'), (')', 'punct', 'Will')]
# [('Straßer', 'ROOT', 'Straßer'), ('(', 'punct', 'zuckt'), ('zuckt', 'par', 'Straßer'), ('bei', 'mo', 'zuckt'), ('dem', 'nk', 'Wort'), ('Wort', 'nk', 'bei'), ('Freund', 'nk', 'Wort'), ('zusammen', 'svp', 'zuckt'), (',', 'punct', 'zuckt'), ('grinst', 'mo', 'höhnisch'), ('höhnisch', 'mo', 'zuckt'), ('und', 'cd', 'zuckt'), ('kräht', 'cj', 'und'), ('vor', 'mo', 'kräht'), ('Wut', 'nk', 'vor'), (';', 'punct', 'Straßer')]
# [('ganz', 'mo', 'schrill'), ('schrill', 'ROOT', 'schrill'), (')', 'punct', 'schrill'), ('.', 'punct', 'schrill')]
# [('Hähä', 'ROOT', 'Hähä'), ('!', 'punct', 'Hähä')]
#
# → Satzstruktur für Dokument 97:
# [('I', 'pnc', 'hab'), ('hab', 'ROOT', 'hab')]
# [('was', 'ROOT', 'was'), ('für', 'mnr', 'was'), ('di', 'nk', 'für'), ('!', 'punct', 'was')]
# [('Straßer', 'ROOT', 'Straßer'), ('(', 'punct', 'aufblähend'), ('sich', 'oa', 'aufblähend'), ('vor', 'mo', 'aufblähend'), ('Wut', 'nk', 'vor'), ('aufblähend', 'par', 'Straßer'), (',', 'punct', 'aufblähend'), ('krähend', 'cj', 'aufblähend'), (',', 'punct', 'aufblähend'), ('noch', 'mo', 'schriller'), ('schriller', 'cj', 'aufblähend'), (')', 'punct', 'aufblähend'), ('.', 'punct', 'Straßer')]
# [('Hähä', 'ROOT', 'Hähä'), ('!', 'punct', 'Hähä')]
#
# → Satzstruktur für Dokument 98:
# [('Da', 'mo', 'schaust'), ('schaust', 'ROOT', 'schaust'), (',', 'punct', 'schaust'), ('was', 'sb', 'schaust'), ('?', 'punct', 'schaust')]
# [('Straßer', 'ROOT', 'Straßer'), ('(', 'punct', 'stößt'), ('stößt', 'rs', 'Straßer'), ('Hias', 'sb', 'stößt'), ('weg', 'svp', 'stößt'), (';', 'punct', 'stößt')]
# [('mit', 'ROOT', 'mit'), ('verbissener', 'nk', 'Wut'), ('Wut', 'nk', 'mit'), (')', 'punct', 'Wut'), ('.', 'punct', 'mit')]
# [("B'halt", 'ROOT', "B'halt"), ('da', 'mo', "B'halt"), ('dein', 'nk', 'Speck'), ('Speck', 'oa', "B'halt"), ('!', 'punct', "B'halt")]
#
# → Satzstruktur für Dokument 99:
# [('(', 'punct', 'hält'), ('Er', 'sb', 'hält'), ('hält', 'ROOT', 'hält'), ('ihm', 'da', 'hält'), ('den', 'nk', 'Teller'), ('Teller', 'oa', 'hält'), ('unter', 'mo', 'hält'), ('die', 'nk', 'Nase'), ('Nase', 'nk', 'unter'), ('.', 'punct', 'hält'), (')', 'punct', 'hält')]
# [('Straßer', 'ROOT', 'Straßer'), ('(', 'punct', 'schnuppernd'), ('unwillkürlich', 'mo', 'gierig'), ('gierig', 'mo', 'nach'), ('nach', 'mo', 'schnuppernd'), ('dem', 'nk', 'Speck'), ('Speck', 'nk', 'nach'), ('schnuppernd', 'par', 'Straßer'), (';', 'punct', 'Straßer')]
# [('dann', 'ROOT', 'dann'), (',', 'punct', 'dann'), ('mit', 'cj', 'dann'), ('erneuter', 'nk', 'Wut'), ('Wut', 'nk', 'mit'), (',', 'punct', 'laut'), ('sehr', 'mo', 'laut'), ('laut', 'par', 'dann'), (')', 'punct', 'laut'), ('.', 'punct', 'dann')]
# [('I', 'nk', 'brauch'), ('brauch', 'ROOT', 'brauch'), ('dein', 'nk', 'Speck'), ('Speck', 'oa', 'brauch'), ('nöt', 'mo', 'brauch'), ('!', 'punct', 'brauch')]
#
# → Satzstruktur für Dokument 100:
# [('Was', 'sb', "g'scheg'n"), ('is', 'uc', 'Was'), ('denn', 'mo', "g'scheg'n"), ('nur', 'mo', "g'scheg'n"), ("g'scheg'n", 'ROOT', "g'scheg'n"), ('?', 'punct', "g'scheg'n")]
# [('Straßer', 'sb', 'kann'), ('(', 'punct', 'kann'), ('kann', 'ROOT', 'kann'), ('vor', 'mo', 'kann'), ('Wut', 'nk', 'vor'), ('nicht', 'ng', 'kann'), ('sprechen', 'oc', 'kann'), (',', 'punct', 'schüttelt'), ('schüttelt', 'cj', 'kann'), ('sich', 'oa', 'schüttelt'), ('nur', 'mo', 'schüttelt'), ('wie', 'cm', 'Vogel'), ('ein', 'nk', 'Vogel'), ('böser', 'nk', 'Vogel'), ('Vogel', 'mo', 'schüttelt'), ('und', 'cd', 'Vogel'), ('kräht', 'cj', 'und'), (',', 'punct', 'schüttelt'), ('noch', 'mo', 'schriller'), ('schriller', 'cj', 'schüttelt'), (')', 'punct', 'kann'), ('.', 'punct', 'kann')]
# [('Hähä', 'ROOT', 'Hähä'), ('!', 'punct', 'Hähä')]

# %%
def finde_typische_strukturen(df, zielwort):
    typische_saetze = []
    for idx, row in df.iterrows():
        text = row['full_text']
        if pd.isna(text) or not text.strip(): 
            continue
        doc = nlp(text)
        for sent in doc.sents:

            if any(token.text.lower() == zielwort.lower() for token in sent):
                struktur = [(t.text, t.dep_, t.head.text) for t in sent]
                typische_saetze.append(struktur)
            if len(typische_saetze) >= 5:  
                return typische_saetze
    return typische_saetze

korporen_info = [
    ("Zeitung – Freude", zeitungskorpora_freude, "Freude"),
    ("Zeitung – Wut", zeitungskorpora_wut, "Wut"),
    ("Web – Freude", webkorpora_freude, "Freude"),
    ("Web – Wut", webkorpora_wut, "Wut"),
    ("Meta – Freude", metakorpora_freude, "Freude"),
    ("Meta – Wut", metakorpora_wut, "Wut")
]

for name, df, zielwort in korporen_info:
    print(f"\n=== Typische Satzstrukturen: {name} ===\n")
    beispiele = finde_typische_strukturen(df, zielwort)
    if beispiele:
        for i, satz in enumerate(beispiele, 1):
            print(f"→ Beispiel {i}: {satz}")
    else:
        print("Keine typischen Strukturen gefunden.")
# Out:
# === Typische Satzstrukturen: Zeitung – Freude ===
#
# → Beispiel 1: [('Sie', 'sb', 'werden'), ('werden', 'ROOT', 'werden'), ('sehen', 'oc', 'werden'), (',', 'punct', 'sehen'), ('wie', 'mo', 'macht'), ('viel', 'nk', 'Freude'), ('Freude', 'sb', 'macht'), ('es', 'sb', 'macht'), ('macht', 'oc', 'sehen'), (',', 'punct', 'macht'), ('wenn', 'cp', 'geht'), ('man', 'sb', 'geht'), ('Schritt', 'oa', 'geht'), ('für', 'mnr', 'Schritt'), ('Schritt', 'nk', 'für'), ('voran', 'mo', 'geht'), ('geht', 'mo', 'macht'), ('.', 'punct', 'werden')]
# → Beispiel 2: [('Die', 'nk', 'Eislauf-Familie'), ('ganze', 'nk', 'Eislauf-Familie'), ('deutsche', 'nk', 'Eislauf-Familie'), ('Eislauf-Familie', 'sb', 'weiß'), ('weiß', 'ROOT', 'weiß'), ('sich', 'oa', 'weiß'), ('angesichts', 'mo', 'weiß'), ('des', 'nk', 'Dokuments'), ('kleinen', 'nk', 'Dokuments'), (',', 'punct', 'kleinen'), ('roten', 'cj', 'kleinen'), ('Dokuments', 'nk', 'angesichts'), ('mit', 'mnr', 'Dokuments'), ('Bundesadler', 'nk', 'mit'), ('vor', 'mo', 'weiß'), ('Freude', 'nk', 'vor'), ('kaum', 'mo', 'fassen'), ('zu', 'pm', 'fassen'), ('fassen', 'oc', 'weiß'), (',', 'punct', 'weiß'), ('doch', 'cd', 'weiß'), ('er', 'sb', 'beantwortet'), ('beantwortet', 'cj', 'doch'), ('die', 'nk', 'Frage'), ('Frage', 'oa', 'beantwortet'), (',', 'punct', 'Frage'), ('was', 'sb', 'werde'), ('sich', 'oa', 'ändern'), ('nach', 'mo', 'ändern'), ('der', 'nk', 'Einbürgerung'), ('Einbürgerung', 'nk', 'nach'), ('seiner', 'nk', 'Partnerin'), ('Partnerin', 'ag', 'Einbürgerung'), ('Aljona', 'pnc', 'Sawtschenko'), ('Sawtschenko', 'nk', 'Partnerin'), ('ändern', 'oc', 'werde'), ('werde', 'oc', 'Frage'), (',', 'punct', 'werde'), ('mit', 'mo', 'beantwortet'), ('den', 'nk', 'Worten'), ('Worten', 'nk', 'mit'), (':', 'punct', 'beantwortet')]
# → Beispiel 3: [('Meine', 'nk', 'Motivation'), ('Motivation', 'pd', 'ist'), ('ist', 'oc', 'sagt'), ('die', 'nk', 'Freude'), ('Freude', 'sb', 'ist'), ('am', 'mnr', 'Freude'), ('Springen', 'nk', 'am'), ('"', 'punct', 'ist'), ('"', 'punct', 'ist'), (',', 'punct', 'sagt'), ('sagt', 'ROOT', 'sagt'), ('Martin', 'pnc', 'Schmitt'), ('Schmitt', 'sb', 'sagt'), (':', 'punct', 'sagt')]
# → Beispiel 4: [('Sie', 'sb', 'werden'), ('werden', 'ROOT', 'werden'), ('sehen', 'oc', 'werden'), (',', 'punct', 'sehen'), ('wie', 'mo', 'macht'), ('viel', 'nk', 'Freude'), ('Freude', 'sb', 'macht'), ('es', 'sb', 'macht'), ('macht', 'oc', 'sehen'), (',', 'punct', 'macht'), ('wenn', 'cp', 'geht'), ('man', 'sb', 'geht'), ('Schritt', 'oa', 'geht'), ('für', 'mnr', 'Schritt'), ('Schritt', 'nk', 'für'), ('voran', 'mo', 'geht'), ('geht', 'mo', 'macht'), ('.', 'punct', 'werden')]
# → Beispiel 5: [('Es', 'ep', 'gibt'), ('gibt', 'ROOT', 'gibt'), ('bei', 'mo', 'gibt'), ('Heiner', 'pnc', 'Müller'), ('Müller', 'nk', 'bei'), ('auch', 'mo', 'gibt'), ('so', 'mo', 'etwas'), ('etwas', 'oa', 'gibt'), ('wie', 'cm', 'Vergnügen'), ('das', 'nk', 'Vergnügen'), ('Vergnügen', 'cc', 'etwas'), ('am', 'mnr', 'Vergnügen'), ('Bösen', 'nk', 'am'), (',', 'punct', 'gibt'), ('die', 'nk', 'Freude'), ('Freude', 'cj', 'gibt'), (',', 'punct', 'Freude'), ('es', 'oa', 'anschauen'), ('anschauen', 'oc', 'Freude'), (',', 'punct', 'anschauen'), ('es', 'oa', 'porträtieren'), ('porträtieren', 'oc', 'können'), ('zu', 'pm', 'können'), ('können', 're', 'es'), (',', 'punct', 'gibt'), ('eine', 'nk', 'Faszination'), ('eigentümliche', 'nk', 'Faszination'), ('Faszination', 'oa', 'gibt'), (',', 'punct', 'Faszination'), ('ohne', 'cp', 'ist'), ('die', 'nk', 'Erkenntnis'), ('Erkenntnis', 'sb', 'ist'), ('nicht', 'ng', 'ist'), ('möglich', 'pd', 'ist'), ('ist', 'rc', 'Faszination'), ('.', 'punct', 'gibt')]
#
# === Typische Satzstrukturen: Zeitung – Wut ===
#
# → Beispiel 1: [('Jetzt', 'mo', 'könnte'), ('könnte', 'ROOT', 'könnte'), ('es', 'sb', 'könnte'), ('losgehen', 'oc', 'könnte'), (',', 'punct', 'könnte'), ('aber', 'cd', 'könnte'), ('mit', 'cj', 'aber'), ('Lust', 'nk', 'mit'), ('und', 'cd', 'Lust'), ('Kraft', 'cj', 'und'), ('und', 'cd', 'Kraft'), ('Wut', 'cj', 'und'), ('.', 'punct', 'könnte')]
# → Beispiel 2: [('Amedeo', 'pnc', 'Carboni'), ('Carboni', 'sb', 'bekommt'), ('vom', 'mnr', 'Carboni'), ('FC', 'pnc', 'Valencia'), ('Valencia', 'nk', 'vom'), (',', 'punct', 'Carboni'), ('18', 'nk', 'Mal'), ('Mal', 'mo', 'Nationalspieler'), ('italienischer', 'nk', 'Nationalspieler'), ('Nationalspieler', 'app', 'Carboni'), (',', 'punct', 'Nationalspieler'), ('zweimal', 'mo', 'Champions-League-Finalist'), ('Champions-League-Finalist', 'cj', 'Nationalspieler'), (',', 'punct', 'Nationalspieler'), ('ein', 'nk', 'Verteidiger'), ('linker', 'nk', 'Verteidiger'), ('Verteidiger', 'cj', 'Nationalspieler'), ('mit', 'mnr', 'Verteidiger'), ('Schnelligkeit', 'nk', 'mit'), ('und', 'cd', 'Schnelligkeit'), ('Wut', 'cj', 'und'), (',', 'punct', 'bekommt'), ('bekommt', 'ROOT', 'bekommt'), ('seit', 'mo', 'bekommt'), ('sechs', 'nk', 'Jahren'), ('Jahren', 'nk', 'seit'), ('jede', 'nk', 'Saison'), ('Saison', 'oa', 'bekommt'), ('wieder', 'mo', 'bekommt'), ('nur', 'mo', 'Einjahresvertrag'), ('einen', 'nk', 'Einjahresvertrag'), ('Einjahresvertrag', 'oa', 'bekommt'), (',', 'punct', 'bekommt'), ('weil', 'cp', 'glauben'), ('die', 'nk', 'Verantwortlichen'), ('Verantwortlichen', 'sb', 'glauben'), ('in', 'mo', 'glauben'), ('Valencia', 'nk', 'in'), ('glauben', 'mo', 'bekommt'), (',', 'punct', 'glauben'), ('es', 'sb', 'sei'), ('sei', 'oc', 'glauben'), ('seine', 'nk', 'letzte'), ('letzte', 'pd', 'sei'), ('.', 'punct', 'bekommt')]
# → Beispiel 3: [('Da', 'mo', 'ist'), ('ist', 'ROOT', 'ist'), ('Wut', 'sb', 'ist'), ('auf', 'mo', 'ist'), ('jeden', 'nk', 'Fall'), ('Fall', 'nk', 'auf'), ('die', 'nk', 'Antriebskraft'), ('bessere', 'nk', 'Antriebskraft'), ('Antriebskraft', 'pd', 'ist'), ('als', 'mo', 'ist'), ('Wehmut', 'nk', 'als'), ('.', 'punct', 'ist')]
# → Beispiel 4: [('Sentiment', 'sb', 'gehen'), ('und', 'cd', 'Sentiment'), ('Selbstanalyse', 'cj', 'und'), (',', 'punct', 'Sentiment'), ('Wut', 'cj', 'Selbstanalyse'), ('und', 'cd', 'Wut'), ('Witz', 'cj', 'und'), ('gehen', 'ROOT', 'gehen'), ('gut', 'mo', 'gehen'), ('zusammen', 'svp', 'gehen'), ('.', 'punct', 'gehen')]
# → Beispiel 5: [('Wut', 'ROOT', 'Wut'), ('bei', 'mnr', 'Wut'), ('Kalle', 'nk', 'bei'), ('.', 'punct', 'Wut')]
#
# === Typische Satzstrukturen: Web – Freude ===
#
# → Beispiel 1: [('Liebhaber', 'sb', 'werden'), ('des', 'nk', 'Western'), ('Western', 'ag', 'Liebhaber'), (',', 'punct', 'Western'), ('Folk', 'cj', 'Western'), ('und', 'cd', 'Folk'), ('Blues', 'cj', 'und'), ('werden', 'ROOT', 'werden'), ('ihre', 'nk', 'Freude'), ('Freude', 'oa', 'haben'), ('daran', 'mo', 'haben'), ('haben', 'oc', 'werden'), ('.', 'punct', 'werden')]
# → Beispiel 2: [('Eine', 'nk', 'Romanze'), ('historische', 'nk', 'Romanze'), ('Romanze', 'sb', 'verbinden'), ('1966″.', 'nk', 'Romanze'), ('in', 'mnr', 'Romanze'), ('seinen', 'nk', 'gedichten'), ('gedichten', 'nk', 'in'), ('verbinden', 'ROOT', 'verbinden'), ('sich', 'oa', 'verbinden'), ('kürze', 'mo', 'verbinden'), (',', 'punct', 'kürze'), ('witz', 'cj', 'kürze'), (',', 'punct', 'kürze'), ('poetisches', 'nk', 'gespür'), ('gespür', 'cj', 'witz'), ('und', 'cd', 'gespür'), ('die', 'nk', 'freude'), ('unbändige', 'nk', 'freude'), ('freude', 'cj', 'und'), ('an', 'mnr', 'freude'), ('neuen', 'nk', 'erfahrungen'), ('erfahrungen', 'nk', 'an'), ('zu', 'mnr', 'freude'), ('sprachlichen', 'nk', 'ereignissen'), ('ereignissen', 'nk', 'zu'), (',', 'punct', 'ereignissen'), ('in', 'mo', 'wird'), ('denen', 'nk', 'in'), ('das', 'nk', 'staunen'), ('staunen', 'sb', 'wird'), ('über', 'mnr', 'staunen'), ('die', 'nk', 'liebe'), ('liebe', 'nk', 'über'), (',', 'punct', 'liebe'), ('die', 'nk', 'welt'), ('welt', 'cj', 'liebe'), (',', 'punct', 'welt'), ('die', 'nk', 'literatur'), ('literatur', 'cj', 'welt'), ('und', 'cd', 'literatur'), ('die', 'nk', 'möglichkeiten'), ('möglichkeiten', 'cj', 'und'), ('des', 'nk', 'schreibens'), ('schreibens', 'ag', 'möglichkeiten'), ('erfahrbar', 'pd', 'wird'), ('wird', 'rc', 'ereignissen'), ('.', 'punct', 'verbinden')]
# → Beispiel 3: [('die', 'nk', 'freude'), ('unbändige', 'nk', 'freude'), ('freude', 'ROOT', 'freude'), ('daran', 'op', 'freude'), (',', 'punct', 'daran'), ('sich', 'oa', 'überraschen'), ('durch', 'mo', 'überraschen'), ('schreiben', 'nk', 'durch'), ('selbst', 'mnr', 'schreiben'), ('zu', 'pm', 'überraschen'), ('überraschen', 're', 'daran'), (',', 'punct', 'herauszufinden'), ('schreibend', 'mo', 'herauszufinden'), ('herauszufinden', 'oc', 'freude'), (',', 'punct', 'herauszufinden'), ('wie', 'mo', 'macht'), ('man', 'sb', 'macht'), ('was', 'oa', 'macht'), ('mit', 'mo', 'macht'), ('sprache', 'nk', 'mit'), ('macht', 'mo', 'freude'), (',', 'punct', 'macht'), ('während', 'cp', 'vermittelt'), ('sie', 'sb', 'vermittelt'), ('was', 'sb', 'vermittelt'), ('mit', 'mo', 'vermittelt'), ('einem', 'nk', 'macht'), ('macht', 'nk', 'mit'), (',', 'punct', 'vermittelt'), ('vermittelt', 'mo', 'macht'), ('sich', 'oa', 'vermittelt'), ('in', 'mo', 'vermittelt'), ('jedem', 'nk', 'in'), ('seiner', 'nk', 'gedichte'), ('gedichte', 'ag', 'jedem'), ('.', 'punct', 'freude')]
# → Beispiel 4: [('Eine', 'nk', 'Romanze'), ('historische', 'nk', 'Romanze'), ('Romanze', 'sb', 'verbinden'), ('1966″.', 'nk', 'Romanze'), ('in', 'mnr', 'Romanze'), ('seinen', 'nk', 'gedichten'), ('gedichten', 'nk', 'in'), ('verbinden', 'ROOT', 'verbinden'), ('sich', 'oa', 'verbinden'), ('kürze', 'mo', 'verbinden'), (',', 'punct', 'kürze'), ('witz', 'cj', 'kürze'), (',', 'punct', 'kürze'), ('poetisches', 'nk', 'gespür'), ('gespür', 'cj', 'witz'), ('und', 'cd', 'gespür'), ('die', 'nk', 'freude'), ('unbändige', 'nk', 'freude'), ('freude', 'cj', 'und'), ('an', 'mnr', 'freude'), ('neuen', 'nk', 'erfahrungen'), ('erfahrungen', 'nk', 'an'), ('zu', 'mnr', 'freude'), ('sprachlichen', 'nk', 'ereignissen'), ('ereignissen', 'nk', 'zu'), (',', 'punct', 'ereignissen'), ('in', 'mo', 'wird'), ('denen', 'nk', 'in'), ('das', 'nk', 'staunen'), ('staunen', 'sb', 'wird'), ('über', 'mnr', 'staunen'), ('die', 'nk', 'liebe'), ('liebe', 'nk', 'über'), (',', 'punct', 'liebe'), ('die', 'nk', 'welt'), ('welt', 'cj', 'liebe'), (',', 'punct', 'welt'), ('die', 'nk', 'literatur'), ('literatur', 'cj', 'welt'), ('und', 'cd', 'literatur'), ('die', 'nk', 'möglichkeiten'), ('möglichkeiten', 'cj', 'und'), ('des', 'nk', 'schreibens'), ('schreibens', 'ag', 'möglichkeiten'), ('erfahrbar', 'pd', 'wird'), ('wird', 'rc', 'ereignissen'), ('.', 'punct', 'verbinden')]
# → Beispiel 5: [('die', 'nk', 'freude'), ('unbändige', 'nk', 'freude'), ('freude', 'ROOT', 'freude'), ('daran', 'op', 'freude'), (',', 'punct', 'daran'), ('sich', 'oa', 'überraschen'), ('durch', 'mo', 'überraschen'), ('schreiben', 'nk', 'durch'), ('selbst', 'mnr', 'schreiben'), ('zu', 'pm', 'überraschen'), ('überraschen', 're', 'daran'), (',', 'punct', 'herauszufinden'), ('schreibend', 'mo', 'herauszufinden'), ('herauszufinden', 'oc', 'freude'), (',', 'punct', 'herauszufinden'), ('wie', 'mo', 'macht'), ('man', 'sb', 'macht'), ('was', 'oa', 'macht'), ('mit', 'mo', 'macht'), ('sprache', 'nk', 'mit'), ('macht', 'mo', 'freude'), (',', 'punct', 'macht'), ('während', 'cp', 'vermittelt'), ('sie', 'sb', 'vermittelt'), ('was', 'sb', 'vermittelt'), ('mit', 'mo', 'vermittelt'), ('einem', 'nk', 'macht'), ('macht', 'nk', 'mit'), (',', 'punct', 'vermittelt'), ('vermittelt', 'mo', 'macht'), ('sich', 'oa', 'vermittelt'), ('in', 'mo', 'vermittelt'), ('jedem', 'nk', 'in'), ('seiner', 'nk', 'gedichte'), ('gedichte', 'ag', 'jedem'), ('.', 'punct', 'freude')]
#
# === Typische Satzstrukturen: Web – Wut ===
#
# → Beispiel 1: [('In', 'ROOT', 'In'), ('Niedersachsens', 'ag', 'Bergen'), ('Bergen', 'nk', 'In'), (',', 'punct', 'Bergen'), ('An', 'app', 'Bergen'), ('Niedersachsens', 'ag', 'Wut'), ('Wut', 'nk', 'An')]
# → Beispiel 2: [('Mehr', 'nk', 'Wut'), ('Wut', 'ROOT', 'Wut')]
# → Beispiel 3: [('Mehr', 'nk', 'Wut'), ('Wut', 'ROOT', 'Wut')]
# → Beispiel 4: [('Mehr', 'nk', 'Wut'), ('Wut', 'ROOT', 'Wut')]
# → Beispiel 5: [('Mehr', 'nk', 'Wut'), ('Wut', 'ROOT', 'Wut')]
#
# === Typische Satzstrukturen: Meta – Freude ===
#
# → Beispiel 1: [('Diese', 'nk', 'Schüler'), ('Schüler', 'sb', 'sind'), ('sind', 'ROOT', 'sind'), ('ein', 'nk', 'Glück'), ('reines', 'nk', 'Glück'), ('Glück', 'pd', 'sind'), ('in', 'mnr', 'Glück'), ('doppelter', 'nk', 'Beziehung'), ('Beziehung', 'nk', 'in'), (':', 'punct', 'sind'), ('einmal', 'mo', 'im'), ('im', 'mo', 'sind'), ('Sinne', 'nk', 'im'), ('von', 'pg', 'Sinne'), ('reiner', 'nk', 'Freude'), ('Freude', 'nk', 'von'), (',', 'punct', 'im'), ('wie', 'mo', 'entwickelt'), ('sie', 'sb', 'haben'), ('sich', 'oa', 'entwickelt'), ('entwickelt', 'oc', 'haben'), ('haben', 'mo', 'im'), ('und', 'cd', 'haben'), ('noch', 'mo', 'entwickeln'), ('entwickeln', 'cj', 'und'), (';', 'punct', 'sind')]
# → Beispiel 2: [('Eine', 'nk', 'Freude'), ('reine', 'nk', 'Freude'), ('Freude', 'ROOT', 'Freude'), (',', 'punct', 'Freude'), ('wenn', 'cp', 'klagte'), ('er', 'sb', 'klagte'), ('auch', 'mo', 'mir'), ('mir', 'da', 'klagte'), ('gegenüber', 'mo', 'klagte'), ('eigentlich', 'mo', 'klagte'), ('zum', 'mo', 'klagte'), ('ersten', 'nk', 'Male'), ('Male', 'nk', 'zum'), ('über', 'mo', 'klagte'), ('sein', 'nk', 'Alter'), ('Alter', 'nk', 'über'), ('klagte', 'mnr', 'Freude'), ('.', 'punct', 'Freude')]
# → Beispiel 3: [('Wirklich', 'mo', 'klug'), ('klug', 'ROOT', 'klug'), ('und', 'cd', 'klug'), ('ausgewogen', 'cj', 'und'), ('im', 'mo', 'ausgewogen'), ('Urteil', 'nk', 'im'), (',', 'punct', 'klug'), ('eine', 'nk', 'Freude'), ('reine', 'nk', 'Freude'), ('Freude', 'cj', 'klug'), ('!', 'punct', 'klug')]
# → Beispiel 4: [('welche', 'nk', 'Freude'), ('Freude', 're', 'so'), (',', 'punct', 'Freude'), ('daß', 'cp', 'weiterarbeitet'), ('er', 'sb', 'weiterarbeitet'), ('mutig', 'mo', 'weiterarbeitet'), ('weiterarbeitet', 'oc', 'Freude'), (',', 'punct', 'so'), ('so', 'ROOT', 'so'), ('wie', 'cm', 'gehört'), ('es', 'ep', 'gehört'), ('sich', 'oa', 'gehört'), ('für', 'op', 'gehört'), ('einen', 'nk', 'Wissenschaftler'), ('Wissenschaftler', 'nk', 'für'), ('gehört', 'cc', 'so'), ('-', 'punct', 'so'), ('ganz', 'mo', 'gleich'), ('gleich', 'mo', 'so'), (',', 'punct', 'gleich'), ('was', 'sb', 'hat'), ('für', 'mo', 'gemacht'), ('Fehler', 'nk', 'für'), ('er', 'sb', 'hat'), ('gemacht', 'oc', 'hat'), ('hat', 'rc', 'so'), (',', 'punct', 'hat'), ('ganz', 'mo', 'gleich'), ('gleich', 'mo', 'geht'), ('auch', 'mo', 'geht'), (',', 'punct', 'geht'), ('wenn', 'cp', 'geht'), ('die', 'nk', 'Kritik'), ('Kritik', 'sb', 'geht'), ('zu', 'mo', 'weit'), ('weit', 'mo', 'geht'), ('geht', 'cj', 'hat'), ('oder', 'cd', 'geht'), ('im', 'mo', 'ungerecht'), ('einzelnen', 'nk', 'im'), ('ungerecht', 'pd', 'ist'), ('ist', 'cj', 'oder'), ('.', 'punct', 'so')]
# → Beispiel 5: [('13', 'nk', '*'), ('*', 'ROOT', '*'), ('5.57', 'nk', 'Las'), ('Las', 'nk', '*'), ('mit', 'mnr', 'Las'), ('Freude', 'nk', 'mit'), ('den', 'nk', 'Roman'), ('Roman', 'oa', '*'), ('von', 'pg', 'Roman'), ('Inge', 'pnc', 'Wangenheim'), ('Wangenheim', 'nk', 'von'), ('über', 'mnr', 'Roman'), ('den', 'nk', 'Juni'), ('17.', 'nk', 'Juni'), ('Juni', 'nk', 'über'), ('.', 'punct', '*')]
#
# === Typische Satzstrukturen: Meta – Wut ===
#
# → Beispiel 1: [('Der', 'nk', 'Direktor'), ('Direktor', 'sb', 'sagte'), ('des', 'nk', 'Wirtschaftsinstituts'), ('Wirtschaftsinstituts', 'ag', 'Direktor'), ('sagte', 'ROOT', 'sagte'), ('mir', 'da', 'sagte'), ('dort', 'mo', 'sagte'), (',', 'punct', 'sagte'), ('daß', 'cp', 'versteht'), ('meine', 'nk', 'Man'), ('Man', 'sb', 'versteht'), ('versteht', 'oc', 'sagte'), ('auoh', 'mo', 'versteht'), ('die', 'nk', 'Berichte'), ('alten', 'nk', 'Berichte'), ('Berichte', 'oa', 'versteht'), ('der', 'nk', 'Ordensbrüder'), ('Ordensbrüder', 'ag', 'Berichte'), ('über', 'mnr', 'Berichte'), ('China', 'nk', 'über'), ('jetzt', 'mo', 'versteht'), ('so', 'mo', 'viel'), ('viel', 'mo', 'besser'), ('besser', 'mo', 'versteht'), (',', 'punct', 'versteht'), ('ihre', 'nk', 'Wut'), ('gräßliche', 'nk', 'Wut'), ('Wut', 'oa', 'versteht'), ('auf', 'mnr', 'Wut'), ('die', 'nk', 'Schönheiten'), ('"', 'punct', 'barbarischen'), ('"', 'punct', 'barbarischen'), ('barbarischen', 'nk', 'Schönheiten'), ('"', 'punct', 'barbarischen'), ('"', 'punct', 'barbarischen'), ('Schönheiten', 'nk', 'auf'), (',', 'punct', 'Schönheiten'), ('die', 'oa', 'entdeckten'), ('sie', 'sb', 'entdeckten'), ('hier', 'mo', 'entdeckten'), ('entdeckten', 'rc', 'Schönheiten'), ('und', 'cd', 'entdeckten'), ('welche', 'oa', 'überwältigten'), ('die', 'nk', 'Mönche'), ('armen', 'nk', 'Mönche'), ('Mönche', 'sb', 'überwältigten'), ('trotz', 'mo', 'überwältigten'), ('all', 'nk', 'Gebete'), ('ihrer', 'nk', 'Gebete'), ('Gebete', 'nk', 'trotz'), ('immer', 'mo', 'wieder'), ('wieder', 'mo', 'überwältigten'), ('überwältigten', 'cj', 'und'), ('*', 'punct', 'sagte')]
# → Beispiel 2: [('Fritz', 'sb', 'trinkt'), ('trinkt', 'ROOT', 'trinkt'), ('wieder', 'mo', 'trinkt'), ('stärker', 'mo', 'trinkt'), (',', 'punct', 'trinkt'), ('andere', 'sb', 'sind'), ('sind', 'cj', 'trinkt'), ('bitterzynisch', 'pd', 'sind'), ('bis', 'cd', 'bitterzynisch'), ('dorthinaus', 'cj', 'bis'), (',', 'punct', 'dorthinaus'), ('andere', 'cj', 'dorthinaus'), (',', 'punct', 'dorthinaus'), ('besonders', 'mo', 'an'), ('an', 'mo', 'Bürger'), ('sich', 'nk', 'an'), ('anständige', 'nk', 'Bürger'), ('Bürger', 'cj', 'andere'), (',', 'punct', 'sind'), ('koohen', 'cj', 'sind'), ('vor', 'op', 'koohen'), ('Wut', 'nk', 'vor'), (',', 'punct', 'sind'), ('und', 'cd', 'sind'), ('die', 'nk', 'Leistungen'), ('wissenschaftlichen', 'nk', 'Leistungen'), ('Leistungen', 'sb', 'werden'), ('werden', 'cj', 'und'), ('sich', 'oa', 'verbessern'), ('unter', 'mo', 'verbessern'), ('diesen', 'nk', 'Umständen'), ('Umständen', 'nk', 'unter'), ('kaum', 'mo', 'verbessern'), ('verbessern', 'oc', 'werden'), ('.', 'punct', 'trinkt')]
# → Beispiel 3: [('und', 'ju', 'begann'), ('begann', 'ROOT', 'begann'), ('ihn', 'oa', 'begann'), ('mit', 'mo', 'begann'), ('der', 'nk', 'Wut'), ('gleichen', 'nk', 'Wut'), ('Wut', 'nk', 'mit'), ('zur', 'mnr', 'Wut'), ('Ordnung', 'nk', 'zur'), ('des', 'nk', 'Freude'), ('falls', 'mo', 'Freude'), ('große', 'nk', 'Freude'), ('Freude', 'ag', 'Ordnung'), (',', 'punct', 'begann'), ('Begann', 'cj', 'begann'), ('heute', 'mo', 'Begann'), ('Bd.3', 'pd', 'Begann'), (',', 'punct', 'Bd.3'), ('Kapitel', 'cj', 'Bd.3'), ('3', 'nk', 'Kapitel'), (',', 'punct', 'Begann'), ('den', 'nk', 'Abschnitt'), ('Abschnitt', 'oa', 'Gedanken'), ('bei', 'mnr', 'Abschnitt'), ('meinen', 'nk', 'Studien'), ('"', 'punct', 'Studien'), ('"', 'punct', 'Studien'), ('Studien', 'nk', 'bei'), ('"', 'punct', 'Studien'), ('"', 'punct', 'Studien'), ('noch', 'mo', 'Gedanken'), ('neue', 'nk', 'Gedanken'), ('Gedanken', 'oa', 'begann'), ('?', 'punct', 'begann')]
# → Beispiel 4: [('Weniger', 'nk', 'Hirasen'), ('Hirasen', 'ROOT', 'Hirasen'), (',', 'punct', 'Hirasen'), ('weniger', 'nk', 'Heuchelei'), ('Heuchelei', 'cj', 'Hirasen'), (',', 'punct', 'Hirasen'), ('mehr', 'nk', 'Selbstkritik'), ('Selbstkritik', 'cj', 'Hirasen'), ('-', 'punct', 'Hirasen'), ('ach', 'mo', 'Hirasen'), (',', 'punct', 'Hirasen'), ('welche', 'nk', 'Wut'), ('Wut', 'oa', 'hat'), ('hätte', 'oc', 'Hirasen'), ('Lenin', 'sb', 'hätte'), (',', 'punct', 'hätte'), ('wenn', 'cp', 'sähe'), ('er', 'sb', 'sähe'), ('sähe', 'mo', 'hätte'), (',', 'punct', 'sähe'), ('was', 'oa', 'gemacht'), ('man', 'sb', 'hat'), ('aus', 'mo', 'gemacht'), ('den', 'nk', 'Parteien'), ('Parteien', 'nk', 'aus'), (',', 'punct', 'gemacht'), ('aus', 'mo', 'gemacht'), ('der', 'nk', 'Gesellschaft'), ('Gesellschaft', 'nk', 'aus'), ('gemacht', 'oc', 'hat'), ('hat', 'oc', 'sähe'), (',', 'punct', 'hat'), ('wie', 'mo', 'verkommen'), ('verkommen', 'mo', 'sähe'), ('alles', 'sb', 'ist'), ('ist', 'cj', 'hätte'), ('auf', 'mo', 'bringen'), ('der', 'nk', 'Basis'), ('so', 'mo', 'unendlioh'), ('unendlioh', 'mo', 'gesunden'), ('gesunden', 'nk', 'Basis'), ('Basis', 'nk', 'auf'), ('des', 'nk', 'Sozialismus'), ('Sozialismus', 'ag', 'Basis'), (',', 'punct', 'Sozialismus'), ('die', 'sb', 'erlaubt'), ('selbst', 'mo', 'erlaubt'), ('einer', 'nk', 'Häufung'), ('Häufung', 'da', 'erlaubt'), ('von', 'pg', 'Häufung'), ('Mittelmäßigkeiten', 'nk', 'von'), ('erlaubt', 'rc', 'Sozialismus'), (',', 'punct', 'Basis'), ('uns', 'oa', 'bringen'), ('auf', 'mo', 'bringen'), ('vielen', 'nk', 'Gebieten'), ('Gebieten', 'nk', 'auf'), ('vorwärts', 'mo', 'bringen'), ('zu', 'pm', 'bringen'), ('bringen', 'oc', 'ist'), ('.', 'punct', 'Hirasen')]
# → Beispiel 5: [('Er', 'sb', 'erzählte'), ('erzählte', 'ROOT', 'erzählte'), ('mir', 'da', 'erzählte'), (',', 'punct', 'erzählte'), ('er', 'sb', 'hätte'), ('hätte', 'oc', 'erzählte'), ('gerade', 'mo', 'wieder'), ('wieder', 'mo', 'gehört'), ('von', 'op', 'gehört'), ('einem', 'nk', 'Beispiel'), ('so', 'mo', 'ekelhaften'), ('ekelhaften', 'nk', 'Beispiel'), ('Beispiel', 'nk', 'von'), ('des', 'nk', 'Antisemitismus'), ('Antisemitismus', 'ag', 'Beispiel'), ('in', 'mnr', 'Antisemitismus'), ('der', 'nk', 'Sowjetunion'), ('Sowjetunion', 'nk', 'in'), ('gehört', 'oc', 'hätte'), ('und', 'cd', 'gehört'), ('daraufhin', 'mo', 'geschrieben'), ('einen', 'nk', 'Artikel'), ('allgemeinen', 'nk', 'Artikel'), ('Artikel', 'oa', 'geschrieben'), ('gegen', 'mnr', 'Artikel'), ('Rassismus', 'nk', 'gegen'), ('voller', 'mo', 'geschrieben'), ('Wut', 'nk', 'voller'), ('geschrieben', 'cj', 'und'), ('.', 'punct', 'erzählte')]

# %%
import spacy
from collections import Counter

nlp = spacy.load("de_core_news_sm")

def dep_stats(df, zielwort):
    rollen = []
    verben = []
    
    zielwort_clean = zielwort.lower()
    
    for idx, row in df.iterrows():
        text = row['full_text']
        if pd.isna(text) or not text.strip():  # Pomija NaN oraz puste teksty
            continue
        doc = nlp(text)
        
        for token in doc:
            if token.text.lower() == zielwort_clean:  # Porównanie z oczyszczonym słowem kluczowym
                if token.dep_ and token.head:  # Sprawdzamy, czy token ma head i dep_
                    rollen.append(token.dep_)
                    verben.append(token.head.lemma_)
                    
    return Counter(rollen).most_common(5), Counter(verben).most_common(5)  # Top 5

korporen_info = [
    ("Zeitung – Freude", zeitungskorpora_freude, "Freude"),
    ("Zeitung – Wut", zeitungskorpora_wut, "Wut"),
    ("Web – Freude", webkorpora_freude, "Freude"),
    ("Web – Wut", webkorpora_wut, "Wut"),
    ("Meta – Freude", metakorpora_freude, "Freude"),
    ("Meta – Wut", metakorpora_wut, "Wut")
]

for name, df, zielwort in korporen_info:
    print(f"\n=== Syntaktische Rollen und Verben: {name} ===")
    rollen, verben = dep_stats(df, zielwort)
    print("Häufigste syntaktische Rollen:", rollen)
    print("Häufigste Verben (Kopf):", verben)
# Out:
# === Syntaktische Rollen und Verben: Zeitung – Freude ===
# Häufigste syntaktische Rollen: [('nk', 26), ('sb', 25), ('oa', 22), ('pd', 6), ('cj', 4)]
# Häufigste Verben (Kopf): [('sein', 11), ('haben', 10), ('machen', 6), ('zu', 6), ('mit', 5)]
#
# === Syntaktische Rollen und Verben: Zeitung – Wut ===
# Häufigste syntaktische Rollen: [('sb', 30), ('nk', 23), ('oa', 23), ('cj', 16), ('pd', 3)]
# Häufigste Verben (Kopf): [('sein', 16), ('vor', 7), ('und', 6), ('werden', 5), ('mit', 4)]
#
# === Syntaktische Rollen und Verben: Web – Freude ===
# Häufigste syntaktische Rollen: [('nk', 21), ('oa', 20), ('sb', 15), ('cj', 14), ('pd', 8)]
# Häufigste Verben (Kopf): [('sein', 13), ('und', 11), ('haben', 10), ('machen', 6), ('zu', 6)]
#
# === Syntaktische Rollen und Verben: Web – Wut ===
# Häufigste syntaktische Rollen: [('nk', 31), ('oa', 23), ('sb', 15), ('cj', 11), ('ROOT', 8)]
# Häufigste Verben (Kopf): [('sein', 9), ('Wut', 8), ('vor', 7), ('in', 6), ('mit', 6)]
#
# === Syntaktische Rollen und Verben: Meta – Freude ===
# Häufigste syntaktische Rollen: [('nk', 28), ('oa', 22), ('pd', 21), ('ROOT', 13), ('sb', 8)]
# Häufigste Verben (Kopf): [('sein', 22), ('mit', 18), ('Freude', 13), ('haben', 9), ('machen', 7)]
#
# === Syntaktische Rollen und Verben: Meta – Wut ===
# Häufigste syntaktische Rollen: [('nk', 54), ('cj', 14), ('oa', 11), ('sb', 11), ('ag', 6)]
# Häufigste Verben (Kopf): [('in', 22), ('vor', 12), ('sein', 7), ('und', 7), ('mit', 5)]

# %%
import pandas as pd
from collections import Counter
import spacy
from IPython.display import display

nlp = spacy.load("de_core_news_sm")

def dep_stats(df, zielwort):
    rollen = []
    verben = []
    for idx, row in df.iterrows():
        text = str(row['full_text'])  
        if pd.isna(text) or not text.strip():  
            continue
        doc = nlp(text)
        for token in doc:
            if token.text.lower() == zielwort.lower():
                if token.head:  
                    rollen.append(token.dep_)
                    verben.append(token.head.lemma_)
    return Counter(rollen).most_common(5), Counter(verben).most_common(5)

korpora = [
    (zeitungskorpora_freude, "Freude", "Zeitung – Freude"),
    (zeitungskorpora_wut, "Wut", "Zeitung – Wut"),
    (webkorpora_freude, "Freude", "Web – Freude"),
    (webkorpora_wut, "Wut", "Web – Wut"),
    (metakorpora_freude, "Freude", "Meta – Freude"),
    (metakorpora_wut, "Wut", "Meta – Wut")
]

ergebnisse = []

for df, zielwort, name in korpora:
    rollen, verben = dep_stats(df, zielwort)
    rollen_str = ", ".join([r[0] for r in rollen])
    verben_str = ", ".join([v[0] for v in verben])
    ergebnisse.append({
        "Korpus": name,
        "Zielwort": zielwort,
        "Häufigste Rollen": rollen_str,
        "Häufigste Verben": verben_str
    })

tabelle = pd.DataFrame(ergebnisse)

print(tabelle)

tabelle.to_excel("syntaktische_strukturen.xlsx", index=False)

ergebnisse_df = pd.DataFrame(ergebnisse)

display(ergebnisse_df)
# Out:
#              Korpus Zielwort      Häufigste Rollen  \
# 0  Zeitung – Freude   Freude    nk, sb, oa, pd, cj
# 1     Zeitung – Wut      Wut    sb, nk, oa, cj, pd
# 2      Web – Freude   Freude    nk, oa, sb, cj, pd
# 3         Web – Wut      Wut  nk, oa, sb, cj, ROOT
# 4     Meta – Freude   Freude  nk, oa, pd, ROOT, sb
# 5        Meta – Wut      Wut    nk, cj, oa, sb, ag
#
#                    Häufigste Verben
# 0      sein, haben, machen, zu, mit
# 1       sein, vor, und, werden, mit
# 2      sein, und, haben, machen, zu
# 3           sein, Wut, vor, in, mit
# 4  sein, mit, Freude, haben, machen
# 5           in, vor, sein, und, mit
#              Korpus Zielwort      Häufigste Rollen  \
# 0  Zeitung – Freude   Freude    nk, sb, oa, pd, cj
# 1     Zeitung – Wut      Wut    sb, nk, oa, cj, pd
# 2      Web – Freude   Freude    nk, oa, sb, cj, pd
# 3         Web – Wut      Wut  nk, oa, sb, cj, ROOT
# 4     Meta – Freude   Freude  nk, oa, pd, ROOT, sb
# 5        Meta – Wut      Wut    nk, cj, oa, sb, ag
#
#                    Häufigste Verben
# 0      sein, haben, machen, zu, mit
# 1       sein, vor, und, werden, mit
# 2      sein, und, haben, machen, zu
# 3           sein, Wut, vor, in, mit
# 4  sein, mit, Freude, haben, machen
# 5           in, vor, sein, und, mit

# %%
import matplotlib.pyplot as plt

def plot_single(ax, counter, title):
    if len(counter) > 0:
        words, counts = zip(*counter.most_common(10))
        ax.barh(words, counts, color='skyblue')
        ax.invert_yaxis()
    ax.set_title(title, fontsize=10)
    ax.set_xlabel('Häufigkeit')

fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

datasets = [
    (freude_counter_zeitung, 'Freude - Zeitungskorpora'),
    (freude_counter_web, 'Freude - Webkorpora'),
    (freude_counter_meta, 'Freude - Metakorpora'),
    (wut_counter_zeitung, 'Wut - Zeitungskorpora'),
    (wut_counter_web, 'Wut - Webkorpora'),
    (wut_counter_meta, 'Wut - Metakorpora'),
]

for ax, (counter, title) in zip(axes, datasets):
    plot_single(ax, counter, title)

plt.tight_layout()
plt.show()

# %% [markdown]
# ![image.png](attachment:1431327b-148d-425d-9bd7-bc671ac05350.png)

# %%
def describe_collocations(counter, target_word, corpus_name):
    if len(counter) == 0:
        return f"Im Korpus {corpus_name} wurden keine Kollokationen für das Wort '{target_word}' gefunden.\n"
    
    most_common_word, most_common_count = counter.most_common(1)[0]
    total_collocations = sum(counter.values())
    unique_collocations = len(counter)
    
    description = (
        f"Im Korpus {corpus_name} für das Wort '{target_word}':\n"
        f"- Häufigste Kollokation: '{most_common_word}' ({most_common_count} Vorkommen)\n"
        f"- Gesamtzahl der Kollokationen: {total_collocations}\n"
        f"- Anzahl der einzigartigen Kollokationen: {unique_collocations}\n"
    )
    return description

print(describe_collocations(freude_counter_zeitung, 'Freude', 'Zeitungskorpora'))
print(describe_collocations(freude_counter_web, 'Freude', 'Webkorpora'))
print(describe_collocations(freude_counter_meta, 'Freude', 'Metakorpora'))

print(describe_collocations(wut_counter_zeitung, 'Wut', 'Zeitungskorpora'))
print(describe_collocations(wut_counter_web, 'Wut', 'Webkorpora'))
print(describe_collocations(wut_counter_meta, 'Wut', 'Metakorpora'))
# Out:
# Im Korpus Zeitungskorpora für das Wort 'Freude':
# - Häufigste Kollokation: 'gerne' (5 Vorkommen)
# - Gesamtzahl der Kollokationen: 527
# - Anzahl der einzigartigen Kollokationen: 445
#
# Im Korpus Webkorpora für das Wort 'Freude':
# - Häufigste Kollokation: 'immer' (7 Vorkommen)
# - Gesamtzahl der Kollokationen: 815
# - Anzahl der einzigartigen Kollokationen: 658
#
# Im Korpus Metakorpora für das Wort 'Freude':
# - Häufigste Kollokation: 'große' (17 Vorkommen)
# - Gesamtzahl der Kollokationen: 957
# - Anzahl der einzigartigen Kollokationen: 677
#
# Im Korpus Zeitungskorpora für das Wort 'Wut':
# - Häufigste Kollokation: 'wut' (8 Vorkommen)
# - Gesamtzahl der Kollokationen: 947
# - Anzahl der einzigartigen Kollokationen: 746
#
# Im Korpus Webkorpora für das Wort 'Wut':
# - Häufigste Kollokation: 'mehr' (26 Vorkommen)
# - Gesamtzahl der Kollokationen: 918
# - Anzahl der einzigartigen Kollokationen: 674
#
# Im Korpus Metakorpora für das Wort 'Wut':
# - Häufigste Kollokation: 'angst' (10 Vorkommen)
# - Gesamtzahl der Kollokationen: 1009
# - Anzahl der einzigartigen Kollokationen: 810

# %%
import pandas as pd
from collections import Counter

def describe_collocations(counter, target_word, corpus_name):
    if len(counter) == 0:
        return f"Im Korpus {corpus_name} wurden keine Kollokationen für das Wort '{target_word}' gefunden.\n"
    
    most_common_word, most_common_count = counter.most_common(1)[0]
    total_collocations = sum(counter.values())
    unique_collocations = len(counter)
    
    description = (
        f"Im Korpus {corpus_name} für das Wort '{target_word}':\n"
        f"- Häufigste Kollokation: '{most_common_word}' ({most_common_count} Vorkommen)\n"
        f"- Gesamtzahl der Kollokationen: {total_collocations}\n"
        f"- Anzahl der einzigartigen Kollokationen: {unique_collocations}\n"
    )
    
    data = {
        "Korpus": [corpus_name],
        "Zielwort": [target_word],
        "Häufigste Kollokation": [most_common_word],
        "Vorkommen der häufigsten Kollokation": [most_common_count],
        "Gesamtzahl der Kollokationen": [total_collocations],
        "Einzigartige Kollokationen": [unique_collocations]
    }
    
    df = pd.DataFrame(data)
    return df

results = []

results.append(describe_collocations(freude_counter_zeitung, 'Freude', 'Zeitungskorpora'))
results.append(describe_collocations(freude_counter_web, 'Freude', 'Webkorpora'))
results.append(describe_collocations(freude_counter_meta, 'Freude', 'Metakorpora'))

results.append(describe_collocations(wut_counter_zeitung, 'Wut', 'Zeitungskorpora'))
results.append(describe_collocations(wut_counter_web, 'Wut', 'Webkorpora'))
results.append(describe_collocations(wut_counter_meta, 'Wut', 'Metakorpora'))

final_df = pd.concat(results, ignore_index=True)

import IPython.display as display
display.display(final_df)
# Out:
#             Korpus Zielwort Häufigste Kollokation  \
# 0  Zeitungskorpora   Freude                 gerne
# 1       Webkorpora   Freude                 immer
# 2      Metakorpora   Freude                 große
# 3  Zeitungskorpora      Wut                   wut
# 4       Webkorpora      Wut                  mehr
# 5      Metakorpora      Wut                 angst
#
#    Vorkommen der häufigsten Kollokation  Gesamtzahl der Kollokationen  \
# 0                                     5                           527
# 1                                     7                           815
# 2                                    17                           957
# 3                                     8                           947
# 4                                    26                           918
# 5                                    10                          1009
#
#    Einzigartige Kollokationen
# 0                         445
# 1                         658
# 2                         677
# 3                         746
# 4                         674
# 5                         810

# %%
import pandas as pd
import spacy
from gensim.models import Word2Vec

nlp = spacy.load("de_core_news_sm")

def tokenize_text(text):
    doc = nlp(text)
    return [token.text for token in doc if not token.is_stop and not token.is_punct]

freude_tokens_zeitung = [tokenize_text(text) for text in zeitungskorpora_freude['full_text'] if pd.notna(text)]
wut_tokens_zeitung = [tokenize_text(text) for text in zeitungskorpora_wut['full_text'] if pd.notna(text)]

freude_tokens_web = [tokenize_text(text) for text in webkorpora_freude['full_text'] if pd.notna(text)]
wut_tokens_web = [tokenize_text(text) for text in webkorpora_wut['full_text'] if pd.notna(text)]

freude_tokens_meta = [tokenize_text(text) for text in metakorpora_freude['full_text'] if pd.notna(text)]
wut_tokens_meta = [tokenize_text(text) for text in metakorpora_wut['full_text'] if pd.notna(text)]

all_sentences = (
    freude_tokens_zeitung + wut_tokens_zeitung + 
    freude_tokens_web + wut_tokens_web + 
    freude_tokens_meta + wut_tokens_meta
)

model = Word2Vec(sentences=all_sentences, vector_size=100, window=5, min_count=1, workers=4)

model.save("word2vec_gefühlswörter_all_korpora.model")

model = Word2Vec.load("word2vec_gefühlswörter_all_korpora.model")

similarity = model.wv.similarity('freude', 'wut')
print(f"Ähnlichkeit zwischen 'Freude' und 'Wut': {similarity}")
print()

similar_words_freude = model.wv.most_similar("freude", topn=10)
print("Die ähnlichsten Wörter zu 'Freude':", similar_words_freude)

similar_words_wut = model.wv.most_similar("wut", topn=10)
print("Die ähnlichsten Wörter zu 'Wut':", similar_words_wut)

for word in ['freude', 'wut']:
    similar_words = model.wv.most_similar(word, topn=10)
    print(f"\nDie ähnlichsten Wörter zu '{word}':")
    for similar_word, score in similar_words:
        print(f"{similar_word}: {score}")

similarity_results = {
    "Wort 1": ["Freude"],
    "Wort 2": ["Wut"],
    "Ähnlichkeit": [similarity]
}

similarity_df = pd.DataFrame(similarity_results)

freude_similar_df = pd.DataFrame(similar_words_freude, columns=["Wort", "Ähnlichkeit"])
wut_similar_df = pd.DataFrame(similar_words_wut, columns=["Wort", "Ähnlichkeit"])

import IPython.display as display
display.display(similarity_df)
display.display(freude_similar_df)
display.display(wut_similar_df)
# Out:
# Ähnlichkeit zwischen 'Freude' und 'Wut': 0.08471697568893433
#
# Die ähnlichsten Wörter zu 'Freude': [('groben', 0.37131163477897644), ('Beginn', 0.3673641085624695), ('XV', 0.34243786334991455), ('Produkte', 0.32539504766464233), ('Berliner', 0.32503002882003784), ('vorangehenden', 0.32358965277671814), ('sorgte', 0.3212592601776123), ('dooh', 0.31882423162460327), ('Ben', 0.3145856261253357), ('absolvierten', 0.3120967447757721)]
# Die ähnlichsten Wörter zu 'Wut': [('auffällig', 0.35545602440834045), ('natür-', 0.3508092761039734), ('genießen', 0.34392136335372925), ('Debatte', 0.3418525755405426), ('welch', 0.31080514192581177), ('prüften', 0.3104100525379181), ('krähend', 0.303971529006958), ('Klenner', 0.3028464615345001), ('prägnante', 0.3020091950893402), ('zentrifugale', 0.2981407642364502)]
#
# Die ähnlichsten Wörter zu 'freude':
# groben: 0.37131163477897644
# Beginn: 0.3673641085624695
# XV: 0.34243786334991455
# Produkte: 0.32539504766464233
# Berliner: 0.32503002882003784
# vorangehenden: 0.32358965277671814
# sorgte: 0.3212592601776123
# dooh: 0.31882423162460327
# Ben: 0.3145856261253357
# absolvierten: 0.3120967447757721
#
# Die ähnlichsten Wörter zu 'wut':
# auffällig: 0.35545602440834045
# natür-: 0.3508092761039734
# genießen: 0.34392136335372925
# Debatte: 0.3418525755405426
# welch: 0.31080514192581177
# prüften: 0.3104100525379181
# krähend: 0.303971529006958
# Klenner: 0.3028464615345001
# prägnante: 0.3020091950893402
# zentrifugale: 0.2981407642364502
#    Wort 1 Wort 2  Ähnlichkeit
# 0  Freude    Wut     0.084717
#             Wort  Ähnlichkeit
# 0         groben     0.371312
# 1         Beginn     0.367364
# 2             XV     0.342438
# 3       Produkte     0.325395
# 4       Berliner     0.325030
# 5  vorangehenden     0.323590
# 6         sorgte     0.321259
# 7           dooh     0.318824
# 8            Ben     0.314586
# 9   absolvierten     0.312097
#            Wort  Ähnlichkeit
# 0     auffällig     0.355456
# 1        natür-     0.350809
# 2      genießen     0.343921
# 3       Debatte     0.341853
# 4         welch     0.310805
# 5       prüften     0.310410
# 6       krähend     0.303972
# 7       Klenner     0.302846
# 8     prägnante     0.302009
# 9  zentrifugale     0.298141

# %%
import pandas as pd
import spacy
from gensim.models import Word2Vec

nlp = spacy.load("de_core_news_sm")

def tokenize_text(text):
    doc = nlp(text)
    return [token.text.lower() for token in doc if not token.is_stop and not token.is_punct]  # Zamień na małe litery

freude_tokens_zeitung = [tokenize_text(text) for text in zeitungskorpora_freude['full_text'] if pd.notna(text)]
wut_tokens_zeitung = [tokenize_text(text) for text in zeitungskorpora_wut['full_text'] if pd.notna(text)]

freude_tokens_web = [tokenize_text(text) for text in webkorpora_freude['full_text'] if pd.notna(text)]
wut_tokens_web = [tokenize_text(text) for text in webkorpora_wut['full_text'] if pd.notna(text)]

freude_tokens_meta = [tokenize_text(text) for text in metakorpora_freude['full_text'] if pd.notna(text)]
wut_tokens_meta = [tokenize_text(text) for text in metakorpora_wut['full_text'] if pd.notna(text)]

all_sentences = (
    freude_tokens_zeitung + wut_tokens_zeitung + 
    freude_tokens_web + wut_tokens_web + 
    freude_tokens_meta + wut_tokens_meta
)

model = Word2Vec(sentences=all_sentences, vector_size=100, window=5, min_count=1, workers=4)

model.save("word2vec_gefühlswörter_all_korpora.model")

model = Word2Vec.load("word2vec_gefühlswörter_all_korpora.model")

for word in model.wv.index_to_key:  # Przeszukujemy cały słownik modelu
    similar_words = model.wv.most_similar(word, topn=5)  # Wybieramy 5 najbliższych słów
    print(f"\nDie ähnlichsten Wörter zu '{word}':")
    for similar_word, score in similar_words:
        print(f"{similar_word}: {score}")
# Out:
# Die ähnlichsten Wörter zu 'wut':
# echter: 0.3571051061153412
# sozialistische: 0.35408586263656616
# roben: 0.3369213938713074
# aufkreuzen: 0.3202259838581085
# 2.7.1960: 0.30998238921165466
#
# Die ähnlichsten Wörter zu 'freude':
# blasse: 0.4435151517391205
# erfahrbar: 0.39191097021102905
# vorschiebt: 0.35555991530418396
# 1945: 0.3522130846977234
# ärgern: 0.3503384292125702
#
# Die ähnlichsten Wörter zu 'sehen':
# offenbar: 0.3841521739959717
# schlafende: 0.37906891107559204
# methode: 0.3326440155506134
# ausführlich: 0.3265351355075836
# stereotypen: 0.3246028423309326
#
# Die ähnlichsten Wörter zu 'menschen':
# jüngerer: 0.36538684368133545
# aufgeschreckt: 0.35008054971694946
# weiterer: 0.3251602351665497
# brüdern: 0.32201823592185974
# neuanfang: 0.31517094373703003
#
# Die ähnlichsten Wörter zu 'mal':
# sexuellen: 0.38486000895500183
# fühlens: 0.33222460746765137
# bodensatz: 0.3229331076145172
# gebracht: 0.3186211585998535
# vermindert: 0.31307050585746765
#
# Die ähnlichsten Wörter zu 'leben':
# mail: 0.3534422814846039
# innenstadt: 0.3433711528778076
# wisch: 0.32475605607032776
# skorpione: 0.3245038390159607
# realität: 0.3231581449508667
#
# Die ähnlichsten Wörter zu 'angst':
# schreiben: 0.3472990095615387
# beklemmenden: 0.3421737849712372
# anatole: 0.3289117217063904
# homepage: 0.313599169254303
# 26.1.: 0.3101176917552948
#
# Die ähnlichsten Wörter zu 'fast':
# partie: 0.33402392268180847
# duft: 0.33317095041275024
# lehrmaterial: 0.32506293058395386
# verliebt: 0.31410762667655945
# angefordert: 0.31379610300064087
#
# Die ähnlichsten Wörter zu 'welt':
# feuerwehren: 0.34313422441482544
# lie: 0.3381207585334778
# instituts: 0.3328045904636383
# ernst: 0.3285835385322571
# clevere: 0.30643364787101746
#
# Die ähnlichsten Wörter zu 'liebe':
# leid: 0.3781343102455139
# entgötterten: 0.3635985255241394
# symbol: 0.33379149436950684
# fruchtbarer: 0.3210342824459076
# herausgearbeitet: 0.3078564703464508
#
# Die ähnlichsten Wörter zu ' ':
# echter: 0.34848764538764954
# todesszenen: 0.33474278450012207
# elektronischem: 0.3230689764022827
# ritter: 0.3141704797744751
# absehbar: 0.3076847791671753
#
# Die ähnlichsten Wörter zu 'weg':
# zärtlich: 0.3666342496871948
# entfernt: 0.343321830034256
# vorgelegt: 0.3318829834461212
# offenbar: 0.32774025201797485
# witzig: 0.32437950372695923
#
# Die ähnlichsten Wörter zu 'lassen':
# gewaltakten: 0.3506080210208893
# zivilbevölkerung: 0.34937506914138794
# qualitäten: 0.34503045678138733
# ärgere: 0.3366193175315857
# spritz: 0.332943856716156
#
# Die ähnlichsten Wörter zu 'feinde':
# parat: 0.33574676513671875
# angegriffen: 0.33059561252593994
# verharmlosten: 0.32832252979278564
# astronomische: 0.3204236328601837
# brewing: 0.31380823254585266
#
# Die ähnlichsten Wörter zu 'frau':
# vorsatz: 0.35642552375793457
# qualität: 0.34382501244544983
# freundlich: 0.33812665939331055
# pakistanischen: 0.33306071162223816
# servolenkung: 0.3326753079891205
#
# Die ähnlichsten Wörter zu 'artikel':
# 77.: 0.40050646662712097
# angeketet: 0.38842862844467163
# pflegen: 0.35438287258148193
# unberechtigt: 0.34174472093582153
# entschieden: 0.3361315131187439
#
# Die ähnlichsten Wörter zu 'geschichte':
# tatsachen: 0.3940671980381012
# direktor: 0.3537667691707611
# freiheiten: 0.3388988673686981
# worte: 0.32581865787506104
# unbedingt: 0.3020499646663666
#
# Die ähnlichsten Wörter zu 'band':
# bewarfen: 0.3467522859573364
# menschlich: 0.32637467980384827
# konflikt: 0.32373473048210144
# muzaffarabad: 0.31927862763404846
# konzentration: 0.3136151134967804
#
# Die ähnlichsten Wörter zu 'mutter':
# womöglich: 0.33488187193870544
# bänden: 0.32601094245910645
# wütend: 0.3207961916923523
# ball: 0.3065987825393677
# kunst: 0.3053032457828522
#
# Die ähnlichsten Wörter zu 'alten':
# starken: 0.3526794910430908
# grühden: 0.33107462525367737
# dier: 0.32431647181510925
# andererseits: 0.3237653970718384
# gefordert: 0.31820398569107056
#
# Die ähnlichsten Wörter zu 'buch':
# setze: 0.3492129445075989
# fassadengestaltungen: 0.3382096290588379
# aufblähend: 0.337552547454834
# sichtliche: 0.3215157985687256
# aufweisen: 0.3196561634540558
#
# Die ähnlichsten Wörter zu '2':
# bevölkerung: 0.34772592782974243
# nikaragua: 0.3462863266468048
# kleider: 0.33011266589164734
# user: 0.3278241753578186
# arbeitslosigkeit: 0.3248053193092346
#
# Die ähnlichsten Wörter zu 'zorn':
# gerichtsbeamten: 0.3712005615234375
# bauernkriege: 0.35736343264579773
# gepeinigt: 0.3493998646736145
# mittragen: 0.3350750207901001
# at: 0.31909459829330444
#
# Die ähnlichsten Wörter zu 'ioh':
# anstieg: 0.33718085289001465
# schmissig: 0.3326679468154907
# einheitsübersetzung: 0.33157479763031006
# person: 0.33061084151268005
# militanten: 0.31899046897888184
#
# Die ähnlichsten Wörter zu 'hand':
# stern: 0.4031265079975128
# zweifellos: 0.3581727147102356
# lautete: 0.34992483258247375
# umschlagen: 0.33429521322250366
# herausgibt: 0.3318369388580322
#
# Die ähnlichsten Wörter zu 'arbeit':
# sodann: 0.3662828505039215
# völkerrechts: 0.35438501834869385
# einsam: 0.3158645033836365
# routine: 0.31265026330947876
# nazi-regimes: 0.3056737184524536
#
# Die ähnlichsten Wörter zu 'sagen':
# aufdrehten: 0.35883551836013794
# osten: 0.3342970907688141
# wenigen: 0.3196556270122528
# brahms: 0.31091567873954773
# verführer: 0.306613564491272
#
# Die ähnlichsten Wörter zu 'waffen':
# fürchten: 0.4046083390712738
# rechenmaschine: 0.3766036331653595
# unerreichbar: 0.3569391369819641
# jugendliche: 0.3487444221973419
# repräsentanten: 0.3472801446914673
#
# Die ähnlichsten Wörter zu 'gefühl':
# ^: 0.34725773334503174
# knarren: 0.33924177289009094
# jemals: 0.3366858959197998
# überleben: 0.3308561146259308
# bürokratien: 0.3306470215320587
#
# Die ähnlichsten Wörter zu 'grund':
# co.: 0.363040566444397
# folgende: 0.3248726427555084
# überlegung: 0.31189921498298645
# biographien: 0.3086225390434265
# aufziehen: 0.30705496668815613
#
# Die ähnlichsten Wörter zu 'reine':
# icc: 0.33865341544151306
# gemütlich: 0.3350553810596466
# gehorchen: 0.32671913504600525
# loswerden: 0.31827130913734436
# exzessive: 0.31100571155548096
#
# Die ähnlichsten Wörter zu 'einfach':
# wittbrodt: 0.42768633365631104
# 18.9.1976: 0.37767329812049866
# beurteilung: 0.36706218123435974
# kontakt: 0.35952284932136536
# aufzuwachsen: 0.3443146049976349
#
# Die ähnlichsten Wörter zu 'vater':
# clevere: 0.4051806628704071
# grellgrünes: 0.3543170988559723
# 32: 0.3479764759540558
# information: 0.33403241634368896
# hieb: 0.3206901550292969
#
# Die ähnlichsten Wörter zu 'letzten':
# hörte: 0.41357743740081787
# nyt: 0.3702794909477234
# geschieht: 0.36868467926979065
# volkskundler: 0.3538469076156616
# 18,34: 0.35041341185569763
#
# Die ähnlichsten Wörter zu 'details':
# brus: 0.3526083827018738
# tagung: 0.33940601348876953
# vorsitzenden: 0.33783382177352905
# voraussetzung: 0.33626261353492737
# 30.1.1959: 0.3274349868297577
#
# Die ähnlichsten Wörter zu 'geben':
# genannt: 0.3637748956680298
# dehnt: 0.3298293352127075
# gegenzug: 0.31233319640159607
# widerte: 0.311723917722702
# gestürmt: 0.3102508783340454
#
# Die ähnlichsten Wörter zu 'kraft':
# wien: 0.3682750165462494
# trinken: 0.36427393555641174
# gelehrte: 0.34656205773353577
# ursachen: 0.32823270559310913
# ror: 0.32319438457489014
#
# Die ähnlichsten Wörter zu 'schreiben':
# bitteren: 0.3676864206790924
# bau: 0.36135026812553406
# antun: 0.35233229398727417
# angst: 0.3472990095615387
# routine: 0.3441629707813263
#
# Die ähnlichsten Wörter zu 'freuden':
# mittag: 0.3637237846851349
# zufall: 0.32418495416641235
# reinhold: 0.31991878151893616
# unerbittlichen: 0.31842154264450073
# theokratie: 0.3178539574146271
#
# Die ähnlichsten Wörter zu 'situation':
# thalheim: 0.39739707112312317
# zurückgerissen: 0.33624503016471863
# treibt: 0.3348141014575958
# ritter: 0.3231073021888733
# dergleichen: 0.3227740526199341
#
# Die ähnlichsten Wörter zu '1':
# berufung: 0.4173126220703125
# einzelne: 0.3473711907863617
# anreizsystem: 0.34712523221969604
# herfielen: 0.3350405991077423
# verspielten: 0.3307911455631256
#
# Die ähnlichsten Wörter zu 'levels':
# zimmer: 0.40010935068130493
# landen: 0.3504604697227478
# maler: 0.3467842638492584
# dreißig: 0.3395825922489166
# enthüllen: 0.3331281840801239
#
# Die ähnlichsten Wörter zu 'weiß':
# gehenden: 0.3873850107192993
# putin: 0.3829854428768158
# allgemein: 0.3571109175682068
# manager: 0.3501075506210327
# versichern: 0.34567803144454956
#
# Die ähnlichsten Wörter zu 'wissen':
# brauch: 0.3794634938240051
# wünschens: 0.34830442070961
# bürokratien: 0.33623555302619934
# botschafterin: 0.3126518726348877
# grandioser: 0.3119005560874939
#
# Die ähnlichsten Wörter zu 'art':
# wissenschaftlern: 0.35444146394729614
# shaw: 0.3481055796146393
# meldung: 0.34635138511657715
# losschlägt: 0.3410395681858063
# laut: 0.33972135186195374
#
# Die ähnlichsten Wörter zu 'all':
# mietverhältnis: 0.36974844336509705
# kalle: 0.32771188020706177
# dunkelheit: 0.3211981952190399
# tv-kanäle: 0.3188732862472534
# unerläßlichen: 0.31838521361351013
#
# Die ähnlichsten Wörter zu 'kinder':
# wirksame: 0.3706314265727997
# herumgepeitscht: 0.3658192455768585
# rett-mädchen: 0.3498612642288208
# verändert: 0.33470121026039124
# übermaßes: 0.3110303282737732
#
# Die ähnlichsten Wörter zu 'akademie':
# ausreichend: 0.3842396140098572
# herz: 0.35202494263648987
# seihe: 0.35169968008995056
# landen: 0.3135850727558136
# winter: 0.312298059463501
#
# Die ähnlichsten Wörter zu 'spiel':
# gedichten: 0.38298094272613525
# medaille: 0.3809329867362976
# schönen: 0.3682094216346741
# abels: 0.36542433500289917
# interessen: 0.33701926469802856
#
# Die ähnlichsten Wörter zu 'augen':
# komik: 0.38733193278312683
# bildern: 0.33738061785697937
# winters: 0.332993745803833
# erscheinet: 0.32552996277809143
# durchsetzte: 0.32024288177490234
#
# Die ähnlichsten Wörter zu 'manchmal':
# hardtke: 0.37312957644462585
# wirr: 0.3685055673122406
# ausliehen: 0.35873711109161377
# törring: 0.35692301392555237
# tropischen: 0.3557967245578766
#
# Die ähnlichsten Wörter zu 'thema':
# teilhaben: 0.3508300483226776
# gedacht: 0.3320312798023224
# entscheidenden: 0.33164796233177185
# aufziehen: 0.3233758509159088
# weg: 0.3223873972892761
#
# Die ähnlichsten Wörter zu 'sieht':
# elektronischem: 0.3590490520000458
# angeforderte: 0.34263888001441956
# mitzunehmen: 0.3405453562736511
# äußerlich: 0.3401208221912384
# feder: 0.3297688066959381
#
# Die ähnlichsten Wörter zu 'trauer':
# verstimmung: 0.3982618451118469
# sonnabende: 0.3889246881008148
# gesetzesseite: 0.37316131591796875
# bas: 0.3642429709434509
# tieres: 0.35406163334846497
#
# Die ähnlichsten Wörter zu 'mitarbeiter':
# fabians: 0.4439593553543091
# urgesunde: 0.3704901337623596
# intro: 0.3704274594783783
# gefeiert: 0.35015836358070374
# knast: 0.3381847143173218
#
# Die ähnlichsten Wörter zu 'deutschen':
# langt: 0.3638416826725006
# peagan: 0.3283390402793884
# empfehle: 0.3197632133960724
# ehe: 0.3173646032810211
# donnerstag: 0.30559590458869934
#
# Die ähnlichsten Wörter zu 'gott':
# herder: 0.36292827129364014
# wunderbaren: 0.3540317416191101
# wodurch: 0.3254241943359375
# le: 0.3237910568714142
# scheiden: 0.3228728473186493
#
# Die ähnlichsten Wörter zu 'liegt':
# gerissen: 0.3469890058040619
# besim: 0.32880544662475586
# richtiger: 0.3255474269390106
# antifa”-chauvinisten: 0.32367053627967834
# verspür: 0.31028711795806885
#
# Die ähnlichsten Wörter zu 'genau':
# west-berlin: 0.341668963432312
# dramen: 0.3310096561908722
# freimaurer: 0.3242138624191284
# unbändiger: 0.32208847999572754
# brille: 0.3216650187969208
#
# Die ähnlichsten Wörter zu 'herr':
# karl: 0.3490750193595886
# silvio: 0.3283471167087555
# gekühlt: 0.32551753520965576
# evo: 0.3225436806678772
# psychologin: 0.32201212644577026
#
# Die ähnlichsten Wörter zu 'gestern':
# abgestimmt: 0.35899752378463745
# verlauf: 0.35322239995002747
# gebrochen: 0.3388756811618805
# fußballfunktionären: 0.33668801188468933
# wladimir: 0.3361063003540039
#
# Die ähnlichsten Wörter zu 'woche':
# pc: 0.34464842081069946
# verlosch: 0.33367636799812317
# blonde: 0.32849687337875366
# reich: 0.3212197721004486
# begrüßten: 0.31463298201560974
#
# Die ähnlichsten Wörter zu 'partei':
# wehe: 0.34337544441223145
# automaten: 0.3381321132183075
# netzsperrengesetz: 0.3360257148742676
# rechtsextremer: 0.32322514057159424
# verneinenden: 0.3188648223876953
#
# Die ähnlichsten Wörter zu 'sprach':
# gedacht: 0.4358936846256256
# m.: 0.39169129729270935
# stolz: 0.3557252883911133
# geschöpf: 0.33780667185783386
# trotz: 0.33390942215919495
#
# Die ähnlichsten Wörter zu 'bauch':
# mittwoch: 0.3643566966056824
# wahllos: 0.33956027030944824
# anzuhören: 0.33776748180389404
# wünschenswert: 0.325153112411499
# gelüste: 0.3051481246948242
#
# Die ähnlichsten Wörter zu 'laut':
# neidisch: 0.3680865466594696
# eislauf-familie: 0.36294054985046387
# art: 0.33972132205963135
# entsinne: 0.33504965901374817
# werdegang: 0.33311927318573
#
# Die ähnlichsten Wörter zu 'politische':
# unserem: 0.35977789759635925
# informationen: 0.3560484051704407
# ausgabe: 0.33731892704963684
# diskutiert: 0.3285006284713745
# gebärde: 0.31005969643592834
#
# Die ähnlichsten Wörter zu 'glaube':
# wächter: 0.3511444330215454
# leute: 0.34501296281814575
# nächste: 0.3200010359287262
# geheime: 0.3196624219417572
# leidenden: 0.3179744482040405
#
# Die ähnlichsten Wörter zu 'offenbar':
# sehen: 0.38415220379829407
# gekonnte: 0.37524935603141785
# stereotypen: 0.344068318605423
# doppelt: 0.3411671817302704
# weg: 0.32774025201797485
#
# Die ähnlichsten Wörter zu '5':
# irgendwo: 0.42301109433174133
# tor: 0.3167228698730469
# zuckt: 0.31040096282958984
# labilität: 0.3100990355014801
# völkerrechts: 0.30891910195350647
#
# Die ähnlichsten Wörter zu 'mann':
# sekretariats: 0.31458184123039246
# nehme: 0.3104064464569092
# beurteilt: 0.2973056435585022
# psyche: 0.29392048716545105
# entarteter: 0.2923955023288727
#
# Die ähnlichsten Wörter zu 'bringen':
# gewitter: 0.3594159185886383
# lache: 0.3432249426841736
# übersetzung: 0.3379294276237488
# clevere: 0.3342192471027374
# forellenfischen: 0.3269731402397156
#
# Die ähnlichsten Wörter zu 'eigentlich':
# staunen: 0.3783567547798157
# bitte: 0.35552313923835754
# aussprach: 0.3440706431865692
# hirn: 0.3327804207801819
# aggressiven: 0.3317767381668091
#
# Die ähnlichsten Wörter zu 'gehört':
# genervtsein: 0.33581408858299255
# anschauen: 0.32750406861305237
# leben: 0.31495845317840576
# beauftragte: 0.3142243027687073
# lacht: 0.31145262718200684
#
# Die ähnlichsten Wörter zu 'lesen':
# institute: 0.37577319145202637
# sozialkritische: 0.3664214015007019
# ausgabe: 0.3426418900489807
# dezimierten: 0.34130120277404785
# sitzend: 0.3106342554092407
#
# Die ähnlichsten Wörter zu 'genossen':
# offener: 0.39146170020103455
# amerikanischen: 0.357417494058609
# ^ig: 0.3371742367744446
# mikrofon: 0.3361978232860565
# flatterfedern: 0.33569467067718506
#
# Die ähnlichsten Wörter zu 'gerne':
# lyrik: 0.3860056400299072
# versammelt: 0.3749905526638031
# schwingend: 0.3286094069480896
# weltsituation: 0.32166022062301636
# vizedom: 0.31850072741508484
#
# Die ähnlichsten Wörter zu 'bleibt':
# blauer: 0.3979613780975342
# borot: 0.3870839774608612
# poetisches: 0.31805089116096497
# meergras: 0.3142981231212616
# zukommen: 0.314089298248291
#
# Die ähnlichsten Wörter zu 'form':
# höre: 0.3455468416213989
# /bzö-regierung: 0.3429602384567261
# gebrüllt: 0.3398752212524414
# stattlichen: 0.3317149877548218
# gefahrvoller: 0.32980477809906006
#
# Die ähnlichsten Wörter zu 'stehen':
# lunoh: 0.37268516421318054
# unsicherheit: 0.3591286242008209
# unterricht: 0.3526564836502075
# begnügt: 0.33727529644966125
# schicksalen: 0.3311704695224762
#
# Die ähnlichsten Wörter zu 'volk':
# toll: 0.43864378333091736
# gelassen: 0.3635846674442291
# kirche: 0.36113524436950684
# textsicher: 0.35404086112976074
# josip: 0.3243364691734314
#
# Die ähnlichsten Wörter zu 'studien':
# tauchen: 0.3402632176876068
# wider: 0.3310004472732544
# mittwoch: 0.32819291949272156
# leningrad: 0.3266100287437439
# zuverlässigen: 0.3238101303577423
#
# Die ähnlichsten Wörter zu 'stand':
# roten: 0.3436099886894226
# zuschulden: 0.3304954171180725
# verve: 0.31846603751182556
# mülldeponie: 0.3147580027580261
# killen: 0.3139060139656067
#
# Die ähnlichsten Wörter zu 'geschrieben':
# schreite: 0.36813414096832275
# anklagend: 0.3337174952030182
# pym: 0.32830098271369934
# dancing: 0.3216628432273865
# sandberg: 0.3171795904636383
#
# Die ähnlichsten Wörter zu 'wiener':
# mitzuliefern: 0.3482767939567566
# superlativen: 0.3422119915485382
# buschwerk: 0.34064075350761414
# gewünscht: 0.3302466869354248
# revolte: 0.3262409567832947
#
# Die ähnlichsten Wörter zu 'abend':
# schriftstellerin: 0.39398759603500366
# anwenden: 0.36080485582351685
# gefüttert: 0.350106418132782
# kollwitz: 0.34778451919555664
# vieh: 0.34605783224105835
#
# Die ähnlichsten Wörter zu 'familie':
# beeindruckt: 0.347690224647522
# gedanke: 0.3424937129020691
# vollen: 0.326436847448349
# stressarmen: 0.3223873972892761
# for: 0.3143504559993744
#
# Die ähnlichsten Wörter zu 'blick':
# kolleginnen: 0.4280302822589874
# selbstgefühl: 0.36402350664138794
# sturm: 0.3409528434276581
# frieden: 0.3380906283855438
# gegangen: 0.33742275834083557
#
# Die ähnlichsten Wörter zu 'freud':
# informieren: 0.3773864805698395
# geldes: 0.3403024673461914
# entscheidenden: 0.3392513394355774
# betreibt: 0.32544830441474915
# tatverdächtige: 0.31475064158439636
#
# Die ähnlichsten Wörter zu 'selber':
# rappt: 0.3518795073032379
# richtiger: 0.35082754492759705
# schnippchen: 0.3197212517261505
# brüchen: 0.3173655867576599
# entscheidend: 0.309841126203537
#
# Die ähnlichsten Wörter zu 'leute':
# publizistik: 0.3855331838130951
# begleitet: 0.3656705617904663
# glaube: 0.34501296281814575
# speziell: 0.33155474066734314
# bewarfen: 0.33110037446022034
#
# Die ähnlichsten Wörter zu 'scheint':
# direktoren: 0.3417111337184906
# morde: 0.33660465478897095
# erfüllen: 0.33614325523376465
# radio: 0.3327084183692932
# alter: 0.33004823327064514
#
# Die ähnlichsten Wörter zu 'zeiten':
# jugend: 0.3907550573348999
# gedrängt: 0.319261372089386
# kräftig: 0.3178516924381256
# j.-p.sartre: 0.3111540973186493
# einwohner: 0.30543914437294006
#
# Die ähnlichsten Wörter zu 'schließlich':
# politökonomen: 0.42179128527641296
# dunklem: 0.33775097131729126
# kapitel: 0.3261072039604187
# höhere: 0.3192882239818573
# tieres: 0.3130108416080475
#
# Die ähnlichsten Wörter zu 'ließ':
# berührend: 0.34851720929145813
# unheimlichen: 0.3452853858470917
# deutschlands: 0.3291815519332886
# müllers: 0.32394230365753174
# mittelschweren: 0.31872591376304626
#
# Die ähnlichsten Wörter zu 'literatur':
# selten: 0.4189206659793854
# tische: 0.3717819154262543
# bandenkämpfe: 0.3474894165992737
# england: 0.32994452118873596
# doppelt: 0.32949748635292053
#
# Die ähnlichsten Wörter zu 'tief':
# gesteigerter: 0.40752336382865906
# ausgangsbedingungen: 0.3620496392250061
# bösen: 0.34751981496810913
# antanzen: 0.32255256175994873
# verwerflich: 0.3081493675708771
#
# Die ähnlichsten Wörter zu 'sterben':
# savoring: 0.3226555287837982
# pugwash-konferenz: 0.3173178434371948
# irgendwelchen: 0.31571707129478455
# allerlei: 0.3141634166240692
# gebietsabgabe: 0.3130374550819397
#
# Die ähnlichsten Wörter zu 'blut':
# begleiten: 0.347469687461853
# einzelnen: 0.33472365140914917
# beherrschte: 0.32380956411361694
# niederlanden: 0.31969478726387024
# hervorragt: 0.3195292055606842
#
# Die ähnlichsten Wörter zu 'wissenschaft':
# überzeugen: 0.3775504231452942
# komplizierten: 0.3519803285598755
# bemühe: 0.3421468138694763
# hs: 0.34012967348098755
# vergleichen: 0.3375607430934906
#
# Die ähnlichsten Wörter zu 'gefühle':
# empfohlen: 0.3551930785179138
# stichwort: 0.34636983275413513
# wandelt: 0.32837575674057007
# hahnenkämpfen: 0.32252588868141174
# informationssuche: 0.3110358417034149
#
# Die ähnlichsten Wörter zu 'frankreich':
# vorkommt: 0.3365583121776581
# unglück: 0.33184608817100525
# betreuer: 0.3228297233581543
# altermondialistes: 0.3141956627368927
# begleitet: 0.31249094009399414
#
# Die ähnlichsten Wörter zu 'superheld':
# feststellst: 0.36210131645202637
# triebneigungen: 0.35981449484825134
# gekostet: 0.3592735826969147
# nutzen: 0.35878798365592957
# ®: 0.35427728295326233
#
# Die ähnlichsten Wörter zu 'arbeiter':
# 19.: 0.34869852662086487
# tortrag: 0.3427271544933319
# zertz: 0.3372514843940735
# entsetzlich: 0.3208582103252411
# verkleinerung: 0.3187101185321808
#
# Die ähnlichsten Wörter zu 'nämlich':
# tanzte: 0.3510522246360779
# abstrakte: 0.33662596344947815
# prosaist: 0.32376357913017273
# mexiko: 0.30774012207984924
# interpretiert: 0.30669641494750977
#
# Die ähnlichsten Wörter zu 'zeigt':
# history: 0.36445528268814087
# fiction: 0.35303452610969543
# heruntergeladen: 0.33891773223876953
# vio: 0.3283692002296448
# rechtlichen: 0.3229168951511383
#
# Die ähnlichsten Wörter zu '10':
# mehrheitsverhältnisse: 0.32682740688323975
# 1932.: 0.32559341192245483
# apple-fan: 0.32051512598991394
# ausgangsbedingungen: 0.31750982999801636
# schotter: 0.311056524515152
#
# Die ähnlichsten Wörter zu 'gedanken':
# tanze: 0.3823961615562439
# anfang: 0.3539090156555176
# meldungen: 0.3461814224720001
# wortgewaltig: 0.3305181562900543
# prokurist: 0.32799917459487915
#
# Die ähnlichsten Wörter zu 'wolf':
# landschaftswiesen: 0.3715801537036896
# ohnmächtige: 0.34193921089172363
# korperverletzungen: 0.3370356559753418
# zusammensetzen: 0.32779163122177124
# 60ern: 0.31774255633354187
#
# Die ähnlichsten Wörter zu 'nahe':
# saß: 0.4042084813117981
# lustvoll: 0.4013245701789856
# beschwerde: 0.3796267807483673
# vorraussetzung: 0.3705125153064728
# ritterstück: 0.3667476773262024
#
# Die ähnlichsten Wörter zu 'lässt':
# benutzen: 0.3721785843372345
# anschaulich: 0.3622015714645386
# unansehnliche: 0.32653722167015076
# verlorengegangene: 0.3205375671386719
# fokussieren: 0.3143004775047302
#
# Die ähnlichsten Wörter zu 'voll':
# müder: 0.40395984053611755
# bösewicht: 0.32794710993766785
# gebrüllt: 0.3134933412075043
# klick: 0.3076348304748535
# gelten: 0.29697757959365845
#
# Die ähnlichsten Wörter zu 'junge':
# volkskundler: 0.35103172063827515
# angeblich: 0.3423401117324829
# lauth: 0.34211498498916626
# unbeweglich: 0.30848750472068787
# suchmaschinenanbieter: 0.30833956599235535
#
# Die ähnlichsten Wörter zu 'hass':
# früh: 0.37851378321647644
# beigetragen: 0.3469139039516449
# heuchelei: 0.3338879644870758
# verwendeten: 0.33012551069259644
# gewünscht: 0.32707247138023376
#
# Die ähnlichsten Wörter zu 'schön':
# hintereinander: 0.37456345558166504
# bezahlfernsehen: 0.3644647002220154
# lehrertisch: 0.32794618606567383
# erweise: 0.3100559115409851
# wörni: 0.30819258093833923
#
# Die ähnlichsten Wörter zu 'spd':
# stelle: 0.3933194875717163
# ehe: 0.38767263293266296
# unterlassen: 0.3673356771469116
# messner: 0.35091787576675415
# wachster: 0.3468271791934967
#
# Die ähnlichsten Wörter zu 'tür':
# empfand: 0.33926573395729065
# irrte: 0.3302080035209656
# tieres: 0.30619287490844727
# beigemischt: 0.30390051007270813
# mittelalters: 0.30167075991630554
#
# Die ähnlichsten Wörter zu 'enttäuschung':
# genialen: 0.3500620424747467
# klingt: 0.3218694031238556
# verlobung: 0.3213159739971161
# fällt: 0.31894826889038086
# selbstgewissheit: 0.31803369522094727
#
# Die ähnlichsten Wörter zu 'glauben':
# strahlende: 0.35848715901374817
# kurzen: 0.3399827480316162
# laufen: 0.33927831053733826
# regierende: 0.3356681168079376
# elementarer: 0.3037647604942322
#
# Die ähnlichsten Wörter zu 'seite':
# zaubert: 0.36846163868904114
# umzulenken: 0.3403724431991577
# weltwöhrungskrise: 0.3289998173713684
# junker: 0.3240187168121338
# blindes: 0.314115434885025
#
# Die ähnlichsten Wörter zu 'k.':
# umarmungen: 0.3751092851161957
# definieren: 0.36320388317108154
# ungeordneten: 0.3425094485282898
# isolierung: 0.33883002400398254
# ausgelöste: 0.3360685408115387
#
# Die ähnlichsten Wörter zu 'bringt':
# 2.7.1960: 0.3856460452079773
# mitzunehmen: 0.36388927698135376
# arbeiterbewegung: 0.35142871737480164
# knollengewächse: 0.32471033930778503
# scheibe: 0.3125142455101013
#
# Die ähnlichsten Wörter zu 'fand':
# teilt: 0.4050463140010834
# zittern: 0.3711836636066437
# erlebnis: 0.34965893626213074
# lehrbücher: 0.33618301153182983
# industrielle: 0.31938907504081726
#
# Die ähnlichsten Wörter zu 'schrie':
# hitlers: 0.32847684621810913
# angestammtes: 0.32716551423072815
# offenbartem: 0.3184518814086914
# sündenfall: 0.31705278158187866
# gegeneinander: 0.3158935010433197
#
# Die ähnlichsten Wörter zu 'sogar':
# schmalen: 0.3448943793773651
# verlieh: 0.33442452549934387
# zorns: 0.32596608996391296
# höherer: 0.3253028690814972
# wochenende: 0.32303470373153687
#
# Die ähnlichsten Wörter zu 'frage':
# 9: 0.4556652009487152
# gleichgültig: 0.3615613281726837
# gebell: 0.3453817069530487
# fröhlicher: 0.3393700420856476
# gläubige: 0.3363437056541443
#
# Die ähnlichsten Wörter zu 'begann':
# 1916: 0.3635016083717346
# bersten: 0.3178471326828003
# freie: 0.3177710771560669
# jud: 0.30774635076522827
# entgegen: 0.3060993254184723
#
# Die ähnlichsten Wörter zu 'wort':
# stellvertretenden: 0.3532416522502899
# merkt: 0.32794708013534546
# zahl: 0.32734885811805725
# mannhardts: 0.3202931880950928
# form: 0.3161519467830658
#
# Die ähnlichsten Wörter zu 'alter':
# gekleideten: 0.3476199507713318
# würdigt: 0.33594003319740295
# nachgeborenen: 0.3341613709926605
# scheint: 0.33004826307296753
# freiheitlichen: 0.3264327645301819
#
# Die ähnlichsten Wörter zu 'lese':
# verschaffen: 0.35907554626464844
# menschenverstand: 0.35552820563316345
# wechsel: 0.3339339792728424
# blättern: 0.3327898383140564
# eingepreßt: 0.32858994603157043
#
# Die ähnlichsten Wörter zu 'böse':
# einsam: 0.36961081624031067
# juristisch: 0.3635202944278717
# schönheiten: 0.3335779905319214
# g8-tisch: 0.3291756212711334
# sozialer: 0.30816036462783813
#
# Die ähnlichsten Wörter zu 'könne':
# abhanden: 0.35498902201652527
# unbesiegt: 0.3545689880847931
# echtheit: 0.3510882258415222
# partnerin: 0.3366498649120331
# heldin: 0.33333125710487366
#
# Die ähnlichsten Wörter zu 'reaktion':
# selbsttäuschung: 0.3491276204586029
# projekts: 0.34743010997772217
# fehlen: 0.3359225392341614
# zugesteckt: 0.3334634304046631
# ökonomen: 0.3237892985343933
#
# Die ähnlichsten Wörter zu 'stolz':
# einerseits: 0.36084023118019104
# sprach: 0.35572534799575806
# täglichen: 0.34551653265953064
# ausdrücken: 0.3326641917228699
# bonté: 0.32797297835350037
#
# Die ähnlichsten Wörter zu 'weise':
# bado: 0.359737753868103
# trailer-park: 0.3335888087749481
# einfacher: 0.32201728224754333
# police: 0.3144889771938324
# zahlreichen: 0.31191205978393555
#
# Die ähnlichsten Wörter zu 'zeigen':
# zuschauer: 0.33728498220443726
# entladen: 0.33604225516319275
# blindes: 0.33397480845451355
# verschiedeneren: 0.32178276777267456
# zusammenhangs: 0.31635236740112305
#
# Die ähnlichsten Wörter zu 'tut':
# schwenken: 0.36624768376350403
# 33: 0.35018131136894226
# sorry: 0.3450036942958832
# lustvoll: 0.32977673411369324
# laune: 0.3294380307197571
#
# Die ähnlichsten Wörter zu 'deutsche':
# frustration: 0.3655804693698883
# sagten: 0.35593125224113464
# melden: 0.3398083746433258
# spitze: 0.3236168920993805
# fügt: 0.3187856078147888
#
# Die ähnlichsten Wörter zu 'spaß':
# flugzeuge: 0.4147615134716034
# gegenteil: 0.3201538324356079
# parallele: 0.31047990918159485
# reichsbrücken: 0.31017690896987915
# zweit: 0.3060581386089325
#
# Die ähnlichsten Wörter zu 'wahre':
# erhebet: 0.42624902725219727
# brock: 0.33836108446121216
# affektstörung: 0.33537349104881287
# fruchtbarer: 0.3342798352241516
# lage: 0.3310200870037079
#
# Die ähnlichsten Wörter zu 'gilt':
# fähig: 0.3746381402015686
# setzen: 0.35712990164756775
# eröffenen: 0.34890347719192505
# jazz: 0.33778494596481323
# randalieren: 0.3251477777957916
#
# Die ähnlichsten Wörter zu 'land':
# betreten: 0.36467602849006653
# verlorene: 0.36209386587142944
# tücher: 0.3493129014968872
# wisohnewski: 0.3441965878009796
# angestaute: 0.33539676666259766
#
# Die ähnlichsten Wörter zu 'hoffnung':
# gepräge: 0.32751309871673584
# erkenntnis: 0.3239622712135315
# schieben: 0.3136771321296692
# hörer: 0.31033772230148315
# aß: 0.3079625368118286
#
# Die ähnlichsten Wörter zu 'umständen':
# zustände: 0.3398812413215637
# schläger: 0.33771777153015137
# deportationen: 0.3279341161251068
# gewisse: 0.3217340409755707
# gefüttert: 0.31382516026496887
#
# Die ähnlichsten Wörter zu 'gesicht':
# geschafft: 0.35521548986434937
# zürcher: 0.3432367146015167
# aufhaltenden: 0.3326738774776459
# arnold: 0.3075835406780243
# tempel: 0.30158594250679016
#
# Die ähnlichsten Wörter zu 'arbeiten':
# scheisse: 0.34294024109840393
# wirtin: 0.3421899676322937
# herunterladbare: 0.3286767899990082
# wovon: 0.3185182213783264
# losschlägt: 0.31851229071617126
#
# Die ähnlichsten Wörter zu 'besondere':
# schenkte: 0.36133497953414917
# musiker: 0.3352818489074707
# häufiger: 0.3305392265319824
# auskommt: 0.32287952303886414
# auflage: 0.31982970237731934
#
# Die ähnlichsten Wörter zu 'schreibe':
# überzeugen: 0.3399176597595215
# elastischen: 0.33277878165245056
# vorzugsweise: 0.31846410036087036
# putins: 0.3173390030860901
# uninteressant: 0.315351277589798
#
# Die ähnlichsten Wörter zu 'voller':
# gitarre: 0.32194212079048157
# übertrieben: 0.3171771764755249
# wußte: 0.31445613503456116
# verstandverlust: 0.3123023808002472
# trieberregung: 0.30457165837287903
#
# Die ähnlichsten Wörter zu 'stadt':
# hängen: 0.3497706353664398
# denke: 0.33814874291419983
# mauern: 0.31918951869010925
# literaturwissenschaftler: 0.31169915199279785
# beharren: 0.30585214495658875
#
# Die ähnlichsten Wörter zu 'bisschen':
# entfesselte: 0.3734135925769806
# reggae-kategorie: 0.3600941002368927
# rasens: 0.35800573229789734
# finde: 0.3275246024131775
# dauert: 0.3094852864742279
#
# Die ähnlichsten Wörter zu 'anderes':
# konstantin: 0.39205068349838257
# parallele: 0.38513803482055664
# verzweiflung: 0.3592182397842407
# gleichen: 0.33478784561157227
# vorzimmers: 0.330817312002182
#
# Die ähnlichsten Wörter zu 'steht':
# wärme: 0.5065381526947021
# straßen-: 0.3909226357936859
# völkern: 0.3705233335494995
# schrecklichen: 0.3679662346839905
# bleiben: 0.36527860164642334
#
# Die ähnlichsten Wörter zu 'trotz':
# phänomen: 0.3771219253540039
# lache: 0.3768371045589447
# verwicklungen: 0.3554924428462982
# zivilisation: 0.3436741828918457
# sprach: 0.33390942215919495
#
# Die ähnlichsten Wörter zu 'bloß':
# begabung: 0.39490699768066406
# europas: 0.38893479108810425
# abwartende: 0.32396358251571655
# hören: 0.31682878732681274
# 18,34: 0.3157140910625458
#
# Die ähnlichsten Wörter zu 'sicher':
# kilo: 0.3584016263484955
# ertragen: 0.33108070492744446
# ventil: 0.32700470089912415
# blieben: 0.32505741715431213
# obwohl: 0.3134393095970154
#
# Die ähnlichsten Wörter zu 'zuvor':
# dorsay: 0.4175763428211212
# arm: 0.362236350774765
# offenbartem: 0.3584330677986145
# gefühlsverirrungen: 0.35065630078315735
# entsetzlich: 0.3431577682495117
#
# Die ähnlichsten Wörter zu 'alte':
# dienert: 0.4013528525829315
# kalle: 0.391879141330719
# phänomen: 0.3456803560256958
# erschrecktheit: 0.3393438160419464
# auoh: 0.33174392580986023
#
# Die ähnlichsten Wörter zu 'rede':
# weber: 0.37617793679237366
# dres: 0.3722936809062958
# scheiße: 0.35146135091781616
# tank: 0.3258424699306488
# schreit: 0.32005468010902405
#
# Die ähnlichsten Wörter zu 'schüler':
# 56: 0.4145561456680298
# peer-education: 0.3832019567489624
# törring: 0.36731284856796265
# wettern: 0.33719363808631897
# gelassenheit: 0.32711151242256165
#
# Die ähnlichsten Wörter zu 'selten':
# literatur: 0.41892069578170776
# kostenlos: 0.38509219884872437
# dürfte: 0.38467544317245483
# slavia: 0.3486313223838806
# türkischen: 0.3467761278152466
#
# Die ähnlichsten Wörter zu 'sprechen':
# physiologischen: 0.35752126574516296
# stößt: 0.3543437421321869
# bewusst: 0.35234084725379944
# gebell: 0.33221644163131714
# halte: 0.3273020386695862
#
# Die ähnlichsten Wörter zu 'hab':
# -leiterinnen: 0.3303671181201935
# affektkrisen: 0.31977343559265137
# gillen: 0.31771183013916016
# werke: 0.3119886517524719
# langem: 0.3041095435619354
#
# Die ähnlichsten Wörter zu 'wirkung':
# zurückkehre: 0.43734660744667053
# tja: 0.3699704706668854
# lernenden: 0.3368702530860901
# entwickelten: 0.317800909280777
# desaster: 0.31027713418006897
#
# Die ähnlichsten Wörter zu 'tempel':
# georg: 0.34844502806663513
# ward: 0.34801849722862244
# gedichten: 0.3372754752635956
# unbeweglich: 0.3340383768081665
# rosis: 0.33373531699180603
#
# Die ähnlichsten Wörter zu '|':
# zeitung: 0.36768823862075806
# affektkrisen: 0.33558759093284607
# 11,oo: 0.3318619132041931
# adrett: 0.3250204920768738
# roben: 0.3140707015991211
#
# Die ähnlichsten Wörter zu 'diskussion':
# bemühe: 0.38551169633865356
# sexueller: 0.3228392004966736
# wahl: 0.31933844089508057
# eoonomio: 0.3188149929046631
# massenauftritte: 0.3132728934288025
#
# Die ähnlichsten Wörter zu 'druck':
# aspekt: 0.39016813039779663
# einkriegen: 0.33997946977615356
# funktionäre: 0.3327105939388275
# machete: 0.32636758685112
# nikaragua: 0.3258933424949646
#
# Die ähnlichsten Wörter zu 'völlig':
# empfinde: 0.3442908823490143
# defekten: 0.34412461519241333
# echten: 0.33956480026245117
# donnerte: 0.3303253948688507
# publizistik: 0.3280334770679474
#
# Die ähnlichsten Wörter zu 'is':
# best: 0.36400315165519714
# ärgern: 0.34464216232299805
# leichterer: 0.32954978942871094
# unerhörtesten: 0.3263304829597473
# irren: 0.32401859760284424
#
# Die ähnlichsten Wörter zu 'gesellschaft':
# gehässigkeit: 0.38386818766593933
# verfolgung: 0.37985512614250183
# linkspartei: 0.3711308538913727
# chor: 0.3691011071205139
# vorgesehen: 0.3654559552669525
#
# Die ähnlichsten Wörter zu 'hielt':
# übrigen: 0.35211509466171265
# hakenkreuzschmierereien: 0.34858447313308716
# stunde: 0.34434831142425537
# atemlos: 0.32371559739112854
# masse: 0.3229156732559204
#
# Die ähnlichsten Wörter zu 'schrieb':
# monde: 0.3256599009037018
# poche: 0.324259489774704
# 2.7.1960: 0.3149794340133667
# bandwettbewerb: 0.3099830448627472
# worten: 0.30608662962913513
#
# Die ähnlichsten Wörter zu 'bzw.':
# jazz: 0.35129788517951965
# lagerverstaubt: 0.329198956489563
# aufsatz: 0.32449379563331604
# spreche: 0.32302260398864746
# pfeilen: 0.3054429292678833
#
# Die ähnlichsten Wörter zu 'wären':
# penthouse: 0.3485094904899597
# wehrt: 0.33216503262519836
# sonne: 0.3171079754829407
# diskriminierung: 0.3062976002693176
# spaten: 0.3045911192893982
#
# Die ähnlichsten Wörter zu 'i':
# radioals: 0.39273983240127563
# räder: 0.37678980827331543
# tendenz: 0.32480165362358093
# italienischer: 0.3187163472175598
# besim: 0.30084937810897827
#
# Die ähnlichsten Wörter zu 'stimme':
# heß: 0.3793332278728485
# 5.12.: 0.364226758480072
# duell: 0.3534626066684723
# erfahrungen: 0.3510779142379761
# zittere: 0.3377966582775116
#
# Die ähnlichsten Wörter zu 'bild':
# wissenschaftsrpform: 0.3530738651752472
# bochesk: 0.3378698527812958
# gibt's: 0.33611080050468445
# stumm: 0.33261969685554504
# oben-: 0.31115105748176575
#
# Die ähnlichsten Wörter zu 'nioht':
# unbeweglich: 0.3330657482147217
# vollem: 0.33145156502723694
# beiläufigen: 0.3310602009296417
# automaten: 0.325984925031662
# taz: 0.32544416189193726
#
# Die ähnlichsten Wörter zu 'geraten':
# leitartikel: 0.42727991938591003
# richtiger: 0.35350894927978516
# management: 0.32362961769104004
# rösselmühlgasse: 0.31851890683174133
# schöne: 0.31319618225097656
#
# Die ähnlichsten Wörter zu 'nächsten':
# sozialen: 0.40534186363220215
# feuchtigkeit: 0.35339784622192383
# stundenbücher: 0.346637099981308
# obstler: 0.3336282968521118
# lautete: 0.333038330078125
#
# Die ähnlichsten Wörter zu 'kranken':
# gebändigt: 0.3709288537502289
# schweine: 0.3638962209224701
# barrikaden: 0.34006139636039734
# briefe: 0.3292919397354126
# enthüllen: 0.32870084047317505
#
# Die ähnlichsten Wörter zu 'auoh':
# alte: 0.3317439556121826
# sünden: 0.3227662742137909
# amedeo: 0.3204314410686493
# gebastelt: 0.3156709671020508
# punkte: 0.3081737756729126
#
# Die ähnlichsten Wörter zu 'eher':
# bankgründungen: 0.33594897389411926
# jst: 0.3358031213283539
# voreilig: 0.3310164511203766
# wachster: 0.33028092980384827
# tollkühn: 0.3292617201805115
#
# Die ähnlichsten Wörter zu 'sitzt':
# lief: 0.365535169839859
# ausgezeichnet: 0.3566391170024872
# kurze: 0.35368871688842773
# margen: 0.341892808675766
# gebell: 0.3293418288230896
#
# Die ähnlichsten Wörter zu 'frauen':
# zielscheibe: 0.3572683334350586
# auffallend: 0.3535918593406677
# weh: 0.34950175881385803
# literatursoziologischen: 0.34217292070388794
# schmerzen: 0.3356367349624634
#
# Die ähnlichsten Wörter zu 'hält':
# nass: 0.3817311227321625
# narren: 0.3580934405326843
# bedrohende: 0.3408840000629425
# merke: 0.3285885155200958
# naturalismus: 0.3263315260410309
#
# Die ähnlichsten Wörter zu 'marguerite':
# gründe: 0.35142621397972107
# ungeordneten: 0.33247530460357666
# angeht: 0.3307034373283386
# bösartig: 0.32635051012039185
# definieren: 0.32425498962402344
#
# Die ähnlichsten Wörter zu 'verboten':
# spur: 0.34981387853622437
# 1957: 0.3398910462856293
# rührt: 0.3361762762069702
# j.-p.sartre: 0.3335728943347931
# millionen: 0.3322106897830963
#
# Die ähnlichsten Wörter zu 'vorbei':
# spielen: 0.3265748620033264
# funkelnden: 0.30956828594207764
# tüchtig: 0.3092285394668579
# briefen: 0.2974260151386261
# überfließenden: 0.2962137758731842
#
# Die ähnlichsten Wörter zu 'z.b.':
# verschiedene: 0.3664451837539673
# versuchte: 0.33405375480651855
# gewonnene: 0.33242833614349365
# tanze: 0.3289136588573456
# fotostative: 0.3286671042442322
#
# Die ähnlichsten Wörter zu 'namen':
# bereitstellung: 0.3447410762310028
# schluß: 0.3432132601737976
# grundrentenzahlung: 0.3387238681316376
# nachmittags: 0.33079344034194946
# frische: 0.31305065751075745
#
# Die ähnlichsten Wörter zu 'gegeben':
# läuft: 0.34799325466156006
# rasten: 0.32962048053741455
# gebratene: 0.32460737228393555
# vornimmt: 0.3236749768257141
# armstrong-platten: 0.3213501274585724
#
# Die ähnlichsten Wörter zu 'ln':
# hübchen: 0.3833363652229309
# reizend: 0.36763128638267517
# ungeduldig: 0.3671400547027588
# eimer: 0.3321448564529419
# geiles: 0.33017492294311523
#
# Die ähnlichsten Wörter zu 'paar':
# erschossen: 0.3751901090145111
# h.: 0.3434106111526489
# leningrad: 0.32915815711021423
# infolge: 0.32280033826828003
# bewußtsein: 0.3198472559452057
#
# Die ähnlichsten Wörter zu 'insbesondere':
# saison: 0.3685034215450287
# medienhandelns: 0.3675425052642822
# außerhalb: 0.3635464310646057
# verloren: 0.3561842739582062
# gotischen: 0.34841659665107727
#
# Die ähnlichsten Wörter zu 'gregor':
# freilich: 0.386300653219223
# begutachtet: 0.37482592463493347
# koohen: 0.3580104112625122
# netto: 0.35317447781562805
# stürzte: 0.33665668964385986
#
# Die ähnlichsten Wörter zu 'minuten':
# verborgenen: 0.3936155140399933
# beauftragte: 0.3468232750892639
# 1998.: 0.33102673292160034
# gegenteil: 0.32601457834243774
# moderna: 0.32376134395599365
#
# Die ähnlichsten Wörter zu 'bestimmt':
# einfachheit: 0.3591429889202118
# gelassen: 0.3308888375759125
# verirren: 0.3246733248233795
# gehenden: 0.3204606771469116
# lenin: 0.3057301342487335
#
# Die ähnlichsten Wörter zu 'zimmer':
# aufstand: 0.4026377201080322
# levels: 0.40010935068130493
# wolken: 0.3509944677352905
# h: 0.34315839409828186
# zurückgreifen: 0.3320625126361847
#
# Die ähnlichsten Wörter zu 'unserem':
# freiheitlichen: 0.38503098487854004
# politische: 0.35977792739868164
# genugtuung: 0.35925421118736267
# martina: 0.35417836904525757
# selbständige: 0.3525228500366211
#
# Die ähnlichsten Wörter zu 'nutzen':
# akademieparteileitung: 0.3858775496482849
# superheld: 0.3587878942489624
# indikator: 0.3490355908870697
# angelegenheiten: 0.33406347036361694
# finke: 0.32756322622299194
#
# Die ähnlichsten Wörter zu 'plötzlich':
# aufnahmen: 0.41033706068992615
# entrungen: 0.36623480916023254
# ergänzenden: 0.3426606357097626
# kuriose: 0.33894971013069153
# kohlmey: 0.3317304253578186
#
# Die ähnlichsten Wörter zu 'musik':
# kälte: 0.38680562376976013
# staaten: 0.36612892150878906
# kapitalismus: 0.34002625942230225
# verstummen: 0.33211269974708557
# gestrandet: 0.33204784989356995
#
# Die ähnlichsten Wörter zu 'gekommen':
# abzuschneiden: 0.35269707441329956
# tätergesellschaft: 0.32754990458488464
# ziellose: 0.31712982058525085
# rätsels: 0.3118612766265869
# stütze: 0.3079075515270233
#
# Die ähnlichsten Wörter zu 'wahl':
# bedrängnis: 0.34432464838027954
# övp: 0.3259879946708679
# machete: 0.3250971734523773
# gerannt: 0.32105571031570435
# diskussion: 0.31933844089508057
#
# Die ähnlichsten Wörter zu 'hervor':
# besagte: 0.4055396020412445
# mördertruppe: 0.3797338306903839
# entwickelten: 0.34328481554985046
# barbaren: 0.3366689085960388
# moshammer: 0.33378759026527405
#
# Die ähnlichsten Wörter zu 'sprache':
# ukraine: 0.38244354724884033
# weinenden: 0.3266870975494385
# umgeschrieben: 0.31811365485191345
# gelungen: 0.3176575005054474
# geträumt: 0.3138541281223297
#
# Die ähnlichsten Wörter zu 'fall':
# diebische: 0.3855092525482178
# 5.12.: 0.35394448041915894
# falsch: 0.33470845222473145
# firma: 0.3292802572250366
# sozialisten: 0.324369877576828
#
# Die ähnlichsten Wörter zu 'stets':
# freut: 0.3489607572555542
# ausdrucks: 0.3319801390171051
# antonio: 0.3185025453567505
# ferien: 0.3150961399078369
# verbessern: 0.30799946188926697
#
# Die ähnlichsten Wörter zu ''s':
# verpasst: 0.38030099868774414
# blindes: 0.3490299582481384
# udssr: 0.3394047021865845
# lebe: 0.33141323924064636
# evangelischen: 0.32731467485427856
#
# Die ähnlichsten Wörter zu 'schlägt':
# sandberg: 0.40780532360076904
# zugesteckt: 0.3312261700630188
# einerseits: 0.32276812195777893
# manifestation: 0.32032403349876404
# feiertag: 0.3185989260673523
#
# Die ähnlichsten Wörter zu 'realität':
# anbieten: 0.3745763897895813
# versteht: 0.37384462356567383
# neidisch: 0.3579100966453552
# leben: 0.3231580853462219
# überstürzt: 0.31471776962280273
#
# Die ähnlichsten Wörter zu 'botschaft':
# pfand: 0.3750060200691223
# scuola: 0.33385154604911804
# lauenburg: 0.33377805352211
# bolivianer: 0.32942673563957214
# 7: 0.32396018505096436
#
# Die ähnlichsten Wörter zu 'jugendlichen':
# getötet: 0.39332446455955505
# erscheinung: 0.3557365834712982
# lie: 0.34984126687049866
# flatterfedern: 0.34283357858657837
# autorin: 0.33977562189102173
#
# Die ähnlichsten Wörter zu 'bekommen':
# fehlt: 0.4462333917617798
# kaufte: 0.35911768674850464
# schülerin: 0.349246621131897
# dix: 0.3485468327999115
# irgendein: 0.34451040625572205
#
# Die ähnlichsten Wörter zu 'straße':
# verzicht: 0.3483499586582184
# autoren: 0.3471587002277374
# stete: 0.3293996751308441
# tatsachen: 0.3143893778324127
# pseudonym: 0.31105664372444153
#
# Die ähnlichsten Wörter zu 'schmerz':
# arabischen: 0.35548684000968933
# vollmondnacht: 0.33371105790138245
# stürmisch: 0.33126989006996155
# unausrottbar: 0.3273284137248993
# zurückgeworfen: 0.32265546917915344
#
# Die ähnlichsten Wörter zu 'lage':
# lachen: 0.3813215494155884
# uefa-cup-spiels: 0.3403076231479645
# breit: 0.33699390292167664
# schwätzen: 0.3328019678592682
# wahre: 0.3310201168060303
#
# Die ähnlichsten Wörter zu 'gesehen':
# werk: 0.38670894503593445
# nagy: 0.3609471321105957
# sollst: 0.35404106974601746
# 18.9.1976: 0.34482669830322266
# kopfe: 0.3346751630306244
#
# Die ähnlichsten Wörter zu 'wirkt':
# friedhöfen: 0.3684777021408081
# verzweiflung: 0.3650554120540619
# nord: 0.33854591846466064
# beiwohnen: 0.3358812928199768
# widersprüche: 0.331684947013855
#
# Die ähnlichsten Wörter zu 'mut':
# zählen: 0.4128669798374176
# entsinnen: 0.3842354714870453
# rechnung: 0.3402933180332184
# bandwettbewerb: 0.3365502655506134
# sprüche: 0.31634289026260376
#
# Die ähnlichsten Wörter zu 'sinne':
# spricht: 0.38750365376472473
# gediehen: 0.34445294737815857
# haltungen: 0.317064106464386
# enormen: 0.3152679204940796
# 13: 0.31074851751327515
#
# Die ähnlichsten Wörter zu 'gewalt':
# scheide: 0.37496963143348694
# gibt's: 0.3727641701698303
# entladungen: 0.3525974750518799
# 2:19: 0.33916229009628296
# gesicherten: 0.33431482315063477
#
# Die ähnlichsten Wörter zu 'künstler':
# 8: 0.3810883164405823
# verliehen: 0.3291451334953308
# thöni: 0.3262736201286316
# ausgrenzen: 0.3259483575820923
# 3: 0.3223806321620941
#
# Die ähnlichsten Wörter zu 'e':
# premiers: 0.3415299952030182
# schutz: 0.34152936935424805
# zerschlagen: 0.33147045969963074
# urlaubszeit: 0.3215995132923126
# theokratie: 0.310491681098938
#
# Die ähnlichsten Wörter zu 'größten':
# erreichen: 0.3418147563934326
# aufnahmen: 0.3392546474933624
# baldigst: 0.3221871852874756
# 2:2: 0.306090384721756
# büro: 0.295341432094574
#
# Die ähnlichsten Wörter zu 'revolution':
# randalieren: 0.4098621606826782
# fernsehen: 0.3386513292789459
# stichwort: 0.3315125107765198
# musiziert: 0.3226630985736847
# letzten: 0.3147105872631073
#
# Die ähnlichsten Wörter zu 'kritik':
# flüchtlingsopfer: 0.3663939833641052
# linzer: 0.3344264030456543
# tausend: 0.33030179142951965
# bergen: 0.32767942547798157
# be: 0.3117547035217285
#
# Die ähnlichsten Wörter zu 'ddr':
# verhilft: 0.429000586271286
# erfüllen: 0.3687807023525238
# zerrissenheit: 0.362746924161911
# broschüren: 0.35738426446914673
# arbeitslosen: 0.3358986973762512
#
# Die ähnlichsten Wörter zu 'deutschland':
# 30: 0.3472696840763092
# grat: 0.3337275981903076
# hd: 0.3333986699581146
# jammert: 0.33200812339782715
# prorekihir: 0.31031015515327454
#
# Die ähnlichsten Wörter zu 'israel':
# gegenstand: 0.4196748733520508
# verrat: 0.3585074245929718
# minimal-: 0.35295361280441284
# mildes: 0.3177461326122284
# outcast: 0.3155374228954315
#
# Die ähnlichsten Wörter zu 'hören':
# verarbeite: 0.3253531754016876
# ch: 0.32222214341163635
# abneigung: 0.3186679482460022
# bloß: 0.3168288469314575
# lärmbelästigung: 0.31624776124954224
#
# Die ähnlichsten Wörter zu 'erzählte':
# murblick: 0.42763572931289673
# greco: 0.35698387026786804
# erwog: 0.3365784287452698
# outfit: 0.33444735407829285
# auszulassen: 0.3276367485523224
#
# Die ähnlichsten Wörter zu 'cyberwelt':
# pflegerin: 0.375379353761673
# kirchenzucht: 0.3684318959712982
# rull-serie: 0.35394296050071716
# aufstand: 0.3313266932964325
# ausrede: 0.3232678771018982
#
# Die ähnlichsten Wörter zu 'wirken':
# fliegen: 0.34164535999298096
# befürworte: 0.3393630385398865
# beigemischt: 0.33029860258102417
# hilflosigkeit: 0.3180730938911438
# behm: 0.30913448333740234
#
# Die ähnlichsten Wörter zu 'verlangt':
# riss: 0.3484884798526764
# immigranten: 0.3329296112060547
# linzer: 0.3271976709365845
# thema: 0.31113776564598083
# akkumulation: 0.30000999569892883
#
# Die ähnlichsten Wörter zu 'ebenfalls':
# wasser: 0.3668636083602905
# vermittelt: 0.3475989103317261
# aufzuwachsen: 0.3434297740459442
# netzsperrengesetz: 0.33908867835998535
# anwälte: 0.3385592997074127
#
# Die ähnlichsten Wörter zu 'computerspiel':
# spanndende: 0.34339573979377747
# nase: 0.34018105268478394
# aaron: 0.33202099800109863
# friedhöfen: 0.32645735144615173
# lopez: 0.3238920569419861
#
# Die ähnlichsten Wörter zu 'herum':
# amtsdiener: 0.32963261008262634
# ohnmächtiger: 0.3240562379360199
# unberechtigt: 0.322719007730484
# sohn: 0.3220992088317871
# intellektuellen: 0.31756940484046936
#
# Die ähnlichsten Wörter zu 'inneren':
# loest: 0.34853824973106384
# aberkannt: 0.33681872487068176
# moderatoren: 0.30674582719802856
# angaben: 0.3034665584564209
# start: 0.29980289936065674
#
# Die ähnlichsten Wörter zu '’s':
# bakunin: 0.35938990116119385
# anfangen: 0.34526512026786804
# verständnis: 0.34516382217407227
# 6.500: 0.3363357484340668
# schweißnasser: 0.3336930274963379
#
# Die ähnlichsten Wörter zu 'zentrum':
# vorzimmers: 0.33346161246299744
# sonnt: 0.30861538648605347
# epileptiker: 0.30762550234794617
# begnügt: 0.29715025424957275
# heimito: 0.2938289940357208
#
# Die ähnlichsten Wörter zu 'probleme':
# empor: 0.36420679092407227
# weltverhältnisse: 0.3370281755924225
# verbessern: 0.3351641595363617
# komisch: 0.31047889590263367
# sternmarsch-vorbereitung: 0.3065349757671356
#
# Die ähnlichsten Wörter zu 'meisten':
# spendabel: 0.39725932478904724
# gebärde: 0.3907734453678131
# einzelpunkb: 0.38758453726768494
# tor: 0.34658172726631165
# zwangs: 0.3454621732234955
#
# Die ähnlichsten Wörter zu 'jedenfalls':
# monk”-cd: 0.3721376061439514
# outfit: 0.3677869141101837
# hauspension: 0.3341358006000519
# fronten: 0.3149835169315338
# beständig: 0.30948489904403687
#
# Die ähnlichsten Wörter zu 'urteil':
# gedacht: 0.396508127450943
# böser: 0.32144400477409363
# selbstjustiz: 0.3190891444683075
# unerhörtesten: 0.31825146079063416
# sprach: 0.31053850054740906
#
# Die ähnlichsten Wörter zu 'stimmung':
# gelernt: 0.41293245553970337
# prozent: 0.3926844596862793
# gearbeitet: 0.38414686918258667
# monde: 0.35795700550079346
# schlagloch: 0.3499986529350281
#
# Die ähnlichsten Wörter zu 'usa':
# inhaltlichen: 0.3826673924922943
# merkels: 0.3671185076236725
# ausrede: 0.32970085740089417
# schreckliches: 0.3255327641963959
# minen: 0.3164137601852417
#
# Die ähnlichsten Wörter zu 'dennoch':
# entladen: 0.36107638478279114
# unterlassen: 0.35136258602142334
# besinnen: 0.3381178379058838
# tatmotive: 0.3206395208835602
# person: 0.32019898295402527
#
# Die ähnlichsten Wörter zu 'schnell':
# bleiben: 0.35274505615234375
# brief: 0.3457184433937073
# offensiv: 0.34358230233192444
# geschöpf: 0.34037408232688904
# erhalten: 0.3349670469760895
#
# Die ähnlichsten Wörter zu 'draußen':
# gefahr: 0.38765591382980347
# schwarzbuch: 0.35718950629234314
# interessanter: 0.34237220883369446
# klagen: 0.3354879319667816
# kriegen: 0.3282392919063568
#
# Die ähnlichsten Wörter zu 'haus':
# karriere: 0.36678600311279297
# tollkühn: 0.34949713945388794
# häusern: 0.34842485189437866
# 19: 0.34186968207359314
# versuchen: 0.34139561653137207
#
# Die ähnlichsten Wörter zu 'wütend':
# wangenheim: 0.363109827041626
# 108: 0.33973026275634766
# mutter: 0.3207962214946747
# schmalere: 0.31222259998321533
# winter: 0.30915889143943787
#
# Die ähnlichsten Wörter zu 'anblick':
# grauenhafte: 0.3718896806240082
# glanz: 0.3466895818710327
# mundwinkel: 0.32651716470718384
# ereignissen: 0.3202100992202759
# ilberg: 0.30328568816185
#
# Die ähnlichsten Wörter zu 'dinge':
# wiederum: 0.3450200855731964
# vorgang: 0.3171376883983612
# wuttke: 0.3163687288761139
# feinnervigen: 0.31566017866134644
# akkumulation: 0.30953845381736755
#
# Die ähnlichsten Wörter zu 'richtung':
# dres: 0.37086305022239685
# laufe: 0.3408600389957428
# reagierte: 0.32668107748031616
# 32: 0.32179415225982666
# held: 0.31734734773635864
#
# Die ähnlichsten Wörter zu 'langsam':
# humanismus: 0.3353672921657562
# ziel: 0.32082441449165344
# mechanisch: 0.3182384967803955
# leichengeruch: 0.3146767318248749
# überlegt: 0.3140791654586792
#
# ...
# gehüllt: 0.32893824577331543
# leiden: 0.31815648078918457
# fußballfunktionären: 0.314221054315567
#
# Die ähnlichsten Wörter zu 'antiquariat':
# bekam: 0.339755117893219
# klassenkämpfe: 0.3371141254901886
# bewusstsein: 0.33267420530319214
# niesend: 0.3124360144138336
# aufstehst: 0.3075070381164551
#
# Die ähnlichsten Wörter zu 'glücklicherweise':
# brut: 0.3729437589645386
# schülerin: 0.34927791357040405
# klassischen: 0.3369576036930084
# auffassungen: 0.3319302797317505
# steve: 0.32905757427215576
#
# Die ähnlichsten Wörter zu 'maschinenmanuskript':
# bau: 0.36927512288093567
# zivilbevölkerung: 0.3423554003238678
# angelegenheiten: 0.3422031104564667
# verschwinden: 0.33457303047180176
# mülldeponie: 0.3099808990955353
#
# Die ähnlichsten Wörter zu 'violences':
# autorin: 0.3795475363731384
# kurzfristig: 0.34758755564689636
# berlusconi: 0.32129576802253723
# husten: 0.31558820605278015
# volkswirtschaftlichen: 0.3064527213573456
#
# Die ähnlichsten Wörter zu 'échauffourées':
# bahnangestellter: 0.3354133665561676
# comet: 0.3344181478023529
# flaschen: 0.33415496349334717
# verrückter: 0.3170997202396393
# warten: 0.31650489568710327
#
# Die ähnlichsten Wörter zu 'à':
# empfang: 0.39190542697906494
# hofft: 0.3898800313472748
# kombination: 0.35472017526626587
# unbehagen: 0.3482489585876465
# scheide: 0.34822189807891846
#
# Die ähnlichsten Wörter zu 'l':
# idee: 0.3615944981575012
# literatur: 0.31517064571380615
# vollgültiges: 0.3147760033607483
# bezahlfernsehen: 0.3112528324127197
# nahestehen: 0.3081742525100708
#
# Die ähnlichsten Wörter zu 'issue':
# dreadlocks: 0.3624868392944336
# ressourcen: 0.3382595181465149
# terrororganisation: 0.33300167322158813
# grat: 0.32236963510513306
# zielt: 0.31091830134391785
#
# Die ähnlichsten Wörter zu 'manifestation':
# basis: 0.4023036062717438
# spektakuläres: 0.34500786662101746
# schweigeseminar: 0.3449687659740448
# zürcher: 0.34102246165275574
# vizedom: 0.33993038535118103
#
# Die ähnlichsten Wörter zu 'anti-g8':
# zoo: 0.36684635281562805
# ministerrat: 0.36235159635543823
# irgendwelchen: 0.35500526428222656
# vergehen: 0.3531823456287384
# enthüllen: 0.33707740902900696
#
# Die ähnlichsten Wörter zu 'allemagne':
# vorbereitete: 0.35795310139656067
# stagnation: 0.3310762941837311
# haupt: 0.3230324387550354
# viertelstunde: 0.315748929977417
# nackt: 0.30863508582115173
#
# Die ähnlichsten Wörter zu 'le':
# einheitsübersetzung: 0.34412896633148193
# jemals: 0.3406340479850769
# eifrig: 0.333599716424942
# becher: 0.3312488794326782
# gott: 0.3237909972667694
#
# Die ähnlichsten Wörter zu 'monde':
# stimmung: 0.35795700550079346
# uninteressant: 0.3386976718902588
# pervertiert: 0.32750964164733887
# schrieb: 0.3256599009037018
# g-8-krawalle: 0.32036295533180237
#
# Die ähnlichsten Wörter zu 'altermondialistes':
# selbstanalyse: 0.3947269022464752
# 1914: 0.33632221817970276
# pfarrer: 0.32075977325439453
# mitgefühl: 0.32041501998901367
# ermutigten: 0.31975460052490234
#
# Die ähnlichsten Wörter zu 'condamnent':
# solide: 0.3283992111682892
# aktiver: 0.3262399733066559
# wächst: 0.3246987760066986
# zuckungen: 0.32011178135871887
# near: 0.31861501932144165
#
# Die ähnlichsten Wörter zu 'libération':
# gesellschaft: 0.35756734013557434
# gewissenlosen: 0.3512639105319977
# dringend: 0.34643250703811646
# achseln: 0.340788334608078
# großartigkeit: 0.33336517214775085
#
# Die ähnlichsten Wörter zu 'verwüstet':
# anlass: 0.3932796120643616
# gysi: 0.3651929497718811
# durchschlag: 0.34408578276634216
# durchs: 0.33323171734809875
# stehe: 0.3298453390598297
#
# Die ähnlichsten Wörter zu 'chaoten':
# winde: 0.364361971616745
# beitrages: 0.3448849320411682
# verlängerung: 0.33666375279426575
# empfehle: 0.32119086384773254
# gebietsabgabe: 0.31970280408859253
#
# Die ähnlichsten Wörter zu 'einschlägig':
# verwirklicht: 0.3237452507019043
# richte: 0.31661397218704224
# werfen: 0.315368115901947
# erkundigen: 0.30588817596435547
# schichten: 0.3025919795036316
#
# Die ähnlichsten Wörter zu 'bildblog':
# tüchtig: 0.38576290011405945
# vielmehr: 0.3278607428073883
# act: 0.32020682096481323
# siekes: 0.31180956959724426
# breoht: 0.30244559049606323
#
# Die ähnlichsten Wörter zu 'aufgeblatteltem':
# europäischen: 0.38893064856529236
# russell: 0.3540383279323578
# unheimlichen: 0.31300655007362366
# küssten: 0.30691269040107727
# west-berlin: 0.30666667222976685
#
# Die ähnlichsten Wörter zu 'stadthafen':
# fremdgegangen: 0.3573479652404785
# mineralwasser: 0.34298649430274963
# aufhört: 0.325675368309021
# dialektischen: 0.32380715012550354
# enthüllen: 0.31631338596343994
#
# Die ähnlichsten Wörter zu 'netto':
# begutachtet: 0.36103054881095886
# jungen: 0.35982081294059753
# gregor: 0.3531745374202728
# ramschvorgang: 0.34922677278518677
# stütze: 0.3432120680809021
#
# Die ähnlichsten Wörter zu 'dorthin':
# logische: 0.3544001579284668
# wagnerkommers: 0.29680556058883667
# selbstkritik: 0.29421189427375793
# mass: 0.29226404428482056
# entspricht: 0.2855764329433441
#
# Die ähnlichsten Wörter zu 'markt':
# tabellenplatz: 0.3411506712436676
# angaben: 0.3410029411315918
# hoffnungslosigkeit: 0.3161449134349823
# -5: 0.309887170791626
# gesamte: 0.30827459692955017
#
# Die ähnlichsten Wörter zu 'steinwurf':
# herausschrieb: 0.40634337067604065
# denker: 0.40363600850105286
# hause: 0.36948904395103455
# pernerstorfer: 0.3422614336013794
# chef: 0.33632051944732666
#
# Die ähnlichsten Wörter zu 'erleiden':
# bildverwaltung: 0.38575199246406555
# fiel: 0.38547685742378235
# durchs: 0.35693034529685974
# schluss: 0.35099461674690247
# burgruinen: 0.34401780366897583
#
# Die ähnlichsten Wörter zu 'gestürmt':
# weiß: 0.3299086391925812
# malte: 0.32315436005592346
# 5.12.: 0.3191905915737152
# respektive: 0.31579819321632385
# geben: 0.31025081872940063
#
# Die ähnlichsten Wörter zu 'gesichert':
# gelassen: 0.33255913853645325
# soziologie: 0.31610575318336487
# 1982: 0.3094472885131836
# herzerweichenden: 0.3006093204021454
# curtis: 0.2990981936454773
#
# Die ähnlichsten Wörter zu 'jonas':
# ungeheuer: 0.3345937728881836
# kompositionspreis: 0.33123090863227844
# redete: 0.3144470155239105
# festschrift: 0.3134550154209137
# vj: 0.3079279363155365
#
# Die ähnlichsten Wörter zu 'weichheit':
# kraftwirkung: 0.34172120690345764
# mensa: 0.34082454442977905
# hervorragt: 0.3357676565647125
# ziska: 0.3323499858379364
# häßlichen: 0.33064004778862
#
# Die ähnlichsten Wörter zu 'absatzes':
# stärkeren: 0.35739344358444214
# rückblickend: 0.34704986214637756
# briefe: 0.3307225704193115
# vorausgesagte: 0.3289884328842163
# vorkommnissen: 0.31684064865112305
#
# Die ähnlichsten Wörter zu 'weltgeschichte':
# anfalls: 0.3719170093536377
# erzählers: 0.35900455713272095
# irgendein: 0.3334042429924011
# hamburg: 0.32210078835487366
# baudelaire: 0.3160729706287384
#
# Die ähnlichsten Wörter zu 'vorzügliche':
# gelinde: 0.3765278458595276
# artists: 0.3359038829803467
# zwangsläufige: 0.3212437927722931
# vorgestellt: 0.3156804144382477
# zeitschrift: 0.3133830428123474
#
# Die ähnlichsten Wörter zu 'kim':
# seihe: 0.39647865295410156
# nieder: 0.348664790391922
# halte: 0.3429287075996399
# private: 0.33568471670150757
# appetit: 0.3348933160305023
#
# Die ähnlichsten Wörter zu 'kollektivs':
# hinterher: 0.3796199560165405
# eltern-generation: 0.35343676805496216
# teller: 0.33836689591407776
# berlusconi: 0.326292484998703
# malgerade: 0.3231832683086395
#
# Die ähnlichsten Wörter zu 'lehrbuch':
# landsleuten: 0.368696004152298
# untätig: 0.3403612971305847
# sinnlosen: 0.3122789263725281
# 12,15: 0.30069980025291443
# einzelnen: 0.2986679673194885
#
# Die ähnlichsten Wörter zu 'klug':
# außerordentlich: 0.36601531505584717
# späßchen: 0.3090113699436188
# abgewogen: 0.3059907853603363
# glieder: 0.30387744307518005
# sagent: 0.30183061957359314
#
# Die ähnlichsten Wörter zu 'ausgewogen':
# edlinger-ploder: 0.4700063467025757
# weiterarbeitet: 0.35156306624412537
# beamte: 0.3409723937511444
# fusione: 0.33150357007980347
# mexikaner: 0.3224889934062958
#
# Die ähnlichsten Wörter zu '3.2.57':
# eigentumswohnung: 0.36373651027679443
# widerfährt: 0.3626701235771179
# begeisterung: 0.35231897234916687
# stimmt: 0.34141021966934204
# bürohaus: 0.336407870054245
#
# Die ähnlichsten Wörter zu 'gr':
# unterdrückte: 0.3597741723060608
# trugen: 0.3466923236846924
# 1923.: 0.3125719130039215
# exzessiven: 0.3064359128475189
# erzählt: 0.3007700741291046
#
# Die ähnlichsten Wörter zu 'h.':
# endlioh: 0.3789898157119751
# stilles: 0.3518836796283722
# waffenfabrikant: 0.3449888229370117
# kane: 0.34420186281204224
# paar: 0.3434106111526489
#
# Die ähnlichsten Wörter zu 'größern':
# gerichtet: 0.4434381425380707
# notar: 0.3590584993362427
# prasselt: 0.3566167652606964
# biographien: 0.31497812271118164
# donnerte: 0.31328284740448
#
# Die ähnlichsten Wörter zu 'einfallen':
# afrikaner: 0.40219467878341675
# dichtmachen: 0.33797502517700195
# rechts: 0.3155592978000641
# welch: 0.30898427963256836
# kommunismus: 0.3069697618484497
#
# Die ähnlichsten Wörter zu 'robustheit':
# führten: 0.3650091886520386
# überkommen: 0.3505253195762634
# zwölf: 0.34753140807151794
# karl: 0.34678182005882263
# klick: 0.3333396315574646
#
# Die ähnlichsten Wörter zu 'unsereins':
# ländern: 0.3611590564250946
# gingen: 0.3463951051235199
# studiums: 0.3272985517978668
# paßt: 0.3253672122955322
# kühner: 0.32173529267311096
#
# Die ähnlichsten Wörter zu 'bedarf':
# entwickelten: 0.3618813753128052
# einzig: 0.3615289628505707
# bedeutungslos: 0.35464078187942505
# zischende: 0.3218107223510742
# aufweist: 0.3100796043872833
#
# Die ähnlichsten Wörter zu 'augenblickliche':
# mail: 0.38077312707901
# gottes: 0.3786797821521759
# krummen: 0.370809406042099
# jules: 0.361146479845047
# unten: 0.35384446382522583
#
# Die ähnlichsten Wörter zu 'geschmacksschlendrian':
# geknüpft: 0.3757193386554718
# schund: 0.3642445206642151
# luthers: 0.35737016797065735
# kerl: 0.3336578905582428
# liebt: 0.31535059213638306
#
# Die ähnlichsten Wörter zu 'maßgebend':
# well: 0.3925442099571228
# intrige: 0.3468160927295685
# keim: 0.3325730860233307
# kompositionspreis: 0.32144665718078613
# chancen: 0.30987077951431274
#
# Die ähnlichsten Wörter zu 'erreichen':
# piratin: 0.36981889605522156
# größten: 0.341814786195755
# festschrift: 0.31234943866729736
# aktion: 0.31149929761886597
# sonnabende: 0.310744047164917
#
# Die ähnlichsten Wörter zu 'produktionspreis':
# holt: 0.3596445918083191
# grundstock: 0.34905731678009033
# pleite: 0.3286297619342804
# unzufrieden: 0.32370612025260925
# minister: 0.32278913259506226
#
# Die ähnlichsten Wörter zu 'mutig':
# dokumentation: 0.42163604497909546
# berufenen: 0.41404837369918823
# ausgiebig: 0.37499114871025085
# einjahresvertrag: 0.3540932238101959
# gegründeten: 0.32268500328063965
#
# Die ähnlichsten Wörter zu 'weiterarbeitet':
# ausgewogen: 0.3515630066394806
# aktiver: 0.3333275020122528
# pfund: 0.31945979595184326
# z.t.: 0.3146498203277588
# dateien: 0.3143526613712311
#
# Die ähnlichsten Wörter zu 'abels':
# spiel: 0.3654242753982544
# nähere: 0.3499089479446411
# auswärts: 0.3391589820384979
# leber: 0.32905590534210205
# coli: 0.3128902316093445
#
# Die ähnlichsten Wörter zu '19':
# landsleuten: 0.3710794150829315
# kargen: 0.3429078161716461
# haus: 0.34186968207359314
# reichsbrücken: 0.3354794979095459
# nannte: 0.3329813480377197
#
# Die ähnlichsten Wörter zu 'herausgeber':
# uber: 0.33452171087265015
# reglements: 0.32972002029418945
# 2,5: 0.3222735822200775
# recherche: 0.31561121344566345
# seelen: 0.3147123456001282
#
# Die ähnlichsten Wörter zu 'schukow':
# rechts: 0.33191123604774475
# dumpfe: 0.3083321452140808
# themen: 0.30764779448509216
# blonde: 0.3063283860683441
# läppische: 0.3057396411895752
#
# Die ähnlichsten Wörter zu 'sitzung':
# kanapee: 0.3811091184616089
# funktioniert: 0.34973806142807007
# steigern: 0.3475801348686218
# schloß: 0.3379736840724945
# weiblichen: 0.3291528820991516
#
# Die ähnlichsten Wörter zu 'unbedeutende':
# kuratierte: 0.35310301184654236
# verprügeln: 0.3214379847049713
# zusätzliche: 0.31895312666893005
# boys: 0.3170570135116577
# hackesche: 0.3154612183570862
#
# Die ähnlichsten Wörter zu 'ausgeglichen':
# abnorme: 0.34557855129241943
# präsentiert: 0.34322500228881836
# einschränkend: 0.34256789088249207
# cabriolet: 0.326130211353302
# komplizierten: 0.3119853436946869
#
# Die ähnlichsten Wörter zu 'theorie':
# öffnete: 0.37296411395072937
# nannte: 0.3386204242706299
# eltern: 0.325271874666214
# watergate: 0.3240108788013458
# täglichen: 0.31551164388656616
#
# Die ähnlichsten Wörter zu 'konterkarriert':
# restaurant: 0.3663550019264221
# musiktheoretischen: 0.3643093407154083
# page: 0.3389412462711334
# beleidigt: 0.3351156711578369
# favorisierte: 0.33074697852134705
#
# Die ähnlichsten Wörter zu 'giersiepen':
# füßen: 0.3634348213672638
# moralische: 0.3624548017978668
# ärgern: 0.3612985610961914
# erfahrungen: 0.3480983376502991
# speeren: 0.34308603405952454
#
# Die ähnlichsten Wörter zu 'seelenknoterei':
# alltagsgesohiohte: 0.3288276195526123
# arbeitnehmer: 0.32396939396858215
# weiß: 0.31909969449043274
# grundorganisation: 0.3156549036502838
# übermaße: 0.31502366065979004
#
# Die ähnlichsten Wörter zu 'ausreichend':
# akademie: 0.3842395842075348
# kapitalismus: 0.3721039593219757
# klar: 0.3418515622615814
# morales: 0.3283557593822479
# langt: 0.3125172257423401
#
# Die ähnlichsten Wörter zu 'bekämpft':
# erceg: 0.42458659410476685
# mittelmäßigkeiten: 0.37563419342041016
# jauchzend: 0.3515884280204773
# niederlanden: 0.3299744129180908
# sowjetbotschafter: 0.32486793398857117
#
# Die ähnlichsten Wörter zu 'reines':
# seidemann: 0.36264175176620483
# page: 0.32997047901153564
# europas: 0.3290894329547882
# italiener: 0.3136833608150482
# wüste: 0.3083667755126953
#
# Die ähnlichsten Wörter zu 'doppelter':
# aaron: 0.38624125719070435
# erträglicher: 0.3584858179092407
# aufziehen: 0.35135650634765625
# träumte: 0.3466089963912964
# hofft: 0.3184930682182312
#
# Die ähnlichsten Wörter zu 'reiner':
# 1,3: 0.34388330578804016
# paris: 0.3366452157497406
# bösewicht: 0.3355278968811035
# tobsucht: 0.3325897753238678
# komik: 0.3325771987438202
#
# Die ähnlichsten Wörter zu 'verdienst':
# angestaute: 0.32572975754737854
# franciscos: 0.31980568170547485
# klare: 0.3157341778278351
# anfangen: 0.3121175765991211
# xviii: 0.3115754723548889
#
# Die ähnlichsten Wörter zu 'zuschreiben':
# krisen: 0.34214672446250916
# jugendliche: 0.3306344449520111
# schwimmer: 0.3186649680137634
# verteidiger: 0.31775587797164917
# herrlichen: 0.3113572299480438
#
# Die ähnlichsten Wörter zu 'verspüren':
# verarbeitung: 0.37977567315101624
# nico: 0.3314112424850464
# verbissener: 0.3251537084579468
# jahrhundert: 0.3189254701137543
# brauch: 0.3173011541366577
#
# Die ähnlichsten Wörter zu 'dreitausendjährige':
# spritz: 0.3579366207122803
# echtheit: 0.34836438298225403
# rappt: 0.3466298282146454
# superzeitlupe: 0.3391824960708618
# fähigkeit: 0.33268308639526367
#
# Die ähnlichsten Wörter zu 'tradition':
# dringend: 0.4390566647052765
# veröffentlichung: 0.41492760181427
# arbeiterbewegung: 0.40240994095802307
# heuer: 0.3719199597835541
# margen: 0.3410724103450775
#
# Die ähnlichsten Wörter zu 'ahnen':
# kapitalismus: 0.3428642451763153
# verarbeitung: 0.3301956057548523
# angeboten: 0.31277528405189514
# hysterie: 0.3086608946323395
# häßliches: 0.3085605800151825
#
# Die ähnlichsten Wörter zu 'kulturtradition':
# verwundert: 0.388592392206192
# honecker: 0.3180121183395386
# auffallende: 0.30174490809440613
# kochkunst: 0.30165570974349976
# steehbeok: 0.3004280626773834
#
# Die ähnlichsten Wörter zu 'rührend':
# dirigieren: 0.33080917596817017
# hutt: 0.3268997073173523
# demos: 0.3182130455970764
# 7: 0.31344881653785706
# artikeln: 0.3083609938621521
#
# Die ähnlichsten Wörter zu 'zigarren':
# unerträgliche: 0.35198238492012024
# scheel: 0.3479812443256378
# schliesslich: 0.3286435306072235
# weigert: 0.3235759735107422
# bemühe: 0.3035937547683716
#
# Die ähnlichsten Wörter zu 'schenkte':
# besondere: 0.36133500933647156
# köpfen: 0.36093971133232117
# well: 0.3567981719970703
# unmöglich: 0.3405439555644989
# aufsteigen: 0.3307874798774719
#
# Die ähnlichsten Wörter zu 'formulierte':
# sportler: 0.3404926359653473
# maske: 0.32237735390663147
# mundharmonika: 0.31887853145599365
# leidenschaft: 0.3173825144767761
# mark: 0.31724095344543457
#
# Die ähnlichsten Wörter zu 'genosse':
# geteilten: 0.3359231650829315
# verletzte: 0.32174035906791687
# umweltminister: 0.3188374638557434
# zusammenbruch: 0.3184680938720703
# nehme: 0.3139333426952362
#
# Die ähnlichsten Wörter zu 'rakosi':
# ablud: 0.35903996229171753
# tauchen: 0.3446192741394043
# berichterstattung: 0.3394356369972229
# >: 0.337545782327652
# umgehen: 0.33694779872894287
#
# Die ähnlichsten Wörter zu 'ansehen':
# gelernt: 0.41813454031944275
# ausdrückt: 0.35352256894111633
# jugendphase: 0.3464003801345825
# selten: 0.3375040590763092
# privater: 0.3374989330768585

# %%
import pandas as pd
from IPython.display import display

# 7. Die ähnlichsten Wörter zu "freude"
similar_words_freude = model.wv.most_similar("freude", topn=10)
df_freude = pd.DataFrame(similar_words_freude, columns=["Ähnliches Wort", "Score"])
df_freude.insert(0, "Zielwort", "Freude")

# 7. Die ähnlichsten Wörter zu "wut"
similar_words_wut = model.wv.most_similar("wut", topn=10)
df_wut = pd.DataFrame(similar_words_wut, columns=["Ähnliches Wort", "Score"])
df_wut.insert(0, "Zielwort", "Wut")

# Anzeige beider Tabellen
print("Ähnlichste Wörter zu 'Freude':")
display(df_freude)

print("\nÄhnlichste Wörter zu 'Wut':")
display(df_wut)
# Out:
# Ähnlichste Wörter zu 'Freude':
#   Zielwort Ähnliches Wort     Score
# 0   Freude         blasse  0.443515
# 1   Freude      erfahrbar  0.391911
# 2   Freude     vorschiebt  0.355560
# 3   Freude           1945  0.352213
# 4   Freude         ärgern  0.350338
# 5   Freude       springen  0.345227
# 6   Freude       pobacken  0.325998
# 7   Freude     veranlasst  0.321259
# 8   Freude        gegnern  0.317853
# 9   Freude        mittags  0.314652
# Ähnlichste Wörter zu 'Wut':
#   Zielwort     Ähnliches Wort     Score
# 0      Wut             echter  0.357105
# 1      Wut     sozialistische  0.354086
# 2      Wut              roben  0.336921
# 3      Wut         aufkreuzen  0.320226
# 4      Wut           2.7.1960  0.309982
# 5      Wut  eltern-generation  0.308661
# 6      Wut             silvio  0.306378
# 7      Wut            bezogen  0.305668
# 8      Wut              dauer  0.304853
# 9      Wut              nioht  0.299862

# %% [markdown]
# ![image.png](attachment:ad12b7ca-d72e-493f-9851-536f80cac8cd.png) ![image.png](attachment:96b3d7ae-8f7b-4a43-b7ab-1336dabfc866.png)

# %%
import pandas as pd
from IPython.display import display

results_freude = []
results_wut = []

for word in ['freude', 'wut']:
    for korpus_name, korpus_tokens in [
        ("Zeitung", freude_tokens_zeitung + wut_tokens_zeitung),
        ("Web", freude_tokens_web + wut_tokens_web),
        ("Meta", freude_tokens_meta + wut_tokens_meta)]:
        
        temp_model = Word2Vec(sentences=korpus_tokens, vector_size=100, window=5, min_count=1, workers=4)
        temp_model.build_vocab(korpus_tokens, update=True)
        temp_model.train(korpus_tokens, total_examples=temp_model.corpus_count, epochs=10)

        try:
            similar_words = temp_model.wv.most_similar(word.lower(), topn=5)
            for similar_word, score in similar_words:
                row = {
                    "Zielwort": word.capitalize(),
                    "Korpus": korpus_name,
                    "Ähnliches Wort": similar_word,
                    "Score": score
                }
                if word == 'freude':
                    results_freude.append(row)
                else:
                    results_wut.append(row)
        except KeyError:
            print(f"'{word}' nicht im Vokabular von '{korpus_name}' gefunden.")

df_freude = pd.DataFrame(results_freude)
df_wut = pd.DataFrame(results_wut)

# Anzeige
print("Ähnlichste Wörter zu 'Freude' in den einzelnen Korpora:")
display(df_freude)

print("\nÄhnlichste Wörter zu 'Wut' in den einzelnen Korpora:")
display(df_wut)
# Out:
# Ähnlichste Wörter zu 'Freude' in den einzelnen Korpora:
#    Zielwort   Korpus Ähnliches Wort     Score
# 0    Freude  Zeitung            wut  0.438531
# 1    Freude  Zeitung          1923.  0.359536
# 2    Freude  Zeitung             e.  0.349814
# 3    Freude  Zeitung          alten  0.344975
# 4    Freude  Zeitung          emile  0.343303
# 5    Freude      Web            wut  0.610655
# 6    Freude      Web           welt  0.434652
# 7    Freude      Web            mal  0.419551
# 8    Freude      Web           zorn  0.399843
# 9    Freude      Web          liebe  0.389552
# 10   Freude     Meta            wut  0.688523
# 11   Freude     Meta          sehen  0.529615
# 12   Freude     Meta        artikel  0.485933
# 13   Freude     Meta           fast  0.455422
# 14   Freude     Meta       arbeiter  0.444367
# Ähnlichste Wörter zu 'Wut' in den einzelnen Korpora:
#    Zielwort   Korpus Ähnliches Wort     Score
# 0       Wut  Zeitung         freude  0.438531
# 1       Wut  Zeitung           ließ  0.420244
# 2       Wut  Zeitung          angst  0.408609
# 3       Wut  Zeitung           frau  0.366508
# 4       Wut  Zeitung          sieht  0.358256
# 5       Wut      Web         freude  0.610655
# 6       Wut      Web           welt  0.490059
# 7       Wut      Web          thema  0.470224
# 8       Wut      Web            mal  0.458948
# 9       Wut      Web        schüler  0.406144
# 10      Wut     Meta         freude  0.688523
# 11      Wut     Meta          sehen  0.555928
# 12      Wut     Meta           hand  0.523583
# 13      Wut     Meta          leben  0.493399
# 14      Wut     Meta        artikel  0.468941

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

words = [word for word in model.wv.index_to_key if model.wv.get_vecattr(word, "count") >= 10]
word_vectors = np.array([model.wv[word] for word in words])

num_clusters = 5
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(word_vectors)

plt.figure(figsize=(10, 8))
for i in range(num_clusters):
    cluster_center = kmeans.cluster_centers_[i]
    plt.scatter(cluster_center[0], cluster_center[1], label=f'Cluster {i + 1}')

plt.title('K-Means Clustering of Words')
plt.legend()
plt.show()
# Out:
# C:\Users\anitk\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
import pandas as pd

similarities_data = []

for word in ['freude', 'wut']:
    for korpus_name, korpus_tokens in [
        ("Zeitung", freude_tokens_zeitung + wut_tokens_zeitung),
        ("Web", freude_tokens_web + wut_tokens_web),
        ("Meta", freude_tokens_meta + wut_tokens_meta)]:
        
        temp_model = Word2Vec(sentences=korpus_tokens, vector_size=100, window=5, min_count=1, workers=4)
        temp_model.build_vocab(korpus_tokens, update=True)
        temp_model.train(korpus_tokens, total_examples=temp_model.corpus_count, epochs=10)

        try:
            similar_words = temp_model.wv.most_similar(word.lower(), topn=5)  # Wybieramy 5 najbliższych słów
            for similar_word, score in similar_words:
                similarities_data.append([word, korpus_name, similar_word, score])
        except KeyError:
            print(f"Das Wort '{word}' wurde nicht im Vokabular des Korpus '{korpus_name}' gefunden.")

df_similarities = pd.DataFrame(similarities_data, columns=["Word", "Corpus", "Similar Word", "Similarity Score"])

print(df_similarities)

df_similarities.to_csv('similarities_table.csv', index=False)
# Out:
#       Word   Corpus Similar Word  Similarity Score
# 0   freude  Zeitung          wut          0.438531
# 1   freude  Zeitung        1923.          0.359536
# 2   freude  Zeitung           e.          0.349814
# 3   freude  Zeitung        alten          0.344975
# 4   freude  Zeitung        emile          0.343303
# 5   freude      Web          wut          0.610655
# 6   freude      Web         welt          0.434652
# 7   freude      Web          mal          0.419551
# 8   freude      Web         zorn          0.399843
# 9   freude      Web        liebe          0.389552
# 10  freude     Meta          wut          0.688523
# 11  freude     Meta        sehen          0.529615
# 12  freude     Meta      artikel          0.485933
# 13  freude     Meta         fast          0.455422
# 14  freude     Meta     arbeiter          0.444367
# 15     wut  Zeitung       freude          0.438531
# 16     wut  Zeitung         ließ          0.420244
# 17     wut  Zeitung        angst          0.408609
# 18     wut  Zeitung         frau          0.366508
# 19     wut  Zeitung        sieht          0.358256
# 20     wut      Web       freude          0.610655
# 21     wut      Web         welt          0.490059
# 22     wut      Web        thema          0.470224
# 23     wut      Web          mal          0.458948
# 24     wut      Web      schüler          0.406144
# 25     wut     Meta       freude          0.688523
# 26     wut     Meta        sehen          0.555928
# 27     wut     Meta         hand          0.523583
# 28     wut     Meta        leben          0.493399
# 29     wut     Meta      artikel          0.468941

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

pca = PCA(n_components=2)
reduced_vectors = pca.fit_transform(word_vectors)  # word_vectors = np.array([...])
kmeans = KMeans(n_clusters=4, random_state=42)
clusters = kmeans.fit_predict(word_vectors)

pca_df = pd.DataFrame({
    'Wort': words,
    'PCA1': reduced_vectors[:, 0],
    'PCA2': reduced_vectors[:, 1],
    'Cluster': clusters
})

from IPython.display import display
display(pca_df)

pca_df.to_csv("word2vec_clusters_pca.csv", index=False)

plt.figure(figsize=(10, 8))
for i in range(len(words)):
    plt.scatter(reduced_vectors[i][0], reduced_vectors[i][1], c=f"C{clusters[i]}")
    plt.text(reduced_vectors[i][0], reduced_vectors[i][1], words[i], fontsize=9)
plt.title('Visualisierung der K-means Ergebnisse von PCA')
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.grid(True)
plt.show()
# Out:
# C:\Users\anitk\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#         Wort      PCA1      PCA2  Cluster
# 0        wut -0.024868  0.005358        2
# 1     freude -0.004490 -0.004545        3
# 2      sehen -0.004673 -0.022208        2
# 3   menschen  0.006328 -0.001562        2
# 4        mal  0.017919 -0.021337        2
# ..       ...       ...       ...      ...
# 73    gehört  0.012675 -0.026132        2
# 74     lesen  0.000484  0.018345        1
# 75  genossen  0.000436  0.017438        0
# 76     gerne -0.011250  0.009622        3
# 77    bleibt  0.007281  0.004400        2
#
# [78 rows x 4 columns]

# %% [markdown]
# ![image.png](attachment:a1c935b8-4508-4db1-9667-88ea2d9bd1b8.png)

# %%
from gensim.models import Word2Vec

all_sentences = (
    freude_tokens_zeitung + wut_tokens_zeitung + 
    freude_tokens_web + wut_tokens_web + 
    freude_tokens_meta + wut_tokens_meta
)

all_sentences = [[word for word in sentence if isinstance(word, str)] for sentence in all_sentences]

model = Word2Vec(sentences=all_sentences, vector_size=100, window=5, min_count=1, workers=4)

model.save("word2vec_gefühlsworter_all_korpora.model")

freude_similar = model.wv.most_similar('freude', topn=10)
wut_similar = model.wv.most_similar('wut', topn=10)

print("Die ähnlichsten Wörter zu 'Freude':")
for word, similarity in freude_similar:
    print(f"{word}: {similarity}")

print("\nDie ähnlichsten Wörter zu 'Wut':")
for word, similarity in wut_similar:
    print(f"{word}: {similarity}")
# Out:
# Die ähnlichsten Wörter zu 'Freude':
# blasse: 0.44447311758995056
# erfahrbar: 0.39148348569869995
# vorschiebt: 0.354999840259552
# 1945: 0.35169094800949097
# ärgern: 0.35045725107192993
# springen: 0.34574535489082336
# pobacken: 0.3254859447479248
# veranlasst: 0.32106688618659973
# gegnern: 0.31796297430992126
# mittags: 0.31351760029792786
#
# Die ähnlichsten Wörter zu 'Wut':
# echter: 0.3556983470916748
# sozialistische: 0.3535740077495575
# roben: 0.33624666929244995
# aufkreuzen: 0.32124316692352295
# 2.7.1960: 0.30933308601379395
# eltern-generation: 0.30809587240219116
# silvio: 0.3072485625743866
# bezogen: 0.30535227060317993
# dauer: 0.3045646548271179
# nioht: 0.29980185627937317

# %%
similarity = model.wv.similarity('freude', 'wut')
print("\nSimilarity between 'Freude' and 'Wut':", similarity)
# Out:
# Similarity between 'Freude' and 'Wut': 0.22328687

# %%
import numpy as np
import pandas as pd
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

words = ['freude', 'wut'] + [word for word, _ in freude_similar] + [word for word, _ in wut_similar]
vectors = np.array([model.wv[word] for word in words])  # Wektory słów z modelu Word2Vec

tsne = TSNE(n_components=2, random_state=0, perplexity=5)
reduced_vectors = tsne.fit_transform(vectors)

tsne_df = pd.DataFrame({
    'Wort': words,
    'TSNE1': reduced_vectors[:, 0],
    'TSNE2': reduced_vectors[:, 1]
})

from IPython.display import display
display(tsne_df)

tsne_df.to_csv("tsne_word_vectors.csv", index=False)

plt.figure(figsize=(10, 8))
for i, word in enumerate(words):
    plt.scatter(reduced_vectors[i, 0], reduced_vectors[i, 1])
    plt.text(reduced_vectors[i, 0] + 0.01, reduced_vectors[i, 1] + 0.01, word, fontsize=12)

plt.title("Visualization of the word vectors for 'Freude' and 'Wut' and their similarities")
plt.show()
# Out:
#                  Wort       TSNE1      TSNE2
# 0              freude  -96.733727 -11.224283
# 1                 wut   87.206520 -11.496770
# 2              blasse  -77.263847   9.338160
# 3           erfahrbar  -69.252037 -35.660172
# 4          vorschiebt  -94.235245  39.366745
# 5                1945 -129.669601  60.717712
# 6              ärgern -109.700150  90.546112
# 7            springen -127.032928 -62.371479
# 8            pobacken -155.187119 -10.330187
# 9          veranlasst -207.049530  26.908464
# 10            gegnern -181.355637  20.426037
# 11            mittags  -60.744881  43.232059
# 12             echter  118.621391 -37.717110
# 13     sozialistische  124.067284   5.590094
# 14              roben   78.858696  19.148434
# 15         aufkreuzen    9.097294  -0.204908
# 16           2.7.1960   31.184513  35.698193
# 17  eltern-generation  -22.755545  97.143372
# 18             silvio   99.110237 -80.148102
# 19            bezogen  157.335266   6.858553
# 20              dauer  112.638664  51.272041
# 21              nioht   46.915852 -49.070000

# %% [markdown]
# ![image.png](attachment:d6e35e09-7616-4b17-8b40-2e7c6cdb92b0.png)

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import numpy as np

# Vorbereitung der Daten: Vektoren aller Wörter im Word2Vec-Modell
words = list(model.wv.index_to_key)
word_vectors = np.array([model.wv[word] for word in words])

# KMeans - Gruppierung der Wörter in 5 Cluster
kmeans = KMeans(n_clusters=5, random_state=0).fit(word_vectors)

# Zuweisung der Wörter zu Clustern und Extraktion der Ergebnisse
clusters = {}
for i, label in enumerate(kmeans.labels_):
    clusters.setdefault(label, []).append(words[i])

# Erstellen eines DataFrame mit den Ergebnissen
cluster_df = pd.DataFrame(columns=["Cluster", "Wörter"])
for cluster, terms in clusters.items():
    # Nur die ersten 10 Wörter jedes Clusters anzeigen
    cluster_df = pd.concat([cluster_df, pd.DataFrame({"Cluster": [cluster], "Wörter": [", ".join(terms[:10])]})], ignore_index=True)

# Anzeigen der Ergebnisse in einer Tabelle
print(cluster_df)

# Visualisierung in 2D - Dimensionsreduktion mit PCA
pca = PCA(n_components=2)
reduced = pca.fit_transform(word_vectors)

# Diagramm zeichnen
plt.figure(figsize=(10,7))
plt.scatter(reduced[:, 0], reduced[:, 1], c=kmeans.labels_, cmap='rainbow')
for i, word in enumerate(words):
    plt.annotate(word, xy=(reduced[i, 0], reduced[i, 1]), fontsize=8)
plt.title("Cluster of Emotions: Freude & Wut")
plt.show()
# Out:
#   Cluster                                             Wörter
# 0       2  wut, freude, welt, liebe, feinde, buch, waffen...
# 1       1  sehen,  , geschichte, hand, grund, levels, art...
# 2       4  menschen, mal, leben, angst, weg, zorn, sagen,...
# 3       3  fast, frau, artikel, band, mutter, alten, 2, i...
# 4       0  lassen, arbeit, geben, schreiben, manchmal, th...

# %% [markdown]
# ![image.png](attachment:3506629a-a77a-4f99-8eda-a03e51813d74.png)

# %%
kmeans = KMeans(n_clusters=10, random_state=0).fit(word_vectors)

# %%
word_vectors_filtered = [model.wv[word] for word in words if model.wv.get_vecattr(word, "count") > 1]
words_filtered = [word for word in words if model.wv.get_vecattr(word, "count") > 1]

# %%
tsne = TSNE(n_components=2, random_state=0, perplexity=30, max_iter=5000)
reduced_vectors = tsne.fit_transform(word_vectors)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))

plt.scatter(reduced_vectors[:, 0], reduced_vectors[:, 1], c=kmeans.labels_, cmap='rainbow')

for i, word in enumerate(words):
    plt.annotate(word, xy=(reduced_vectors[i, 0], reduced_vectors[i, 1]), fontsize=8)

plt.title("2D Visualization of Words (t-SNE) with Clusters")
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.show()

# %% [markdown]
# ![image.png](attachment:94ff8a43-6ddb-4eb0-8ed5-0e5a6b3f2b8b.png)

# %%
import pandas as pd
import numpy as np

cluster_labels = kmeans.labels_

df_clusters = pd.DataFrame({
    'Word': words,
    'Cluster': cluster_labels
})

df_clusters_sorted = df_clusters.sort_values(by='Cluster')

print(df_clusters_sorted)

df_clusters_sorted.to_excel('Cluster_Results.xlsx', index=False)
# Out:
#              Word  Cluster
# 2741  spekulation        0
# 650        bänden        0
# 3967     skulptur        0
# 3966       museum        0
# 4325  unverändert        0
# ...           ...      ...
# 3805   türkischen        9
# 3804     zuweilen        9
# 3796    dauernden        9
# 3919         hell        9
# 4024       grazer        9
#
# [8049 rows x 2 columns]

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize

freude_zeitung = pd.read_excel("zeitungskorpora_freude_cleaned.xlsx")
wut_zeitung = pd.read_excel("zeitungskorpora_wut_cleaned.xlsx")

freude_web = pd.read_excel("webkorpora_freude_cleaned.xlsx")
wut_web = pd.read_excel("webkorpora_wut_cleaned.xlsx")

freude_meta = pd.read_excel("metakorpora_freude_cleaned.xlsx")
wut_meta = pd.read_excel("metakorpora_wut_cleaned.xlsx")

def tokenize_column(df, col_name="full_text"):
    combined_text = " ".join(df[col_name].astype(str)).lower()
    return word_tokenize(combined_text)

tokens_zeitung = tokenize_column(freude_zeitung) + tokenize_column(wut_zeitung)
tokens_web = tokenize_column(freude_web) + tokenize_column(wut_web)
tokens_meta = tokenize_column(freude_meta) + tokenize_column(wut_meta)

freude_zeitung_count = tokens_zeitung.count("freude")
wut_zeitung_count = tokens_zeitung.count("wut")

freude_web_count = tokens_web.count("freude")
wut_web_count = tokens_web.count("wut")

freude_meta_count = tokens_meta.count("freude")
wut_meta_count = tokens_meta.count("wut")

data = {
    'Korpus': ['Zeitung', 'Web', 'Meta'],
    'Freude': [freude_zeitung_count, freude_web_count, freude_meta_count],
    'Wut': [wut_zeitung_count, wut_web_count, wut_meta_count]
}

df_counts = pd.DataFrame(data)
print(df_counts)
# Out:
#     Korpus  Freude  Wut
# 0  Zeitung      90  101
# 1      Web      88   96
# 2     Meta     102  105

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Korpus': ['Zeitung', 'Web', 'Meta'],
    'Freude': [90, 88, 102],
    'Wut': [101, 96, 105]
}

import pandas as pd
df = pd.DataFrame(data)
df_melted = df.melt(id_vars='Korpus', var_name='Wort', value_name='Häufigkeit')

plt.figure(figsize=(8,5))
sns.barplot(data=df_melted, x='Korpus', y='Häufigkeit', hue='Wort')
plt.title('Frequency of „Freude“ and „Wut“ in Various Corpora')
plt.ylabel('Number of occurrences')
plt.xlabel('Corpus')
plt.tight_layout()
plt.show()

# %% [markdown]
# ![image.png](attachment:91075f94-18c6-4679-be0b-da2a5ad0a2cd.png)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

freude_zeitung_collocations = {
    'gerne': 5, 'grund': 5, 'vielleicht': 5, 'schritt': 4, 'sagt': 4,
    'große': 4, 'sagte': 4, 'wissen': 4, 'lässt': 4, 'mitreißen': 4
}

wut_zeitung_collocations = {
    'wut': 8, 'wurde': 6, 'scham': 6, 'angst': 5, 'mehr': 5,
    'sagte': 5, 'deren': 5, 'sei': 4, 'ja': 4, 'lässt': 4
}

freude_web_collocations = {
    'immer': 7, 'daran': 4, 'unbändige': 4, 'neuen': 4, 'leserinnen': 4,
    'leben': 4, 'hätte': 4, 'gehabt': 4, 'groß': 4, 'wenig': 4
}

wut_web_collocations = {
    'mehr': 26, 'angst': 9, 'wirklich': 8, 'ganze': 8, 'gut': 7,
    'levels': 6, 'details': 6, 'blut': 6, 'spiel': 6, 'immer': 6
}

freude_meta_collocations = {
    'große': 17, 'großer': 16, 'immer': 14, 'reine': 12, 'ganz': 11,
    'sehen': 9, 'genossen': 8, 'arbeit': 7, 'gestern': 6, 'las': 6
}

wut_meta_collocations = {
    'angst': 10, 'immer': 10, 'schon': 8, 'zorn': 6, 'gar': 6,
    'sehen': 5, 'darin': 4, 'ja': 4, 'haß': 4, 'reine': 4
}

freude_collocations = {**freude_zeitung_collocations, **freude_web_collocations, **freude_meta_collocations}
wut_collocations = {**wut_zeitung_collocations, **wut_web_collocations, **wut_meta_collocations}

def generate_wordcloud(collocations, title):
    wc = WordCloud(background_color='white').generate_from_frequencies(collocations)
    plt.figure(figsize=(6, 6))
    plt.imshow(wc, interpolation='bilinear')
    plt.axis('off')
    plt.title(title)
    plt.show()

generate_wordcloud(freude_collocations, 'Typical collocations for „Freude“')

generate_wordcloud(wut_collocations, 'TTypical collocations for „Wut“')

# %% [markdown]
# ![image.png](attachment:c12b850b-b641-47eb-8876-90a860823e43.png)

# %%
freude_collocations_zeitung = ['gerne', 'grund', 'vielleicht', 'schritt', 'sagt', 'große', 'sagte', 'wissen', 'lässt', 'mitreißen']
wut_collocations_zeitung = ['wut', 'mehr', 'zorn', 'angst', 'laut', 'scham', 'wurde', 'sagte', 'deren', 'sei']

freude_collocations_web = ['immer', 'daran', 'unbändige', 'neuen', 'leserinnen', 'leben', 'hätte', 'gehabt', 'groß', 'wenig']
wut_collocations_web = ['mehr', 'angst', 'wirklich', 'ganze', 'gut', 'levels', 'details', 'blut', 'spiel', 'immer']

freude_collocations_meta = ['große', 'großer', 'immer', 'reine', 'ganz', 'sehen', 'genossen', 'arbeit', 'gestern', 'las']
wut_collocations_meta = ['angst', 'immer', 'schon', 'zorn', 'gar', 'sehen', 'darin', 'ja', 'haß', 'reine']

# %%
from gensim.models import Word2Vec

def generate_fake_vectors(tokens):
    return np.random.rand(len(tokens), 300) 

freude_zeitung_vectors = generate_fake_vectors(freude_collocations_zeitung)
wut_zeitung_vectors = generate_fake_vectors(wut_collocations_zeitung)
freude_web_vectors = generate_fake_vectors(freude_collocations_web)
wut_web_vectors = generate_fake_vectors(wut_collocations_web)
freude_meta_vectors = generate_fake_vectors(freude_collocations_meta)
wut_meta_vectors = generate_fake_vectors(wut_collocations_meta)

all_vectors = np.concatenate([freude_zeitung_vectors, wut_zeitung_vectors,
                              freude_web_vectors, wut_web_vectors,
                              freude_meta_vectors, wut_meta_vectors], axis=0)

collocations = (freude_collocations_zeitung + wut_collocations_zeitung +
                freude_collocations_web + wut_collocations_web +
                freude_collocations_meta + wut_collocations_meta)

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

pca = PCA(n_components=2)
reduced = pca.fit_transform(all_vectors)

kmeans = KMeans(n_clusters=2, random_state=0)
labels = kmeans.fit_predict(all_vectors)

plt.figure(figsize=(10,8))
sns.scatterplot(x=reduced[:,0], y=reduced[:,1], hue=labels, s=100)
for i, word in enumerate(collocations):
    plt.text(reduced[i,0]+0.01, reduced[i,1]+0.01, word, fontsize=9)
plt.title('Semantic clusters of collocations to „Freude“ and „Wut“ (PCA + KMeans)')
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.show()
# Out:
# C:\Users\anitk\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# ![image.png](attachment:1d0ecaa3-81cc-43ff-92e3-fe8623f908d6.png)

# %%
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sentences = [["freude", "glück", "strahlen", "lachen", "wut", "zorn", "hass", "ärger", "trauer", "emotion"]]
model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, workers=1)

freude_similar = model.wv.most_similar("freude", topn=5)
wut_similar = model.wv.most_similar("wut", topn=5)

words = ["freude"] + [w[0] for w in freude_similar] + ["wut"] + [w[0] for w in wut_similar]
labels = ["freude"] * (1 + len(freude_similar)) + ["wut"] * (1 + len(wut_similar))

vectors = np.array([model.wv[word] for word in words])

pca = PCA(n_components=2)
reduced = pca.fit_transform(vectors)

kmeans = KMeans(n_clusters=2, random_state=0, n_init=10)
clusters = kmeans.fit_predict(vectors)

plt.figure(figsize=(10, 7))
palette = sns.color_palette("Set1", n_colors=2)
sns.scatterplot(x=reduced[:, 0], y=reduced[:, 1], hue=clusters, s=120, palette=palette)
for i, word in enumerate(words):
    plt.text(reduced[i, 0]+0.01, reduced[i, 1]+0.01, word, fontsize=12)
plt.title('K-Means clusters of similar words „Freude“ and „Wut“')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Componente 2')
plt.legend(title="Cluster")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\anitk\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# ![image.png](attachment:9935978a-27b3-42b4-aaa1-8dc3dd6aeff7.png)
